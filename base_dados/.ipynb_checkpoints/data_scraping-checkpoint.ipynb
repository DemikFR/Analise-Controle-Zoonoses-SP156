# %% [markdown]
# # Pipeline ETL: Agregando Datasets do SP196 em um Arquivo Consolidado

# %% [markdown]
# ## Aviso: Comentários resumidos neste código; consulte a  [Documentação](https://github.com/DemikFR/Analise-Controle-Zoonoses-SP156/blob/main/README.md) para obter uma compreensão mais detalhada das razões por trás de cada trecho de código.

# %% [markdown]
# ## Gerar o dataframe com os dados da Prefeitura

# %%
import requests
import re
from bs4 import BeautifulSoup as bs
import pandas as pd
from io import StringIO
import chardet

# %% [markdown]
# ### Criar o dataframe que conterá os dados necessários para a análise

# %%
df = pd.DataFrame()
dfs = []

# %% [markdown]
# ## Função para buscar os caminhos para o download de cada dataset

# %%
def get_soup(url, search):
    response = requests.get(url)
    
    # Verificar se a conexão foi bem sucedida
    if response.status_code == 200:
        soup = bs(response.content, 'html.parser')

        # Retornar as páginas onde terão as de download
        return soup.find_all('a', href=True, attrs={'title': re.compile(search)}) 
    else:
        return f'Página{link["title"]} está inacessível. Código: {response.status_code}'

# %% [markdown]
# ## Código para inserir os dados em uma lista

# %%
# URL base do site da Prefeitura
url_base = 'http://dados.prefeitura.sp.gov.br'

# URL inicial onde estarão os links para os datasets
url_inicial = 'http://dados.prefeitura.sp.gov.br/dataset/dados-do-sp156'

# extensão do dataset para filtrar
file_type = '.csv'

for link in get_soup(url_inicial, r'^Dados do SP156 -.*'):
    
    # Pegar o link de download
    for page in get_soup(url_base+link['href'], r'^http://dados.prefeitura.sp.gov.br/dataset/.*'):
        link_download = page['href']
        
        # Verificar se é o arquivo a ser baixado é Excel
        if file_type in link_download:
            
            # Pegar o conteúdo do CSV
            response_csv = requests.get(page['href'])
            
            # Cada datset tem um encoding diferente, por isso foi necessário usar a biblioteca chardet para identificar 
            # automaticamente qual é.
            encoding = chardet.detect(response_csv.content)['encoding']
            
            # Colocar os dados na tabela auxiliar
            if int(link["title"][-4:]) >= 2021:
                df3 = pd.read_csv(StringIO(response_csv.content.decode(encoding)), sep=';', encoding=encoding, low_memory=False)
            else:
                df3 = pd.read_csv(StringIO(response_csv.content.decode(encoding)), sep=',', encoding=encoding, low_memory=False)
                
            dfs.append(df3)  # Adicionar o DataFrame intermediário à lista
            
            # Inserir os dados na planilha original
            print(f'Os dados do {link["title"]} foram inseridos com sucesso.')
# Out:
# Os dados do Dados do SP156 - 1º TRI 2023 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 4º TRI 2022 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 3º TRI 2022 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º TRI 2022 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º TRI 2022 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 4º TRI 2021 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 3º TRI 2021 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º TRI 2021 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º TRI 2021 foram inseridos com sucesso.
# Os dados do Dados do SP156 - Dezembro - 2020 foram inseridos com sucesso.
# Os dados do Dados do SP156 - Outubro e Novembro - 2020 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 3º TRI 2020 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2020 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º SEM 2019 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2019 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º SEM 2018 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2018 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2° SEM 2017 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1° SEM 2017 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1° SEM 2016 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º SEM 2015 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2015 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2° SEM 2014 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2014 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º SEM 2013 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2013 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º SEM 2012 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2012 foram inseridos com sucesso.

# %% [markdown]
# ## Criar o dataframe com todos os datasets coletados

# %%
df = pd.concat(dfs, ignore_index=True)

# %%
df.shape
# Out:
# (13688540, 33)

# %% [markdown]
# ## Verificar todas as colunas disponibilizadas

# %%
df.any()
# Out:
# Data de abertura                                                          True
# Canal                                                                     True
# Tema                                                                      True
# Assunto                                                                   True
# Serviço                                                                   True
# Logradouro                                                                True
# Número                                                                    True
# CEP                                                                       True
# Subprefeitura                                                             True
# Distrito                                                                  True
# Setor                                                                     True
# Quadra                                                                    True
# Latitude                                                                  True
# Longitude                                                                 True
# Data do parecer                                                           True
# Status da solicitação                                                     True
# Órgão                                                                     True
# Data Avaliação Pesquisa Satisfação                                        True
# Nível Satisfação                                                          True
# Prazo de Atendimento                                                      True
# Qualidade do Serviço                                                      True
# Atendeu a Solicitação                                                     True
# Compreensão da Resposta                                                   True
# De modo geral, qual o seu nível de satisfação com o serviço prestado?     True
# Prazo de atendimento                                                      True
# Qualidade do serviço                                                      True
# A Prefeitura atendeu a sua solicitação?                                   True
# Compreensão da resposta recebida                                          True
# Cep                                                                       True
# Unnamed: 23                                                              False
# Canal de atendimento                                                      True
# Especificação do assunto                                                  True
# Bairro                                                                    True
# dtype: bool

# %% [markdown]
# ## Manter apenas os campos necessários

# %%
df = df[['Data de abertura', 'Tema', 'Assunto', 'Especificação do assunto', 'Serviço', 'Bairro', 'Distrito'
         , 'Status da solicitação', 'Data do parecer']]

# %% [markdown]
# ## Apagar registros que por terem muitos valores nulo, não servirão para a análise

# %%
df = df.dropna(thresh=4)

# %%
df[df.Assunto.isnull()]
# Out:
# Empty DataFrame
# Columns: [Data de abertura, Tema, Assunto, Especificação do assunto, Serviço, Bairro, Distrito, Status da solicitação, Data do parecer]
# Index: []

# %%
df.sample(10)
# Out:
#                  Data de abertura                            Tema
# 2069587       2022-01-24 13:44:35                         Animais  \
# 937865        2022-12-10 09:16:54    Ouvidoria Geral do Município
# 5803840   2020-12-12 21:23:34.046  Cidadania e assistência social
# 10136407  2017-06-08 19:37:47.271                  Lixo e limpeza
# 3308450       2021-08-30 20:57:54                         Animais
# 12732288               2013-03-30                             NaN
# 1767438       2022-05-24 15:03:27                           Saúde
# 8365396   2019-03-19 12:33:32.476           Trânsito e Transporte
# 5127873       2021-03-23 14:23:44  Cidadania e assistência social
# 5789363   2020-12-12 15:50:13.612  Cidadania e assistência social
#
#                                                   Assunto
# 2069587   Animais que transmitem doenças ou risco à saúde  \
# 937865                       Ouvidoria Geral do Município
# 5803840                          Renda Básica Emergencial
# 10136407      Ponto viciado, entulho e caçamba de entulho
# 3308450                  Animais que podem causar doenças
# 12732288          Transporte publico / Linha e Itinerário
# 1767438                  Medicamento de controle especial
# 8365396                              Veículos abandonados
# 5127873                          Renda Básica Emergencial
# 5789363                          Renda Básica Emergencial
#
#               Especificação do assunto
# 2069587                            NaN  \
# 937865                             NaN
# 5803840                            NaN
# 10136407                           NaN
# 3308450                            NaN
# 12732288  Intervalo excessivo da linha
# 1767438                            NaN
# 8365396                            NaN
# 5127873                            NaN
# 5789363                            NaN
#
#                                                     Serviço       Bairro
# 2069587     Abelhas e Vespas - Solicitar vistoria em ninhos          NaN  \
# 937865                                           Reclamação          NaN
# 5803840   Renda Básica Emergencial - Consultar benefício...          NaN
# 10136407  Entulho e grandes objetos em via pública - sol...          NaN
# 3308450       Ratos - Solicitar vistoria em local infestado          NaN
# 12732288                                                NaN  JARDIM PERI
# 1767438   Farmácias de manipulação e drogarias - Entrega...          NaN
# 8365396   Solicitar remoção de veículo/carcaça abandonad...          NaN
# 5127873   Renda Básica Emergencial - Consultar benefício...          NaN
# 5789363   Renda Básica Emergencial - Consultar benefício...          NaN
#
#             Distrito   Status da solicitação          Data do parecer
# 2069587   CAMPO BELO              FINALIZADO      2022-04-13 17:57:47
# 937865           NaN  AGUARDANDO ATENDIMENTO      2023-01-06 08:23:15
# 5803840          NaN              FINALIZADA  2020-12-12 21:23:35.704
# 10136407  ITAIM BIBI              FINALIZADA  2018-02-10 17:10:49.000
# 3308450      SOCORRO              FINALIZADA      2021-09-08 14:08:02
# 12732288         NaN               REALIZADA  2013-04-09 00:00:00.000
# 1767438          NaN              FINALIZADA      2022-05-25 10:45:16
# 8365396    SAO LUCAS              FINALIZADA  2019-10-16 23:59:38.278
# 5127873          NaN              FINALIZADA      2021-03-23 14:23:55
# 5789363          NaN              FINALIZADA  2020-12-12 15:50:17.962

# %% [markdown]
# ## Filtrar apenas os dados necessários para a análise

# %%
df['Tema'].drop_duplicates()
# Out:
# 0           Cidadania e assistência social
# 5                                  Animais
# 7               Obras, imóveis e habitação
# 10                            Rua e bairro
# 34                           Meio Ambiente
# 37                          Lixo e limpeza
# 41                                Urgência
# 54                                   Saúde
# 67                     Comércio e serviços
# 95                   Trânsito e Transporte
# 151                           Causa animal
# 188           Ouvidoria Geral do Município
# 227                         Pragas urbanas
# 431                               Finanças
# 439                         Acessibilidade
# 918                          Bilhete Único
# 1272                      Segurança urbana
# 2334                 Documentos e licenças
# 2885              Cultura, esporte e lazer
# 4389                              Educação
# 8048                              Trabalho
# 334059              Descomplica São Miguel
# 596920               Canais de Atendimento
# 597569                 Prefeitura Regional
# 1044114                               4093
# 1389675                               4126
# 1548739                Baixas Temperaturas
# 1550759                               4050
# 1997106                  Serviço funerário
# 2605867                               3917
# 2605909                               4020
# 2770878                            SAC/GRC
# 4821770                               3929
# 11388300                               NaN
# Name: Tema, dtype: object

# %% [markdown]
# ### Entender o motivo de existirem nulos no 'Tema'

# %%
pd.set_option('display.max_rows', None)
df[df.Tema.isnull()]['Assunto'].drop_duplicates()
# Out:
# 11388300                             Construcao de passarelas
# 11388301                                               Buraco
# 11388302                                      Poluição Sonora
# 11388304    Placas de Nomes de Ruas, Praças e demais Logra...
# 11388306                         Iluminacao - Lampada apagada
# 11388307             Transporte publico / Conduta de Trabalho
# 11388308                              Remoção veículo/carcaça
# 11388310                                               Elogio
# 11388314                            Vistoria / Infraestrutura
# 11388317                                                Obras
# 11388318                                           Edificacao
# 11388319                                        Animais / Cão
# 11388324                                         Pavimentacao
# 11388329                      Árvore(Calçada/Passeio Público)
# 11388332                          Transporte publico / Outros
# 11388334                                       Guias/sarjetas
# 11388336        Transporte publico / Manutenção e Conservação
# 11388343                                              Calçada
# 11388359              Transporte publico / Linha e Itinerário
# 11388363                        Bueiros/galerias agua pluvial
# 11388367                   CET / Veículo com placa abandonado
# 11388370                   Transporte publico / Bilhete Unico
# 11388373    CET / Insatisfação com circulação de veículos(...
# 11388379                     Lixo / Limpeza - Coleta Seletiva
# 11388384                                              Entulho
# 11388393                                   Comercio irregular
# 11388399                                     Varrição/Limpeza
# 11388401                 Praças/Áreas Verdes/Canteiro Central
# 11388403                                        Praça Pública
# 11388406                 Ecoponto (Entulho e Grandes Objetos)
# 11388410         Processo Encerrado/Solicitacao Vistas/Cópias
# 11388413                        Denúncia sobre Poluição do Ar
# 11388415                  Capinação/Roçada de áreas vegetadas
# 11388416                              Bagulho/Grandes Objetos
# 11388418                                           Papeleiras
# 11388420                                          Feira Livre
# 11875339                                     PETI - Denúncias
# 12126022     Lixeira em Prédio Residencial e Outros Edifícios
# 12126259      Recente Ocorrência de Desabamento em Edificação
# 12126506                                Feira livre / Sacolao
# 12128265            Problemas com as Estruturas da Edificação
# 12169492         Recente Ocorrência de Incêndio em Edificação
# 12201851         Recente Ocorrência de Explosão em Edificação
# 12500442                        Jardinagem (poda, corte mato)
# 12502582    Mananciais-Oper.Defesa Águas/Áreas Verdes-Denú...
# 12935095                                      Permissionárias
# 13271787        Iluminacao - Novo ponto de Iluminacao Publica
# 13303394                                        Meio Ambiente
# 13306464                    CET / Cancelamento de Ocorrências
# 13538834                Central de Atendimento Telefonico 156
# Name: Assunto, dtype: object

# %% [markdown]
# ### O campo 'Tema' só é usado em datasets mais recentes, por isso deve-se utilizar o campo 'Assunto' para filtrar

# %%
df1 = df[df['Assunto'].str.contains('Animais', regex=False) | df['Tema'].str.contains(r'^Anim.*|^Pragas.*', regex=True)].reset_index(drop=True)

# %%
df1.shape
# Out:
# (704360, 9)

# %%
df1.sample(20)
# Out:
#                Data de abertura     Tema
# 603879               2013-11-29      NaN  \
# 97819       2022-01-06 16:21:02  Animais
# 519524  2015-04-10 20:35:48.727  Animais
# 548917               2014-11-26      NaN
# 176233      2021-08-20 19:12:31  Animais
# 102626      2022-01-15 12:00:42  Animais
# 253309      2021-03-10 01:36:57  Animais
# 439327  2017-01-30 15:34:50.676  Animais
# 684693  2012-03-08 17:14:05.310      NaN
# 669057  2012-12-29 12:06:42.080      NaN
# 548778               2014-11-26      NaN
# 197130      2021-04-19 18:33:52  Animais
# 245376      2021-02-16 21:44:37  Animais
# 509639  2015-02-15 03:29:03.627  Animais
# 154198      2021-12-14 21:57:15  Animais
# 200128      2021-04-27 22:51:20  Animais
# 325495  2020-02-11 23:40:17.345  Animais
# 407454  2018-03-06 16:58:57.095  Animais
# 416090  2018-06-07 14:05:19.383  Animais
# 335200  2020-06-08 13:14:59.128  Animais
#
#                                                 Assunto
# 603879                                 Animais / Pombos  \
# 97819                       Exames, vacinas e castração
# 519524  Animais que transmitem doenças ou risco à saúde
# 548917                                    Animais / Cão
# 176233                 Animais que podem causar doenças
# 102626                        Registro de animais - RGA
# 253309                      Exames, vacinas e castração
# 439327  Animais que transmitem doenças ou risco à saúde
# 684693                                    Animais / Cão
# 669057                             Animais / Pernilongo
# 548778                                Animais / Baratas
# 197130                      Exames, vacinas e castração
# 245376                      Exames, vacinas e castração
# 509639  Animais que transmitem doenças ou risco à saúde
# 154198                     Animal agressor e/ou invasor
# 200128                      Exames, vacinas e castração
# 325495                    Criação inadequada de animais
# 407454  Animais que transmitem doenças ou risco à saúde
# 416090  Animais que transmitem doenças ou risco à saúde
# 335200                            Animal em via pública
#
#                   Especificação do assunto
# 603879                Reclamação de Pombos  \
# 97819                                  NaN
# 519524                                 NaN
# 548917  Condições de criação / maus tratos
# 176233                                 NaN
# 102626                                 NaN
# 253309                                 NaN
# 439327                                 NaN
# 684693                        Cão Agressor
# 669057            Reclamação de Pernilongo
# 548778               Reclamação de Baratas
# 197130                                 NaN
# 245376                                 NaN
# 509639                                 NaN
# 154198                                 NaN
# 200128                                 NaN
# 325495                                 NaN
# 407454                                 NaN
# 416090                                 NaN
# 335200                                 NaN
#
#                                                   Serviço             Bairro
# 603879                                                NaN                NaN  \
# 97819                  Castrar cães e gatos gratuitamente                NaN
# 519524  Pernilongo/Mosquito - Solicitar vistoria em lo...                NaN
# 548917                                                NaN    VILA CONSTANCIA
# 176233  Escorpião - Solicitar vistoria de local com es...                NaN
# 102626  Registro Geral do Animal (RGA) - Solicitar ide...                NaN
# 253309                 Castrar cães e gatos gratuitamente                NaN
# 439327    Abelhas e Vespas - Solicitar vistoria em ninhos                NaN
# 684693                                                NaN  JARDIM MARIA RITA
# 669057                                                NaN       JARDIM CELIA
# 548778                                                NaN      JARDIM MIRIAM
# 197130                 Castrar cães e gatos gratuitamente                NaN
# 245376                 Castrar cães e gatos gratuitamente                NaN
# 509639  Pernilongo/Mosquito - Solicitar vistoria em lo...                NaN
# 154198      Avisar sobre animal agressor em vias públicas                NaN
# 200128                 Castrar cães e gatos gratuitamente                NaN
# 325495         Denunciar condições inadequadas de criação                NaN
# 407454     Pombos - Solicitar vistoria em local infestado                NaN
# 416090      Ratos - Solicitar vistoria em local infestado                NaN
# 335200   Solicitar remoção de animal morto em via pública                NaN
#
#                  Distrito Status da solicitação          Data do parecer
# 603879                NaN             REALIZADA  2013-12-06 00:00:00.000
# 97819                 NaN            FINALIZADO      2022-01-13 17:10:28
# 519524      CIDADE ADEMAR            FINALIZADA  2015-04-22 22:07:17.270
# 548917                NaN             REALIZADA  2016-12-09 13:43:33.251
# 176233     JOSE BONIFACIO            FINALIZADA      2021-08-24 13:03:45
# 102626                NaN            FINALIZADO      2022-02-15 12:56:14
# 253309                NaN            INDEFERIDO      2021-03-19 15:39:37
# 439327  ALTO DE PINHEIROS            FINALIZADA  2017-04-25 11:39:09.444
# 684693               23.0             CANCELADA  2012-04-24 00:00:00.000
# 669057                NaN             REALIZADA  2012-12-29 12:06:42.000
# 548778                NaN             REALIZADA  2015-05-15 03:00:00.000
# 197130                NaN            FINALIZADA      2021-05-02 10:25:48
# 245376                NaN            FINALIZADA      2021-02-17 12:42:31
# 509639        SANTO AMARO            FINALIZADA  2015-05-06 18:59:55.510
# 154198     ITAIM PAULISTA            FINALIZADA      2021-12-21 11:43:07
# 200128                NaN            FINALIZADA      2021-05-06 15:51:35
# 325495        VILA CURUCA            FINALIZADA  2020-05-22 14:34:30.870
# 407454       CAMPO GRANDE            FINALIZADA  2018-05-07 18:14:12.908
# 416090          AGUA RASA            FINALIZADA  2018-12-19 17:17:06.882
# 335200        VILA CURUCA            FINALIZADA  2020-06-08 16:37:41.000

# %% [markdown]
# ## Padronizar o campo 'Serviço' com o 'Especificação do assunto'

# %% [markdown]
# #### Os dois campos possuem o mesmo objetivo

# %%
df1.loc[df1['Serviço'].isnull(), 'Serviço'] = df1.loc[df1['Serviço'].isnull(), 'Especificação do assunto']

# %%
df1.sample(10)
# Out:
#                Data de abertura     Tema
# 510035  2015-02-18 16:20:57.040  Animais  \
# 185873      2021-09-19 18:07:14  Animais
# 288814  2020-11-24 22:38:29.227  Animais
# 291203  2020-07-01 20:41:52.828  Animais
# 502653  2015-01-08 14:52:27.123  Animais
# 681382  2012-02-25 15:48:32.860      NaN
# 598247               2013-10-15      NaN
# 342585  2019-07-30 14:02:31.520  Animais
# 403864  2018-02-01 11:32:20.290  Animais
# 357377  2019-12-10 15:25:11.634  Animais
#
#                                                 Assunto
# 510035  Animais que transmitem doenças ou risco à saúde  \
# 185873                 Animais que podem causar doenças
# 288814                      Exames, vacinas e castração
# 291203                            Animal em via pública
# 502653  Animais que transmitem doenças ou risco à saúde
# 681382                                          Animais
# 598247                                    Animais / Cão
# 342585                            Animal em via pública
# 403864                    Criação inadequada de animais
# 357377  Animais que transmitem doenças ou risco à saúde
#
#                         Especificação do assunto
# 510035                                       NaN  \
# 185873                                       NaN
# 288814                                       NaN
# 291203                                       NaN
# 502653                                       NaN
# 681382  Remoção de animal morto em vias publicas
# 598247                              Cão Agressor
# 342585                                       NaN
# 403864                                       NaN
# 357377                                       NaN
#
#                                                   Serviço             Bairro
# 510035      Ratos - Solicitar vistoria em local infestado                NaN  \
# 185873    Abelhas e Vespas - Solicitar vistoria em ninhos                NaN
# 288814                 Castrar cães e gatos gratuitamente                NaN
# 291203   Solicitar remoção de animal morto em via pública                NaN
# 502653  Escorpião - Solicitar vistoria de local com es...                NaN
# 681382           Remoção de animal morto em vias publicas  JARDIM ANHANGUERA
# 598247                                       Cão Agressor    CASA VERDE ALTA
# 342585   Solicitar remoção de animal morto em via pública                NaN
# 403864         Denunciar condições inadequadas de criação                NaN
# 357377    Abelhas e Vespas - Solicitar vistoria em ninhos                NaN
#
#                  Distrito Status da solicitação          Data do parecer
# 510035           CANGAIBA            FINALIZADA  2015-04-16 03:00:00.000
# 185873           ITAQUERA            FINALIZADA      2021-09-27 17:49:24
# 288814                NaN            FINALIZADA  2020-12-08 13:59:38.311
# 291203           ITAQUERA            FINALIZADA  2020-07-01 23:09:22.000
# 502653  CIDADE TIRADENTES            FINALIZADA  2015-06-03 14:05:29.137
# 681382                NaN             REALIZADA  2012-03-01 14:39:12.753
# 598247                NaN             REALIZADA  2013-11-13 00:00:00.000
# 342585        ARTUR ALVIM            FINALIZADA  2019-07-30 19:44:28.000
# 403864           ITAQUERA            FINALIZADA  2018-02-21 13:36:11.778
# 357377       CIDADE LIDER            FINALIZADA  2020-04-16 19:37:53.337

# %%
df1[df1['Serviço'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Data de abertura, Tema, Assunto, Especificação do assunto, Serviço, Bairro, Distrito, Status da solicitação, Data do parecer]
# Index: []

# %% [markdown]
# #### Deletar o campo que não terá mais utilidade

# %%
df1 = df1.drop('Especificação do assunto', axis=1)

# %% [markdown]
# ## Tratamento dos campos de localização

# %% [markdown]
# #### Os campos 'Bairro' e 'Distrito' são ambíguos, por isso que os valores que estão nulos em 'Distrito' receberão o valor de 'Bairro', caso exista. Além disso, o campo 'Distrito' existe alguns que são número, indicando um distrito que está na metadado disponibilizado neste repositório.

# %% [markdown]
# ### Preencher valores de 'Distrito' com o de 'Bairro'

# %%
df1.loc[df1['Distrito'].isnull() & df1['Bairro'].notnull(), 'Distrito'] = df1.loc[df1['Distrito'].isnull() & df1['Bairro'].notnull(), 'Bairro']

# %%
df1.sample(10)
# Out:
#                Data de abertura     Tema
# 443863  2017-03-09 15:56:45.603  Animais  \
# 393948  2018-11-12 21:05:05.246  Animais
# 652248  2012-09-17 16:32:15.570      NaN
# 687684  2012-03-23 09:25:45.060      NaN
# 283081  2020-11-10 14:51:33.174  Animais
# 437346  2017-01-13 20:59:53.441  Animais
# 570665               2014-03-20      NaN
# 404547  2018-02-08 15:13:27.250  Animais
# 597614               2013-10-10      NaN
# 387104  2018-08-30 17:43:48.991  Animais
#
#                                                 Assunto
# 443863                    Criação inadequada de animais  \
# 393948  Animais que transmitem doenças ou risco à saúde
# 652248                                    Animais / Cão
# 687684           Animais / Abelhas, Vespas, Marimbondos
# 283081                      Exames, vacinas e castração
# 437346  Animais que transmitem doenças ou risco à saúde
# 570665                                    Animais / Cão
# 404547  Animais que transmitem doenças ou risco à saúde
# 597614                                  Animais / Ratos
# 387104  Animais que transmitem doenças ou risco à saúde
#
#                                                   Serviço             Bairro
# 443863         Denunciar condições inadequadas de criação                NaN  \
# 393948      Ratos - Solicitar vistoria em local infestado                NaN
# 652248   Atropelado ou Acidentado vivo e sem proprietário    JARDIM NAKAMURA
# 687684                         Colméia/Vespeiro instalado        SANTO AMARO
# 283081                 Castrar cães e gatos gratuitamente                NaN
# 437346    Abelhas e Vespas - Solicitar vistoria em ninhos                NaN
# 570665                 Condições de criação / maus tratos  JARDIM ARICANDUVA
# 404547  Pernilongo/Mosquito - Solicitar vistoria em lo...                NaN
# 597614                                Reclamação de ratos       VILA FORMOSA
# 387104  Pernilongo/Mosquito - Solicitar vistoria em lo...                NaN
#
#                  Distrito Status da solicitação          Data do parecer
# 443863            LAJEADO            FINALIZADA  2017-04-12 17:48:43.216
# 393948      VILA MEDEIROS            FINALIZADA  2019-01-09 13:40:08.255
# 652248    JARDIM NAKAMURA             CANCELADA  2012-09-17 00:00:00.000
# 687684               72.0             CANCELADA  2012-08-10 00:00:00.000
# 283081                NaN            FINALIZADA  2020-12-23 11:55:08.768
# 437346           TUCURUVI            FINALIZADA  2017-04-10 17:42:54.434
# 570665  JARDIM ARICANDUVA             REALIZADA  2014-03-28 00:00:00.000
# 404547       CIDADE DUTRA            FINALIZADA  2018-04-23 12:27:29.730
# 597614       VILA FORMOSA             REALIZADA  2013-10-11 00:00:00.000
# 387104       CAMPO GRANDE            FINALIZADA  2018-11-23 12:27:24.777

# %% [markdown]
# ### Converter os valores que estão em código para o seu nome original

# %%
distrito = pd.read_csv('codigos_de_distritos.csv', sep=';')

# %%
distrito['Nr Distrito'] = distrito['Nr Distrito'].astype(float)

# %%
distrito
# Out:
#     Nr Distrito       Nome Distrito
# 0           1.0           Agua Rasa
# 1           2.0   Alto de Pinheiros
# 2           3.0          Anhanguera
# 3           4.0          Aricanduva
# 4           5.0         Artur Alvim
# 5           6.0         Barra Funda
# 6           7.0          Bela Vista
# 7           8.0               Belem
# 8           9.0          Bom Retiro
# 9          10.0                Bras
# 10         11.0         Brasilandia
# 11         12.0             Butanta
# 12         13.0        Cachoeirinha
# 13         14.0             Cambuci
# 14         15.0          Campo Belo
# 15         16.0        Campo Grande
# 16         17.0         Campo Limpo
# 17         18.0            Cangaiba
# 18         19.0       Capao Redondo
# 19         20.0              Carrao
# 20         21.0          Casa Verde
# 21         22.0       Cidade Ademar
# 22         23.0        Cidade Dutra
# 23         24.0        Cidade Lider
# 24         25.0   Cidade Tiradentes
# 25         26.0          Consolacao
# 26         27.0             Cursino
# 27         28.0  Ermelino Matarazzo
# 28         29.0      Freguesia Do O
# 29         30.0              Grajau
# 30         31.0          Guaianases
# 31         32.0               Moema
# 32         33.0            Iguatemi
# 33         34.0            Ipiranga
# 34         35.0          Itaim Bibi
# 35         36.0      Itaim Paulista
# 36         37.0            Itaquera
# 37         38.0           Jabaquara
# 38         39.0              Jacana
# 39         40.0             Jaguara
# 40         41.0             Jaguare
# 41         42.0             Jaragua
# 42         43.0       Jardim Angela
# 43         44.0       Jardim Helena
# 44         45.0     Jardim Paulista
# 45         46.0     Jardim Sao Luis
# 46         47.0      Jose Bonifacio
# 47         48.0                Lapa
# 48         49.0           Liberdade
# 49         50.0               Limao
# 50         51.0            Mandaqui
# 51         52.0            Marsilac
# 52         53.0               Mooca
# 53         54.0             Morumbi
# 54         55.0         Parelheiros
# 55         56.0                Pari
# 56         57.0     Parque Do Carmo
# 57         58.0            Pedreira
# 58         59.0               Penha
# 59         60.0            Perdizes
# 60         61.0               Perus
# 61         62.0           Pinheiros
# 62         63.0            Pirituba
# 63         64.0          Ponte Rasa
# 64         65.0      Raposo Tavares
# 65         66.0           Republica
# 66         67.0         Rio Pequeno
# 67         68.0              Sacoma
# 68         69.0       Santa Cecilia
# 69         70.0             Santana
# 70         71.0         Santo Amaro
# 71         72.0           Sao Lucas
# 72         73.0          Sao Mateus
# 73         74.0          Sao Miguel
# 74         75.0          Sao Rafael
# 75         76.0           Sapopemba
# 76         77.0               Saude
# 77         78.0                  Se
# 78         79.0             Socorro
# 79         80.0             Tatuape
# 80         81.0            Tremembe
# 81         82.0            Tucuruvi
# 82         83.0        Vila Andrade
# 83         84.0         Vila Curuca
# 84         85.0        Vila Formosa
# 85         86.0      Vila Guilherme
# 86         87.0          Vila Jacui
# 87         88.0     Vila Leopoldina
# 88         89.0          Vila Maria
# 89         90.0        Vila Mariana
# 90         91.0        Vila Matilde
# 91         92.0       Vila Medeiros
# 92         93.0       Vila Prudente
# 93         94.0          Vila Sonia
# 94         95.0        Sao Domingos
# 95         96.0             Lajeado

# %%
df1['Distrito'] = df1['Distrito'].replace(distrito.set_index('Nr Distrito')['Nome Distrito'])

# %%
df1 = df1.drop('Bairro', axis=1)

# %%
df1.sample(10)
# Out:
#                Data de abertura            Tema
# 23301       2022-10-21 14:52:57         Animais  \
# 409417  2018-03-23 11:36:31.077         Animais
# 442654  2017-02-24 10:30:16.718         Animais
# 629980               2013-04-11             NaN
# 14386       2023-03-02 14:49:15  Pragas urbanas
# 191530      2021-04-05 21:52:39         Animais
# 64097       2022-09-19 18:02:52         Animais
# 245613      2021-02-17 14:28:04         Animais
# 528153  2015-06-19 12:33:52.723         Animais
# 80385       2022-05-12 12:07:07         Animais
#
#                                                 Assunto
# 23301   Animais que transmitem doenças ou risco à saúde  \
# 409417                    Criação inadequada de animais
# 442654  Animais que transmitem doenças ou risco à saúde
# 629980                             Animais / Pernilongo
# 14386   Animais que transmitem doenças ou risco à saúde
# 191530                      Exames, vacinas e castração
# 64097                       Exames, vacinas e castração
# 245613  Animais que transmitem doenças ou risco à saúde
# 528153                     Animal agressor e/ou invasor
# 80385                       Exames, vacinas e castração
#
#                                                   Serviço         Distrito
# 23301     Abelhas e Vespas - Solicitar vistoria em ninhos         ITAQUERA  \
# 409417         Denunciar condições inadequadas de criação       PONTE RASA
# 442654      Ratos - Solicitar vistoria em local infestado         TUCURUVI
# 629980                           Reclamação de Pernilongo    QUARTA PARADA
# 14386       Ratos - Solicitar vistoria em local infestado  JARDIM SAO LUIS
# 191530                 Castrar cães e gatos gratuitamente              NaN
# 64097                  Castrar cães e gatos gratuitamente              NaN
# 245613      Ratos - Solicitar vistoria em local infestado              NaN
# 528153  Cães e gatos invasores de instituições pública...     CIDADE DUTRA
# 80385                  Castrar cães e gatos gratuitamente              NaN
#
#          Status da solicitação          Data do parecer
# 23301               FINALIZADA      2022-11-23 14:53:58
# 409417              FINALIZADA  2018-04-06 15:09:03.573
# 442654              FINALIZADA  2017-05-05 13:31:12.919
# 629980               REALIZADA  2013-05-17 00:00:00.000
# 14386               FINALIZADA      2023-03-06 04:52:20
# 191530              FINALIZADA      2021-04-07 11:21:39
# 64097               FINALIZADA      2022-09-22 17:37:14
# 245613  AGUARDANDO ATENDIMENTO      2021-02-18 10:37:04
# 528153               CANCELADA  2015-07-23 03:00:00.000
# 80385               FINALIZADA      2022-05-13 11:37:53

# %%
df1['Distrito'].isnull().sum()
# Out:
# 232552

# %%
df1['Distrito'].notnull().sum()
# Out:
# 471808

# %% [markdown]
# ## Tratamento das descrições (Assunto, Serviço)

# %%
df2 = df1.rename({'Assunto': 'Tipo de Serviço'}, axis=1)

# %%
df2.sample()
# Out:
#                Data de abertura     Tema                Tipo de Serviço
# 375426  2019-04-30 04:33:32.130  Animais  Criação inadequada de animais  \
#
#                                            Serviço        Distrito
# 375426  Denunciar condições inadequadas de criação  ITAIM PAULISTA  \
#
#        Status da solicitação          Data do parecer
# 375426            FINALIZADA  2019-05-06 20:23:48.254

# %%
df2['Tipo de Serviço'].drop_duplicates()
# Out:
# 0                                Registro de animais - RGA
# 1                              Exames, vacinas e castração
# 3                                        Adoção de animais
# 4                            Criação inadequada de animais
# 6                                       Animais silvestres
# 9                                    Animal em via pública
# 14         Animais que transmitem doenças ou risco à saúde
# 23                            Animal agressor e/ou invasor
# 66        Dengue/chikungunya/zika (mosquito aedes aegypti)
# 26265                                  Comércio de animais
# 128038                    Animais que podem causar doenças
# 361615                                      Animais/Aranha
# 386661                                  Animais/Carrapatos
# 392961                                      Animais/Pulgas
# 397007                                      Animais/barata
# 529214                                       Animais / Cão
# 529218                                      Animais / Gato
# 529219                                     Animais / Ratos
# 529220              Animais / Abelhas, Vespas, Marimbondos
# 529226                                             Animais
# 529229                                Animais / Pernilongo
# 529237                                  Animais / Morcegos
# 529244                     Animais / Escorpiões ou Aranhas
# 529253                                    Animais / Pombos
# 529263                                Animais / Carrapatos
# 529296              Animais / Ocorrencias com outros tipos
# 529414                                   Animais / Formiga
# 529472                                   Animais / Baratas
# 529482                                    Animais / Pulgas
# 529725                                    Animais / Moscas
# 529765                                    Animais / Cavalo
# 529767                                  Vistoria / Animais
# 540659                                Animais / Escorpiões
# 540820                                   Animais / Aranhas
# Name: Tipo de Serviço, dtype: object

# %%
df2[['Tipo de Serviço', 'Serviço']].drop_duplicates()
# Out:
#                                          Tipo de Serviço
# 0                              Registro de animais - RGA  \
# 1                            Exames, vacinas e castração
# 3                                      Adoção de animais
# 4                          Criação inadequada de animais
# 6                                     Animais silvestres
# 9                                  Animal em via pública
# 12                                 Animal em via pública
# 14       Animais que transmitem doenças ou risco à saúde
# 15       Animais que transmitem doenças ou risco à saúde
# 19       Animais que transmitem doenças ou risco à saúde
# 21       Animais que transmitem doenças ou risco à saúde
# 23                          Animal agressor e/ou invasor
# 25                          Animal agressor e/ou invasor
# 66      Dengue/chikungunya/zika (mosquito aedes aegypti)
# 69       Animais que transmitem doenças ou risco à saúde
# 71                             Registro de animais - RGA
# 109                                Animal em via pública
# 227      Animais que transmitem doenças ou risco à saúde
# 501                          Exames, vacinas e castração
# 1276                           Registro de animais - RGA
# 1460                                  Animais silvestres
# 26265                                Comércio de animais
# 34365                                Comércio de animais
# 40401                                 Animais silvestres
# 46546                                 Animais silvestres
# 67423                                Comércio de animais
# 88229                                Comércio de animais
# 128038                  Animais que podem causar doenças
# 128051                  Animais que podem causar doenças
# 128056                  Animais que podem causar doenças
# 128063                  Animais que podem causar doenças
# 128068                             Animal em via pública
# 128086                  Animais que podem causar doenças
# 128122                  Animais que podem causar doenças
# 361615                                    Animais/Aranha
# 386661                                Animais/Carrapatos
# 392961                                    Animais/Pulgas
# 397007                                    Animais/barata
# 529214                                     Animais / Cão
# 529218                                    Animais / Gato
# 529219                                   Animais / Ratos
# 529220            Animais / Abelhas, Vespas, Marimbondos
# 529221                                     Animais / Cão
# 529224                                     Animais / Cão
# 529226                                           Animais
# 529229                              Animais / Pernilongo
# 529237                                Animais / Morcegos
# 529238                                    Animais / Gato
# 529240                                    Animais / Gato
# 529244                   Animais / Escorpiões ou Aranhas
# 529253                                  Animais / Pombos
# 529263                              Animais / Carrapatos
# 529269                                     Animais / Cão
# 529296            Animais / Ocorrencias com outros tipos
# 529397                                    Animais / Gato
# 529406                                    Animais / Gato
# 529414                                 Animais / Formiga
# 529472                                 Animais / Baratas
# 529482                                  Animais / Pulgas
# 529725                                  Animais / Moscas
# 529765                                  Animais / Cavalo
# 529767                                Vistoria / Animais
# 530004                                    Animais / Gato
# 530090                                  Animais / Cavalo
# 530119                                Vistoria / Animais
# 530506                                     Animais / Cão
# 534481                                Vistoria / Animais
# 536291                                Vistoria / Animais
# 540659                              Animais / Escorpiões
# 540820                                 Animais / Aranhas
# 585177                                Animais / Morcegos
# 681086                                     Animais / Cão
# 682824            Animais / Abelhas, Vespas, Marimbondos
#
#                                                   Serviço
# 0       Avisar  sobre animal encontrado com Registro G...
# 1                      Castrar cães e gatos gratuitamente
# 3                                     Adotar cães e gatos
# 4              Denunciar condições inadequadas de criação
# 6       Animais silvestres feridos ? Solicitar atendim...
# 9        Solicitar remoção de animal morto em via pública
# 12      Avaliação de animal em sofrimento sem propriet...
# 14      Pernilongo/Mosquito - Solicitar vistoria em lo...
# 15           Morcegos - Reclamar sobre local com morcegos
# 19          Ratos - Solicitar vistoria em local infestado
# 21        Abelhas e Vespas - Solicitar vistoria em ninhos
# 23          Avisar sobre animal agressor em vias públicas
# 25      Cães e gatos invasores de instituições pública...
# 66      Água limpa e parada ? Solicitar vistoria de lo...
# 69      Escorpião - Solicitar vistoria de local com es...
# 71      Registro Geral do Animal (RGA) - Solicitar ide...
# 109      Animal de grande porte solto - Solicitar remoção
# 227        Pombos - Solicitar vistoria em local infestado
# 501      Castrar cães e gatos de protetores independentes
# 1276     Registro Geral do Animal (RGA) - Atualizar dados
# 1460      Animais silvestres ? Agendar entrega voluntária
# 26265   Cadastro Municipal de Comércio de Animais (CMC...
# 34365   Cadastro Municipal de Comércio de Animais (CMC...
# 40401   Animais silvestres feridos – Solicitar atendim...
# 46546     Animais silvestres – Agendar entrega voluntária
# 67423   Cadastro Municipal de Comércio de Animais (CMC...
# 88229   Cadastro Municipal de Comércio de Animais (CMC...
# 128038  Pernilongo/Mosquito - Solicitar vistoria em lo...
# 128051      Ratos - Solicitar vistoria em local infestado
# 128056    Abelhas e Vespas - Solicitar vistoria em ninhos
# 128063       Morcegos - Reclamar sobre local com morcegos
# 128068             Remoção de animal morto em via pública
# 128086     Pombos - Solicitar vistoria em local infestado
# 128122  Escorpião - Solicitar vistoria de local com es...
# 361615                              Reclamação de Aranhas
# 386661                           Reclamação de carrapatos
# 392961                               Reclamação de pulgas
# 397007                              Reclamação de baratas
# 529214                 Condições de criação / maus tratos
# 529218                 Condições de criação / maus tratos
# 529219                                Reclamação de ratos
# 529220                         Colméia/Vespeiro instalado
# 529221   Atropelado ou Acidentado vivo e sem proprietário
# 529224                                       Cão Agressor
# 529226           Remoção de animal morto em vias publicas
# 529229                           Reclamação de Pernilongo
# 529237                            Ocorrências com morcego
# 529238                        Atropelado sem proprietário
# 529240                                   Invadiu o local
# 529244                Reclamação de Escorpiões ou Aranhas
# 529253                               Reclamação de Pombos
# 529263                           Reclamação de Carrapatos
# 529269                                    Invadiu o local
# 529296                 Ocorrências / Condições de criação
# 529397                                      Gato agressor
# 529406                        Acidentado sem proprietário
# 529414                             Reclamação de Formigas
# 529472                              Reclamação de Baratas
# 529482                               Reclamação de Pulgas
# 529725                               Reclamação de Moscas
# 529765                               Diversas ocorrências
# 529767                           Trânsito de boiadas a pé
# 530004                            Gato encontrado com RGA
# 530090                               Condições de criação
# 530119                                         Em parques
# 530506                             Cão encontrado com RGA
# 534481                  Falta de placa sobre animal feroz
# 536291                        Cães em vigilância bancária
# 540659                           Reclamação de Escorpiões
# 540820                              Reclamação de Aranhas
# 585177                             Ocorrências rotineiras
# 681086                               Solto em via pública
# 682824          Remoção de Abelhas, Vespas ou Marimbondos

# %% [markdown]
# ### Padronizar o Tipo de Serviço

# %%
df2.loc[df2['Tipo de Serviço'].str.contains('Animais[ |/]') & df2['Tipo de Serviço']
        .str.match('^(?!.*(Cão|Gato|Cavalo|silvestres|RGA|agressor|via))'), 'Tipo de Serviço'
       ] = 'Animais que transmitem doenças ou risco à saúde'

# %%
df2[['Tipo de Serviço', 'Serviço']].drop_duplicates()
# Out:
# 25      Cães e gatos invasores de instituições pública...
# 66      Água limpa e parada ? Solicitar vistoria de lo...
# 69      Escorpião - Solicitar vistoria de local com es...
# 71      Registro Geral do Animal (RGA) - Solicitar ide...
# 109      Animal de grande porte solto - Solicitar remoção
# 227        Pombos - Solicitar vistoria em local infestado
# 501      Castrar cães e gatos de protetores independentes
# 1276     Registro Geral do Animal (RGA) - Atualizar dados
# 1460      Animais silvestres ? Agendar entrega voluntária
# 26265   Cadastro Municipal de Comércio de Animais (CMC...
# 34365   Cadastro Municipal de Comércio de Animais (CMC...
# 40401   Animais silvestres feridos – Solicitar atendim...
# 46546     Animais silvestres – Agendar entrega voluntária
# 67423   Cadastro Municipal de Comércio de Animais (CMC...
# 88229   Cadastro Municipal de Comércio de Animais (CMC...
# 128068             Remoção de animal morto em via pública
# 361615                              Reclamação de Aranhas
# 386661                           Reclamação de carrapatos
# 392961                               Reclamação de pulgas
# 397007                              Reclamação de baratas
# 529214                 Condições de criação / maus tratos
# 529218                 Condições de criação / maus tratos
# 529219                                Reclamação de ratos
# 529220                         Colméia/Vespeiro instalado
# 529221   Atropelado ou Acidentado vivo e sem proprietário
# 529224                                       Cão Agressor
# 529226           Remoção de animal morto em vias publicas
# 529229                           Reclamação de Pernilongo
# 529237                            Ocorrências com morcego
# 529238                        Atropelado sem proprietário
# 529240                                   Invadiu o local
# 529244                Reclamação de Escorpiões ou Aranhas
# 529253                               Reclamação de Pombos
# 529263                           Reclamação de Carrapatos
# 529269                                    Invadiu o local
# 529296                 Ocorrências / Condições de criação
# 529397                                      Gato agressor
# 529406                        Acidentado sem proprietário
# 529414                             Reclamação de Formigas
# 529472                              Reclamação de Baratas
# 529482                               Reclamação de Pulgas
# 529725                               Reclamação de Moscas
# 529765                               Diversas ocorrências
# 529767                           Trânsito de boiadas a pé
# 530004                            Gato encontrado com RGA
# 530090                               Condições de criação
# 530119                                         Em parques
# 530506                             Cão encontrado com RGA
# 534481                  Falta de placa sobre animal feroz
# 536291                        Cães em vigilância bancária
# 540659                           Reclamação de Escorpiões
# 585177                             Ocorrências rotineiras
# 681086                               Solto em via pública
# 682824          Remoção de Abelhas, Vespas ou Marimbondos

# %%
df2['Tipo de Serviço'] = df2['Tipo de Serviço'].str.replace('Animais / ', '')

# %%
df2['Tipo de Serviço'] = df2['Tipo de Serviço'].str.replace(' / Animais', '')

# %%
df2['Tipo de Serviço'] = df2['Tipo de Serviço'].str.replace('Dengue/chikungunya/zika (mosquito aedes aegypti)', 'Vistoria')

# %%
df2['Tipo de Serviço'].drop_duplicates()
# Out:
# 0                               Registro de animais - RGA
# 1                             Exames, vacinas e castração
# 3                                       Adoção de animais
# 4                           Criação inadequada de animais
# 6                                      Animais silvestres
# 9                                   Animal em via pública
# 14        Animais que transmitem doenças ou risco à saúde
# 23                           Animal agressor e/ou invasor
# 66                                               Vistoria
# 26265                                 Comércio de animais
# 529214                                                Cão
# 529218                                               Gato
# 529226                                            Animais
# 529765                                             Cavalo
# Name: Tipo de Serviço, dtype: object

# %% [markdown]
# ### Padronizar o Serviço

# %% [markdown]
# ### Apagar os registros de teste

# %%
df2 = df2.drop(df2.loc[df1['Serviço'].str.contains('TESTE', regex=True)].index)

# %% [markdown]
# ## Gerar o arquivo com os dados necessários

# %%
df1.to_csv('sp156_all_time.csv', sep=';')
