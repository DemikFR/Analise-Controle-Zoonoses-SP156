# %% [markdown]
# # Buscar os dados necessários para a análise

# %% [markdown]
# ## Gerar o dataframe com os dados da Prefeitura

# %%
import requests
import re
from bs4 import BeautifulSoup as bs
import pandas as pd
from io import StringIO
import chardet

# %% [markdown]
# ### Criar o dataframe que conterá os dados necessários para a análise

# %%
df = pd.DataFrame()

# %% [markdown]
# ### Função para buscar os caminhos para o download de cada dataset

# %%
def get_soup(url, search):
    response = requests.get(url)
    
    # Verificar se a conexão foi bem sucedida
    if response.status_code == 200:
        soup = bs(response.content, 'html.parser')

        # Retornar as páginas onde terão as de download
        return soup.find_all('a', href=True, attrs={'title': re.compile(search)}) 
    else:
        return f'Página{link["title"]} está inacessível. Código: {response.status_code}'

# %% [markdown]
# ### Código para inserir os dados em um dataframe

# %%
# URL base do site da Prefeitura
url_base = 'http://dados.prefeitura.sp.gov.br'

# URL inicial onde estarão os links para os datasets
url_inicial = 'http://dados.prefeitura.sp.gov.br/dataset/dados-do-sp156'

# extensão do dataset para filtrar
file_type = '.csv'

for link in get_soup(url_inicial, r'^Dados do SP156 -.*'):
    
    # Pegar o link de download
    for page in get_soup(url_base+link['href'], r'^http://dados.prefeitura.sp.gov.br/dataset/.*'):
        link_download = page['href']
        
        # Verificar se é o arquivo a ser baixado é Excel
        if file_type in link_download:
            
            # Pegar o conteúdo do CSV
            response_csv = requests.get(page['href'])
            
            # Cada datset tem um encoding diferente, por isso foi necessário usar a biblioteca chardet para identificar 
            # automaticamente qual é.
            encoding = chardet.detect(response_csv.content)['encoding']
            
            # Colocar os dados na tabela auxiliar
            if int(link["title"][-4:]) >= 2021:
                df3 = pd.read_csv(StringIO(response_csv.content.decode(encoding)), sep=';', encoding=encoding, low_memory=False)
            else:
                df3 = pd.read_csv(StringIO(response_csv.content.decode(encoding)), sep=',', encoding=encoding, low_memory=False)
            
            # Inserir os dados na planilha original
            df = pd.concat([df, df3], ignore_index=True)
            print(f'Os dados do {link["title"]} foram inseridos com sucesso.')

# %%
df
# Out:
#                  Data de abertura               Canal
# 0             2022-12-31 21:07:05  CENTRAL TELEFÔNICA  \
# 1             2022-12-31 21:13:26  CENTRAL TELEFÔNICA
# 2             2022-12-31 21:15:16  CENTRAL TELEFÔNICA
# 3             2022-12-31 21:16:08  CENTRAL TELEFÔNICA
# 4             2022-12-31 21:22:07  CENTRAL TELEFÔNICA
# ...                           ...                 ...
# 13688535  2012-06-30 23:48:36.770                 NaN
# 13688536  2012-06-30 23:49:06.000                 NaN
# 13688537  2012-06-30 23:50:58.493                 NaN
# 13688538  2012-06-30 23:52:49.217                 NaN
# 13688539  2012-06-30 23:58:07.427                 NaN
#
#                                     Tema
# 0         Cidadania e assistência social  \
# 1         Cidadania e assistência social
# 2         Cidadania e assistência social
# 3         Cidadania e assistência social
# 4         Cidadania e assistência social
# ...                                  ...
# 13688535                             NaN
# 13688536                             NaN
# 13688537                             NaN
# 13688538                             NaN
# 13688539                             NaN
#
#                                            Assunto
# 0           População ou pessoa em situação de rua  \
# 1           População ou pessoa em situação de rua
# 2           População ou pessoa em situação de rua
# 3           População ou pessoa em situação de rua
# 4           População ou pessoa em situação de rua
# ...                                            ...
# 13688535    População ou Pessoa em Situação de Rua
# 13688536  Iluminacao - Lampada acesa durante o dia
# 13688537   Transporte publico / Linha e Itinerário
# 13688538    População ou Pessoa em Situação de Rua
# 13688539   Transporte publico / Linha e Itinerário
#
#                                                     Serviço Logradouro
# 0         Pessoa em situação de rua ? Solicitar atendime...        NaN  \
# 1         Pessoa em situação de rua ? Solicitar atendime...        NaN
# 2         Pessoa em situação de rua ? Solicitar atendime...        NaN
# 3         Pessoa em situação de rua ? Solicitar atendime...        NaN
# 4         Pessoa em situação de rua ? Solicitar atendime...        NaN
# ...                                                     ...        ...
# 13688535                                                NaN        NaN
# 13688536                                                NaN        NaN
# 13688537                                                NaN        NaN
# 13688538                                                NaN        NaN
# 13688539                                                NaN        NaN
#
#           Número  CEP Subprefeitura Distrito  ...
# 0            NaN  NaN           NaN      NaN  ...  \
# 1            NaN  NaN           NaN      NaN  ...
# 2            NaN  NaN         MOOCA    BELEM  ...
# 3            NaN  NaN            SE       SE  ...
# 4            NaN  NaN           NaN      NaN  ...
# ...          ...  ...           ...      ...  ...
# 13688535     NaN  NaN           NaN      NaN  ...
# 13688536     NaN  NaN           NaN      5.0  ...
# 13688537     NaN  NaN           NaN     48.0  ...
# 13688538     NaN  NaN           NaN     20.0  ...
# 13688539     NaN  NaN           NaN      NaN  ...
#
#           De modo geral, qual o seu nível de satisfação com o serviço prestado?
# 0                                                       NaN                      \
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 13688535                                                NaN
# 13688536                                                NaN
# 13688537                                                NaN
# 13688538                                                NaN
# 13688539                                                NaN
#
#           Prazo de atendimento Qualidade do serviço
# 0                          NaN                  NaN  \
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# ...                        ...                  ...
# 13688535                   NaN                  NaN
# 13688536                   NaN                  NaN
# 13688537                   NaN                  NaN
# 13688538                   NaN                  NaN
# 13688539                   NaN                  NaN
#
#          A Prefeitura atendeu a sua solicitação?
# 0                                            NaN  \
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 13688535                                     NaN
# 13688536                                     NaN
# 13688537                                     NaN
# 13688538                                     NaN
# 13688539                                     NaN
#
#          Compreensão da resposta recebida Cep Unnamed: 23
# 0                                     NaN NaN         NaN  \
# 1                                     NaN NaN         NaN
# 2                                     NaN NaN         NaN
# 3                                     NaN NaN         NaN
# 4                                     NaN NaN         NaN
# ...                                   ...  ..         ...
# 13688535                              NaN NaN         NaN
# 13688536                              NaN NaN         NaN
# 13688537                              NaN NaN         NaN
# 13688538                              NaN NaN         NaN
# 13688539                              NaN NaN         NaN
#
#          Canal de atendimento                      Especificação do assunto
# 0                         NaN                                           NaN  \
# 1                         NaN                                           NaN
# 2                         NaN                                           NaN
# 3                         NaN                                           NaN
# 4                         NaN                                           NaN
# ...                       ...                                           ...
# 13688535                  SAC  Abordagem social a Pessoa em Situação de Rua
# 13688536                  SAC      Iluminacao - Lampada acesa durante o dia
# 13688537          Central 156                Programação horária inadequada
# 13688538                  SAC  Abordagem social a Pessoa em Situação de Rua
# 13688539          Central 156             Pedido de alteração de itinerário
#
#                       Bairro
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 13688535      JARDIM JARAGUA
# 13688536             VILA RE
# 13688537         AGUA BRANCA
# 13688538  CHACARA CALIFORNIA
# 13688539         AGUA BRANCA
#
# [13688540 rows x 33 columns]

# %% [markdown]
# ## Manter apenas os dados e campos necessários

# %%
df = df[['Data de abertura', 'Tema', 'Assunto', 'Especificação do assunto', 'Serviço', 'Bairro', 'Distrito'
         , 'Status da solicitação', 'Data do parecer']]

# %%
df = df[df['Assunto'].str.contains('Animais', regex=False) | df['Tema'].str.contains(r'^Anim.*', regex=True)].reset_index(
    drop=True)

# %%
df.sample(20)
# Out:
#                Data de abertura     Tema
# 52299   2020-09-17 20:39:00.971  Animais  \
# 180895  2017-02-20 19:23:56.245  Animais
# 193620  2016-01-11 10:36:56.637  Animais
# 149729  2018-04-07 11:20:45.877  Animais
# 436902  2012-05-19 11:11:11.023      NaN
# 118015  2019-06-05 15:55:02.335  Animais
# 383407  2012-07-25 09:59:07.083      NaN
# 199373  2016-02-13 15:13:44.133  Animais
# 101548  2019-01-18 18:30:39.845  Animais
# 82171   2019-08-09 16:15:04.514  Animais
# 183583  2017-03-17 13:07:47.084  Animais
# 414834  2012-02-01 19:50:10.567      NaN
# 183925  2017-03-21 13:46:31.452  Animais
# 335790               2013-10-07      NaN
# 311574               2014-03-31      NaN
# 296006               2014-01-14      NaN
# 198736  2016-02-10 11:18:40.720  Animais
# 334880               2013-09-30      NaN
# 75515   2020-06-16 16:10:24.653  Animais
# 160324  2017-08-27 13:36:02.060  Animais
#
#                                                 Assunto
# 52299                       Exames, vacinas e castração  \
# 180895  Animais que transmitem doenças ou risco à saúde
# 193620                            Animal em via pública
# 149729                    Criação inadequada de animais
# 436902                                 Animais / Pombos
# 118015                            Animal em via pública
# 383407                                    Animais / Cão
# 199373  Animais que transmitem doenças ou risco à saúde
# 101548                            Animal em via pública
# 82171   Animais que transmitem doenças ou risco à saúde
# 183583  Animais que transmitem doenças ou risco à saúde
# 414834                                    Animais / Cão
# 183925                    Criação inadequada de animais
# 335790           Animais / Ocorrencias com outros tipos
# 311574                                    Animais / Cão
# 296006           Animais / Abelhas, Vespas, Marimbondos
# 198736  Animais que transmitem doenças ou risco à saúde
# 334880                                    Animais / Cão
# 75515                       Exames, vacinas e castração
# 160324                            Animal em via pública
#
#                                 Especificação do assunto
# 52299                                                NaN  \
# 180895                                               NaN
# 193620                                               NaN
# 149729                                               NaN
# 436902                              Reclamação de Pombos
# 118015                                               NaN
# 383407  Atropelado ou Acidentado vivo e sem proprietário
# 199373                                               NaN
# 101548                                               NaN
# 82171                                                NaN
# 183583                                               NaN
# 414834                                   Invadiu o local
# 183925                                               NaN
# 335790                Ocorrências / Condições de criação
# 311574                Condições de criação / maus tratos
# 296006                        Colméia/Vespeiro instalado
# 198736                                               NaN
# 334880  Atropelado ou Acidentado vivo e sem proprietário
# 75515                                                NaN
# 160324                                               NaN
#
#                                                   Serviço
# 52299                  Castrar cães e gatos gratuitamente  \
# 180895    Abelhas e Vespas - Solicitar vistoria em ninhos
# 193620  Avaliação de animal em sofrimento sem propriet...
# 149729         Denunciar condições inadequadas de criação
# 436902                                                NaN
# 118015  Avaliação de animal em sofrimento sem propriet...
# 383407                                                NaN
# 199373    Abelhas e Vespas - Solicitar vistoria em ninhos
# 101548   Solicitar remoção de animal morto em via pública
# 82171     Abelhas e Vespas - Solicitar vistoria em ninhos
# 183583  Pernilongo/Mosquito - Solicitar vistoria em lo...
# 414834                                                NaN
# 183925         Denunciar condições inadequadas de criação
# 335790                                                NaN
# 311574                                                NaN
# 296006                                                NaN
# 198736    Abelhas e Vespas - Solicitar vistoria em ninhos
# 334880                                                NaN
# 75515                  Castrar cães e gatos gratuitamente
# 160324   Solicitar remoção de animal morto em via pública
#
#                                   Bairro       Distrito Status da solicitação
# 52299                                NaN            NaN            INDEFERIDO  \
# 180895                               NaN  JARDIM HELENA            FINALIZADA
# 193620                               NaN    CAMPO LIMPO            FINALIZADA
# 149729                               NaN       ITAQUERA            FINALIZADA
# 436902  CONJUNTO RESIDENCIAL VISTA VERDE           64.0             REALIZADA
# 118015                               NaN          SAUDE            FINALIZADA
# 383407                  LAUZANE PAULISTA           51.0             CANCELADA
# 199373                               NaN     ARICANDUVA            FINALIZADA
# 101548                               NaN     ITAIM BIBI            FINALIZADA
# 82171                                NaN          MOEMA            FINALIZADA
# 183583                               NaN       IPIRANGA            FINALIZADA
# 414834                     JARDIM SORAIA           19.0             CANCELADA
# 183925                               NaN      SAPOPEMBA            FINALIZADA
# 335790                PRAIAS PAULISTANAS            NaN             REALIZADA
# 311574                               NaN            NaN             REALIZADA
# 296006                           TATUAPE            NaN             REALIZADA
# 198736                               NaN     ITAIM BIBI            FINALIZADA
# 334880                         LIBERDADE            NaN             REALIZADA
# 75515                                NaN            NaN            INDEFERIDO
# 160324                               NaN       TUCURUVI             CANCELADA
#
#                 Data do parecer
# 52299   2020-11-30 13:34:28.525
# 180895  2017-02-24 17:23:00.446
# 193620  2017-06-19 13:07:38.990
# 149729  2018-05-02 11:43:25.307
# 436902  2012-06-04 00:00:00.000
# 118015  2020-02-14 18:19:17.607
# 383407  2012-07-25 00:00:00.000
# 199373  2016-04-11 13:36:03.013
# 101548  2019-02-06 15:59:39.000
# 82171   2019-08-13 13:25:07.165
# 183583  2017-03-21 18:04:53.739
# 414834  2015-06-30 00:00:00.000
# 183925  2017-03-23 18:52:48.152
# 335790  2014-01-13 00:00:00.000
# 311574  2015-10-05 00:00:00.000
# 296006  2014-03-27 00:00:00.000
# 198736  2016-03-28 03:00:00.000
# 334880  2013-10-01 00:00:00.000
# 75515   2020-07-22 10:57:20.375
# 160324  2017-08-28 11:48:14.026

# %% [markdown]
# ## Gerar o arquivo com os dados necessários

# %%
df.to_csv('sp156_all_time.csv', sep=';')
