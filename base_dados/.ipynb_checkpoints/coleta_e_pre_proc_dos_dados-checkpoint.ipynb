# %% [markdown]
# # Agregando Datasets do SP196 em um Arquivo Consolidado

# %% [markdown]
# ## Aviso: Comentários resumidos neste código; consulte a  [Documentação](https://github.com/DemikFR/Analise-Controle-Zoonoses-SP156/blob/main/README.md) para obter uma compreensão mais detalhada das razões por trás de cada trecho de código.

# %% [markdown]
# ## Gerar o dataframe com os dados da Prefeitura

# %%
import requests
import re
from bs4 import BeautifulSoup as bs
import pandas as pd
from io import StringIO
import chardet

# %% [markdown]
# ### Criar o dataframe que conterá os dados necessários para a análise

# %%
df = pd.DataFrame()
dfs = []

# %% [markdown]
# ## Função para buscar os caminhos para o download de cada dataset

# %%
def get_soup(url, search):
    response = requests.get(url)
    
    # Verificar se a conexão foi bem sucedida
    if response.status_code == 200:
        soup = bs(response.content, 'html.parser')

        # Retornar as páginas onde terão as de download
        return soup.find_all('a', href=True, attrs={'title': re.compile(search)}) 
    else:
        return f'Página{link["title"]} está inacessível. Código: {response.status_code}'

# %% [markdown]
# ## Código para inserir os dados em uma lista

# %%
# URL base do site da Prefeitura
url_base = 'http://dados.prefeitura.sp.gov.br'

# URL inicial onde estarão os links para os datasets
url_inicial = 'http://dados.prefeitura.sp.gov.br/dataset/dados-do-sp156'

# extensão do dataset para filtrar
file_type = '.csv'

for link in get_soup(url_inicial, r'^Dados do SP156.*'):
    
    # Pegar o link de download
    for page in get_soup(url_base+link['href'], r'^http://dados.prefeitura.sp.gov.br/dataset/.*'):
        link_download = page['href']
        
        # Verificar se é o arquivo a ser baixado é Excel
        if file_type in link_download:
            
            # Pegar o conteúdo do CSV
            response_csv = requests.get(page['href'])
            
            # Cada datset tem um encoding diferente, por isso foi necessário usar a biblioteca chardet para identificar 
            # automaticamente qual é.
            encoding = chardet.detect(response_csv.content)['encoding']
            
            # Colocar os dados na tabela auxiliar
            if int(link["title"][-4:]) >= 2020:
                df3 = pd.read_csv(StringIO(response_csv.content.decode(encoding)), sep=';', encoding=encoding, low_memory=False)
            else:
                df3 = pd.read_csv(StringIO(response_csv.content.decode(encoding)), sep=',', encoding=encoding, low_memory=False)
                
            dfs.append(df3)  # Adicionar o DataFrame intermediário à lista
            
            # Inserir os dados na planilha original
            print(f'Os dados do {link["title"]} foram inseridos com sucesso.')
# Out:
# Os dados do Dados do SP156 - 1º TRI 2023 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 4º TRI 2022 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 3º TRI 2022 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º TRI 2022 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º TRI 2022 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 4º TRI 2021 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 3º TRI 2021 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º TRI 2021 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º TRI 2021 foram inseridos com sucesso.
# Os dados do Dados do SP156 - Dezembro - 2020 foram inseridos com sucesso.
# Os dados do Dados do SP156 - Outubro e Novembro - 2020 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 3º TRI 2020 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2020 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º SEM 2019 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2019 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º SEM 2018 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2018 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2° SEM 2017 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1° SEM 2017 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1° SEM 2016 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º SEM 2015 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2015 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2° SEM 2014 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2014 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º SEM 2013 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2013 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º SEM 2012 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2012 foram inseridos com sucesso.

# %% [markdown]
# ## Criar o dataframe com todos os datasets coletados

# %%
df = pd.concat(dfs, ignore_index=True)

# %%
df.shape
# Out:
# (13862242, 33)

# %% [markdown]
# ## Verificar todas as colunas disponibilizadas

# %%
df.any()
# Out:
# Data de abertura                                                          True
# Canal                                                                     True
# Tema                                                                      True
# Assunto                                                                   True
# Serviço                                                                   True
# Logradouro                                                                True
# Número                                                                    True
# CEP                                                                       True
# Subprefeitura                                                             True
# Distrito                                                                  True
# Setor                                                                     True
# Quadra                                                                    True
# Latitude                                                                  True
# Longitude                                                                 True
# Data do parecer                                                           True
# Status da solicitação                                                     True
# Órgão                                                                     True
# Data Avaliação Pesquisa Satisfação                                        True
# Nível Satisfação                                                          True
# Prazo de Atendimento                                                      True
# Qualidade do Serviço                                                      True
# Atendeu a Solicitação                                                     True
# Compreensão da Resposta                                                   True
# De modo geral, qual o seu nível de satisfação com o serviço prestado?     True
# Prazo de atendimento                                                      True
# Qualidade do serviço                                                      True
# A Prefeitura atendeu a sua solicitação?                                   True
# Compreensão da resposta recebida                                          True
# Cep                                                                       True
# Unnamed: 23                                                              False
# Canal de atendimento                                                      True
# Especificação do assunto                                                  True
# Bairro                                                                    True
# dtype: bool

# %% [markdown]
# ## Manter apenas os campos necessários

# %%
df = df[['Data de abertura', 'Tema', 'Assunto', 'Especificação do assunto', 'Serviço', 'Bairro', 'Distrito'
         , 'Status da solicitação', 'Data do parecer']]

# %% [markdown]
# ## Apagar registros que por terem muitos valores nulo, não servirão para a análise

# %%
df = df.dropna(thresh=4)

# %%
df[df['Data de abertura'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Data de abertura, Tema, Assunto, Especificação do assunto, Serviço, Bairro, Distrito, Status da solicitação, Data do parecer]
# Index: []

# %%
df.sample(10)
# Out:
#                  Data de abertura                            Tema
# 8043100   2019-10-14 17:13:11.669                   Bilhete Único  \
# 13387795  2012-12-05 12:14:47.640                             NaN
# 2807774       2021-12-02 16:40:00                        Finanças
# 12007270               2014-02-21                             NaN
# 849087        2022-11-23 11:08:46                        Finanças
# 10697150  2016-05-03 17:20:51.513                           Saúde
# 8604547   2019-04-06 01:22:13.245                   Bilhete Único
# 11516728  2015-06-02 21:34:38.630           Trânsito e Transporte
# 10612148  2016-03-29 12:50:25.103                         Animais
# 129992        2023-01-21 19:56:31  Cidadania e assistência social
#
#                                                     Assunto
# 8043100                            BU Estudante e Professor  \
# 13387795                                    Poluição Sonora
# 2807774                                           Senha Web
# 12007270           Transporte publico / Conduta de Trabalho
# 849087                                            Senha Web
# 10697150   Dengue/chikungunya/zika (mosquito aedes aegypti)
# 8604547                            BU Estudante e Professor
# 11516728  Ônibus - Conduta de Trabalho do Motorista, Cob...
# 10612148    Animais que transmitem doenças ou risco à saúde
# 129992               População ou pessoa em situação de rua
#
#                                 Especificação do assunto
# 8043100                                              NaN  \
# 13387795           Residencia com Atividade Profissional
# 2807774                                              NaN
# 12007270  Motorista não aguardar embarque / desembarque
# 849087                                               NaN
# 10697150                                             NaN
# 8604547                                              NaN
# 11516728                                             NaN
# 10612148                                             NaN
# 129992                                               NaN
#
#                                                     Serviço
# 8043100   Bilhete Único Estudante - Apresentação de just...  \
# 13387795                                                NaN
# 2807774   Senha Web - Desbloqueio online para MEI, Empre...
# 12007270                                                NaN
# 849087    Senha Web - Desbloqueio online para MEI, Empre...
# 10697150  Água limpa e parada – Solicitar vistoria de lo...
# 8604547   Bilhete Único Estudante ou Professor - Correçã...
# 11516728  Ônibus - Denunciar motorista por não atender a...
# 10612148      Ratos - Solicitar vistoria em local infestado
# 129992    Pessoa em situação de rua ? Solicitar atendime...
#
#                        Bairro      Distrito Status da solicitação
# 8043100                   NaN           NaN            FINALIZADA  \
# 13387795  JARDIM VILA FORMOSA           4.0             REALIZADA
# 2807774                   NaN           NaN            FINALIZADA
# 12007270      JARDIM SAO JOSE           NaN             REALIZADA
# 849087                    NaN           NaN            FINALIZADA
# 10697150                  NaN  VILA FORMOSA            FINALIZADA
# 8604547                   NaN           NaN            FINALIZADA
# 11516728                  NaN    ITAIM BIBI            FINALIZADA
# 10612148                  NaN    VILA MARIA            FINALIZADA
# 129992                    NaN           NaN            FINALIZADA
#
#                   Data do parecer
# 8043100   2019-10-15 14:08:52.506
# 13387795  2013-12-09 12:45:50.293
# 2807774       2021-12-03 16:42:10
# 12007270  2014-03-19 00:00:00.000
# 849087        2022-11-23 16:33:28
# 10697150  2016-06-16 03:00:00.000
# 8604547   2019-04-09 14:10:23.186
# 11516728  2015-06-19 16:00:00.000
# 10612148  2016-05-13 03:00:00.000
# 129992        2023-01-21 22:03:06

# %% [markdown]
# ## Filtrar apenas os dados necessários para a análise

# %%
df['Tema'].drop_duplicates()
# Out:
# 0           Cidadania e assistência social
# 5                                  Animais
# 7               Obras, imóveis e habitação
# 10                            Rua e bairro
# 34                           Meio Ambiente
# 37                          Lixo e limpeza
# 41                                Urgência
# 54                                   Saúde
# 67                     Comércio e serviços
# 95                   Trânsito e Transporte
# 151                           Causa animal
# 188           Ouvidoria Geral do Município
# 227                         Pragas urbanas
# 431                               Finanças
# 439                         Acessibilidade
# 918                          Bilhete Único
# 1272                      Segurança urbana
# 2334                 Documentos e licenças
# 2885              Cultura, esporte e lazer
# 4389                              Educação
# 8048                              Trabalho
# 334059              Descomplica São Miguel
# 596920               Canais de Atendimento
# 597569                 Prefeitura Regional
# 1044114                               4093
# 1389675                               4126
# 1548739                Baixas Temperaturas
# 1550759                               4050
# 1997106                  Serviço funerário
# 2605867                               3917
# 2605909                               4020
# 2770878                            SAC/GRC
# 4821770                               3929
# 11562002                               NaN
# Name: Tema, dtype: object

# %% [markdown]
# ### Entender o motivo de existirem nulos no 'Tema'

# %%
pd.set_option('display.max_rows', None)
df[df.Tema.isnull()]['Assunto'].drop_duplicates()
# Out:
# 11562002                             Construcao de passarelas
# 11562003                                               Buraco
# 11562004                                      Poluição Sonora
# 11562006    Placas de Nomes de Ruas, Praças e demais Logra...
# 11562008                         Iluminacao - Lampada apagada
# 11562009             Transporte publico / Conduta de Trabalho
# 11562010                              Remoção veículo/carcaça
# 11562012                                               Elogio
# 11562016                            Vistoria / Infraestrutura
# 11562019                                                Obras
# 11562020                                           Edificacao
# 11562021                                        Animais / Cão
# 11562026                                         Pavimentacao
# 11562031                      Árvore(Calçada/Passeio Público)
# 11562034                          Transporte publico / Outros
# 11562036                                       Guias/sarjetas
# 11562038        Transporte publico / Manutenção e Conservação
# 11562045                                              Calçada
# 11562061              Transporte publico / Linha e Itinerário
# 11562065                        Bueiros/galerias agua pluvial
# 11562069                   CET / Veículo com placa abandonado
# 11562072                   Transporte publico / Bilhete Unico
# 11562075    CET / Insatisfação com circulação de veículos(...
# 11562081                     Lixo / Limpeza - Coleta Seletiva
# 11562086                                              Entulho
# 11562095                                   Comercio irregular
# 11562101                                     Varrição/Limpeza
# 11562103                 Praças/Áreas Verdes/Canteiro Central
# 11562105                                        Praça Pública
# 11562108                 Ecoponto (Entulho e Grandes Objetos)
# 11562112         Processo Encerrado/Solicitacao Vistas/Cópias
# 11562115                        Denúncia sobre Poluição do Ar
# 11562117                  Capinação/Roçada de áreas vegetadas
# 11562118                              Bagulho/Grandes Objetos
# 11562120                                           Papeleiras
# 11562122                                          Feira Livre
# 11562131                                       Lixo / Limpeza
# 11562140                                     Areas municipais
# 11562142           CET / Manutenção da Sinalização Semafórica
# 11562144                                Árvore(Praça Pública)
# 11562145    Transporte publico / Terminal, Corredor e Esta...
# 11562151                              Vigilância de Alimentos
# 11562157                               Boca de Lobo - Bueiros
# 11562158                  Transporte publico / Táxi e Escolar
# 11562159                                       Animais / Gato
# 11562160                                      Animais / Ratos
# 11562165               Animais / Abelhas, Vespas, Marimbondos
# 11562172                      Dengue (Mosquito Aedes aegypti)
# 11562177                               Programa Bolsa Família
# 11562221                                             Terrenos
# 11562233            Transporte Publico / Bilhete Único Mensal
# 11562238                                              Animais
# 11562264                Transporte publico / Pontos de Parada
# 11562269                                         CET / Escola
# 11562277                                 CET / Mão de direção
# 11562280                     Lixo/Limpeza - Queixas/Denuncias
# 11562291                                 CET / Estacionamento
# 11562304    NF Paulistana (Comunicação de não conversão – ...
# 11562305                                   Saude / Informacao
# 11562339                                   CET / Fiscalização
# 11562345                                    Remoções diversas
# 11562357                                      CET / Zona Azul
# 11562358                                 Animais / Pernilongo
# 11562362                            Saude - Queixa / Denuncia
# 11562375          CET / Manutenção de sinalização de trânsito
# 11562397     Esgoto a céu aberto/imóvel particular/residência
# 11562440                                   Animais / Morcegos
# 11562465                         CET / Circulação de Pedestre
# 11562469                        CET / Conflito entre veículos
# 11562500                                                Saude
# 11562502                      Animais / Escorpiões ou Aranhas
# 11562503               Guias/rebaixamento para acessibilidade
# 11562569                                             Corregos
# 11562577                                   Vistoria / Limpeza
# 11562597                                    Vistoria / Árvore
# 11562616                                  Denúncia sobre Solo
# 11562634                                     Animais / Pombos
# 11562693             Iluminacao - Lampada acesa durante o dia
# 11562727                      Denúncia sobre Poluição da Água
# 11562731                               Obras em Vias Públicas
# 11562749                                 Animais / Carrapatos
# 11562756                                     CET / Velocidade
# 11562849                  Hidrante de Incêndio em Edificações
# 11562879                                           Leve Leite
# 11562895                                    Logradouro/imovel
# 11562956          Iluminacao - Barulho no Transformador/Chave
# 11563064                                               Árvore
# 11563097                                           Reclamação
# 11563099               Animais / Ocorrencias com outros tipos
# 11563123                             Denúncia sobre Vegetação
# 11563181                                             Vistoria
# 11563237                                  Programa Ação Jovem
# 11563246                           CET / Manutenção de placas
# 11563282                                 Vistoria / Ambiental
# 11563380                      Escadas e Rampas em Edificações
# 11563638                                    Bancos / Denúncia
# 11563644                    PEV - Ponto de Entrega Voluntária
# 11563706                                Postos de Combustível
# 11563880                          Vistoria / Mesas e Cadeiras
# 11563890                             Bolsa Família - Denúncia
# 11563953        CET / Desvio/Interdição temporária de tráfego
# 11563970           CET / Sinalização de orientação de destino
# 11563981             Iluminacao - Luminaria pendente ou caída
# 11563999                               Iluminacao - Fio caído
# 11564117                            Vistoria / Acessibilidade
# 11564126                            Roçada de Áreas vegetadas
# 11564141                     CET / Interferências no trânsito
# 11564241                        Parques Municipais / Denúncia
# 11564254                               CET / Faixa reversível
# 11564378                                Programa Renda Cidadã
# 11564420                                             Poluição
# 11564516                           Guarda Civil Metropolitana
# 11564620                                        Jogos de Azar
# 11564714                                    Animais / Formiga
# 11564746                                       CET / Semáforo
# 11564848           Lixo Limpeza Saúde - Atraso / Implantação
# 11564901                        Acesso p/ Deficientes Fisicos
# 11565136                         CET / Conduta de Funcionário
# 11565458    Água Infiltrada Afetando a Segurança da Edific...
# 11565496                                    Animais / Baratas
# 11565652                                     Animais / Pulgas
# 11565679                                            Desportos
# 11565752                                                 IPTU
# 11565771              CET / Sinalização Horizontal e Vertical
# 11565861                                      Faixas/Cartazes
# 11565958                  Ecoponto(Entulho e Grandes Objetos)
# 11565973    Locais de Reunião - Lotação Superior a 500 Pes...
# 11566438                                             Transito
# 11567123          Produtos Químicos Perigosos nas Edificações
# 11567329                        Centro de Controle de Doenças
# 11567342                           Iluminacao - Fio faiscando
# 11567415                  Saídas de Emergência em Edificações
# 11567588                                 Vistoria / Tabagismo
# 11567924                              Renda Mínima - Denúncia
# 11567936                                               Idosos
# 11568115                                             Sugestão
# 11568254                           Vistoria / Estacionamentos
# 11568687        Brigada de Combate a Incêndios em Edificações
# 11569149                                Programa Renda Mínima
# 11569175    Transporte publico / Terminal, Corredor e Estação
# 11569321                                     Pintura de guias
# 11569331                                     Animais / Moscas
# 11569377                                    Pintura de Postes
# 11569485                  Extintor de Incêndio em Edificações
# 11569813                                       Vistoria / Gás
# 11569834     Comercialização Irregular de Fogos de Artifícios
# 11569891      Elevador de Passageiro/Carga,Escada Rolante Etc
# 11569904                                     Animais / Cavalo
# 11569926                                   Vistoria / Animais
# 11570166                Iluminacao - Poste metalico abalroado
# 11570644    Instalações Elétricas Precárias - Nas Edificações
# 11571113                           Programa Social - Denuncia
# 11571839                              Agente Jovem - Denúncia
# 11572953    Transporte publico / Portador  Mobilidade Redu...
# 11573383             Iluminação de Emergência nas Edificações
# 11574085                    Alarme de Incêndio em edificações
# 11575748                                          Funcionario
# 11575776                    Portas Corta-Fogo nas Edificações
# 11576833    PROGRAMA NOTA FISCAL PAULISTANA - N.F. DE SERV...
# 11577093                                       BPC - Denúncia
# 11577221                                   Lixo-Limpeza Saúde
# 11577867                        Alistamento e Serviço Militar
# 11577871    Instalações de Gás (GLP ou NATURAL) na Edificação
# 11577912                                   Lixo Limpeza Ruído
# 11577939                                    Servico funerario
# 11578200    Dific. de  estacionamento - pessoas c/deficiencia
# 11580247                      CET / Fiscalização (Emergência)
# 11580440     Sinalização de Emergência/Incêndio em Edificação
# 11581051               População ou Pessoa em Situação de Rua
# 11581798                              Renda Cidadã - Denúncia
# 11587554                     CET / Emergências de Alagamentos
# 11588868    Comercialização irregular de substâncias inala...
# 11592747                                              Merenda
# 11593728    Vigilância Sanitária de Produtos de Interesse ...
# 11598139                                                Praça
# 11601583                                 Pintura de Floreiras
# 11608160    Chuveiro Automático de Combate ao Fogo (Sprink...
# 11623164                            Pára-Raios em Edificações
# 11635380                                     Atendimento - SF
# 11656181                                                  PPI
# 11664554                                                  CCM
# 11668410                                Ação Jovem - Denúncia
# 11727910                                 Animais / Escorpiões
# 11729798                                    Animais / Aranhas
# 11849344                                                  ISS
# 11887504     Dengue/Chikungunya/Zika (Mosquito Aedes aegypti)
# 11906357                            Guarda-Volumes nos bancos
# 12049041                                     PETI - Denúncias
# 12299724     Lixeira em Prédio Residencial e Outros Edifícios
# 12299961      Recente Ocorrência de Desabamento em Edificação
# 12300208                                Feira livre / Sacolao
# 12301967            Problemas com as Estruturas da Edificação
# 12343194         Recente Ocorrência de Incêndio em Edificação
# 12375553         Recente Ocorrência de Explosão em Edificação
# 12674144                        Jardinagem (poda, corte mato)
# 12676284    Mananciais-Oper.Defesa Águas/Áreas Verdes-Denú...
# 13108797                                      Permissionárias
# 13445489        Iluminacao - Novo ponto de Iluminacao Publica
# 13477096                                        Meio Ambiente
# 13480166                    CET / Cancelamento de Ocorrências
# 13712536                Central de Atendimento Telefonico 156
# Name: Assunto, dtype: object

# %% [markdown]
# ### O campo 'Tema' só é usado em datasets mais recentes, por isso deve-se utilizar o campo 'Assunto' para filtrar

# %%
df1 = df[df['Assunto'].str.contains('Animais', regex=False) | df['Tema'].str.contains(r'^Anim.*|^Pragas.*', regex=True)].reset_index(drop=True)

# %%
df1.shape
# Out:
# (704360, 9)

# %%
df1.sample(20)
# Out:
#                Data de abertura            Tema
# 44820       2022-07-16 12:51:51         Animais  \
# 493908  2015-11-17 13:48:54.093         Animais
# 100165      2022-01-11 10:56:38         Animais
# 415737  2018-05-30 15:05:50.160         Animais
# 262217      2020-12-03 00:49:34         Animais
# 116641      2022-02-22 10:58:39         Animais
# 89519       2022-06-11 18:11:25         Animais
# 444607  2017-03-15 16:01:02.347         Animais
# 687785  2012-03-23 13:43:28.673             NaN
# 11707       2023-02-08 05:31:32  Pragas urbanas
# 503689  2015-01-13 14:34:45.150         Animais
# 636045               2013-05-17             NaN
# 377339  2019-05-16 12:54:22.029         Animais
# 578306               2014-04-29             NaN
# 501666  2015-01-05 12:30:25.167         Animais
# 281749      2020-11-05 21:46:03         Animais
# 381858  2018-07-05 18:29:02.763         Animais
# 602072               2013-11-14             NaN
# 494614  2015-11-22 00:04:14.150         Animais
# 540512               2014-10-08             NaN
#
#                                                  Assunto
# 44820    Animais que transmitem doenças ou risco à saúde  \
# 493908                     Criação inadequada de animais
# 100165                         Registro de animais - RGA
# 415737   Animais que transmitem doenças ou risco à saúde
# 262217                       Exames, vacinas e castração
# 116641   Animais que transmitem doenças ou risco à saúde
# 89519                        Exames, vacinas e castração
# 444607   Animais que transmitem doenças ou risco à saúde
# 687785                                     Animais / Cão
# 11707   Dengue/chikungunya/zika (mosquito aedes aegypti)
# 503689   Animais que transmitem doenças ou risco à saúde
# 636045            Animais / Abelhas, Vespas, Marimbondos
# 377339   Animais que transmitem doenças ou risco à saúde
# 578306                                   Animais / Ratos
# 501666   Animais que transmitem doenças ou risco à saúde
# 281749                       Exames, vacinas e castração
# 381858   Animais que transmitem doenças ou risco à saúde
# 602072            Animais / Abelhas, Vespas, Marimbondos
# 494614                             Animal em via pública
# 540512            Animais / Abelhas, Vespas, Marimbondos
#
#                                 Especificação do assunto
# 44820                                                NaN  \
# 493908                                               NaN
# 100165                                               NaN
# 415737                                               NaN
# 262217                                               NaN
# 116641                                               NaN
# 89519                                                NaN
# 444607                                               NaN
# 687785  Atropelado ou Acidentado vivo e sem proprietário
# 11707                                                NaN
# 503689                                               NaN
# 636045                        Colméia/Vespeiro instalado
# 377339                                               NaN
# 578306                               Reclamação de ratos
# 501666                                               NaN
# 281749                                               NaN
# 381858                                               NaN
# 602072                        Colméia/Vespeiro instalado
# 494614                                               NaN
# 540512                        Colméia/Vespeiro instalado
#
#                                                   Serviço           Bairro
# 44820     Abelhas e Vespas - Solicitar vistoria em ninhos              NaN  \
# 493908         Denunciar condições inadequadas de criação              NaN
# 100165  Registro Geral do Animal (RGA) - Solicitar ide...              NaN
# 415737  Pernilongo/Mosquito - Solicitar vistoria em lo...              NaN
# 262217                 Castrar cães e gatos gratuitamente              NaN
# 116641      Ratos - Solicitar vistoria em local infestado              NaN
# 89519                  Castrar cães e gatos gratuitamente              NaN
# 444607      Ratos - Solicitar vistoria em local infestado              NaN
# 687785                                                NaN   JARDIM LETICIA
# 11707   Água limpa e parada ? Solicitar vistoria de lo...              NaN
# 503689      Ratos - Solicitar vistoria em local infestado              NaN
# 636045                                                NaN    JARDIM GUANCA
# 377339  Escorpião - Solicitar vistoria de local com es...              NaN
# 578306                                                NaN          TATUAPE
# 501666      Ratos - Solicitar vistoria em local infestado              NaN
# 281749                 Castrar cães e gatos gratuitamente              NaN
# 381858      Ratos - Solicitar vistoria em local infestado              NaN
# 602072                                                NaN  PARQUE MANDAQUI
# 494614  Avaliação de animal em sofrimento sem propriet...              NaN
# 540512                                                NaN    JARDIM ROMANO
#
#                   Distrito Status da solicitação          Data do parecer
# 44820       JOSE BONIFACIO            FINALIZADA      2022-08-09 13:58:10
# 493908             SANTANA            FINALIZADA  2015-11-26 14:33:02.187
# 100165                 NaN            INDEFERIDO      2022-02-04 15:26:11
# 415737  ERMELINO MATARAZZO            FINALIZADA  2018-06-19 13:20:27.439
# 262217                 NaN            INDEFERIDO      2021-01-09 21:43:28
# 116641           JABAQUARA            FINALIZADO      2022-02-25 15:21:04
# 89519                  NaN            INDEFERIDO      2022-06-23 16:41:46
# 444607       CIDADE ADEMAR            FINALIZADA  2017-04-12 13:38:54.730
# 687785                 NaN             REALIZADA  2012-03-23 00:00:00.000
# 11707                BELEM            FINALIZADA      2023-03-01 08:00:20
# 503689       VILA MEDEIROS            FINALIZADA  2015-04-02 03:00:00.000
# 636045                 NaN             REALIZADA  2013-08-08 00:00:00.000
# 377339               SAUDE            FINALIZADA  2019-05-29 20:28:39.179
# 578306                 NaN             REALIZADA  2015-03-23 00:00:00.000
# 501666            TUCURUVI             CANCELADA  2016-08-17 13:31:52.020
# 281749                 NaN            FINALIZADA      2020-11-23 14:31:29
# 381858  ERMELINO MATARAZZO            FINALIZADA  2018-09-03 14:47:22.565
# 602072                 NaN             REALIZADA  2013-11-19 00:00:00.000
# 494614            TREMEMBE            FINALIZADA  2017-06-13 12:39:29.990
# 540512                 NaN             REALIZADA  2014-10-27 00:00:00.000

# %% [markdown]
# ## Padronizar o campo 'Serviço' com o 'Especificação do assunto'

# %% [markdown]
# #### Os dois campos possuem o mesmo objetivo

# %%
df1.loc[df1['Serviço'].isnull(), 'Serviço'] = df1.loc[df1['Serviço'].isnull(), 'Especificação do assunto']

# %%
df1.sample(10)
# Out:
#                Data de abertura     Tema
# 257351      2021-03-20 19:00:05  Animais  \
# 346336  2019-09-11 15:14:39.602  Animais
# 465511  2016-03-16 17:46:55.603  Animais
# 420894  2017-08-15 17:42:45.955  Animais
# 308408      2020-09-03 14:13:00  Animais
# 280678      2020-11-03 00:15:36  Animais
# 364068  2019-01-28 11:10:00.318  Animais
# 223111      2021-06-24 13:28:09  Animais
# 170203      2021-08-04 15:38:04  Animais
# 234072      2021-01-20 12:57:33  Animais
#
#                                                 Assunto
# 257351                      Exames, vacinas e castração  \
# 346336  Animais que transmitem doenças ou risco à saúde
# 465511  Animais que transmitem doenças ou risco à saúde
# 420894  Animais que transmitem doenças ou risco à saúde
# 308408                      Exames, vacinas e castração
# 280678                      Exames, vacinas e castração
# 364068  Animais que transmitem doenças ou risco à saúde
# 223111                      Exames, vacinas e castração
# 170203                      Exames, vacinas e castração
# 234072                      Exames, vacinas e castração
#
#        Especificação do assunto
# 257351                      NaN  \
# 346336                      NaN
# 465511                      NaN
# 420894                      NaN
# 308408                      NaN
# 280678                      NaN
# 364068                      NaN
# 223111                      NaN
# 170203                      NaN
# 234072                      NaN
#
#                                                   Serviço Bairro
# 257351                 Castrar cães e gatos gratuitamente    NaN  \
# 346336    Abelhas e Vespas - Solicitar vistoria em ninhos    NaN
# 465511  Pernilongo/Mosquito - Solicitar vistoria em lo...    NaN
# 420894       Morcegos - Reclamar sobre local com morcegos    NaN
# 308408                 Castrar cães e gatos gratuitamente    NaN
# 280678                 Castrar cães e gatos gratuitamente    NaN
# 364068      Ratos - Solicitar vistoria em local infestado    NaN
# 223111                 Castrar cães e gatos gratuitamente    NaN
# 170203                 Castrar cães e gatos gratuitamente    NaN
# 234072                 Castrar cães e gatos gratuitamente    NaN
#
#                Distrito Status da solicitação          Data do parecer
# 257351              NaN            FINALIZADA      2021-03-29 11:38:28
# 346336           SACOMA            FINALIZADA  2020-03-18 15:06:31.026
# 465511  JARDIM PAULISTA            FINALIZADA  2016-08-09 03:00:00.000
# 420894          SANTANA            FINALIZADA  2017-08-17 14:39:46.743
# 308408              NaN            FINALIZADA      2020-10-20 13:42:08
# 280678              NaN            FINALIZADA      2020-12-09 14:42:04
# 364068          SOCORRO            FINALIZADA  2019-02-26 16:18:05.166
# 223111              NaN            FINALIZADA      2021-06-30 11:51:03
# 170203              NaN            FINALIZADA      2021-08-19 16:48:54
# 234072              NaN            FINALIZADA      2021-01-20 13:22:06

# %%
df1[df1['Serviço'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Data de abertura, Tema, Assunto, Especificação do assunto, Serviço, Bairro, Distrito, Status da solicitação, Data do parecer]
# Index: []

# %% [markdown]
# #### Deletar o campo que não terá mais utilidade

# %%
df1 = df1.drop('Especificação do assunto', axis=1)

# %% [markdown]
# ## Tratamento dos campos de localização

# %% [markdown]
# #### Os campos 'Bairro' e 'Distrito' são ambíguos, por isso que os valores que estão nulos em 'Distrito' receberão o valor de 'Bairro', caso exista. Além disso, o campo 'Distrito' existe alguns que são número, indicando um distrito que está na metadado disponibilizado neste repositório.

# %% [markdown]
# ### Converter os valores que estão em código para o seu nome original

# %%
distrito = pd.read_csv('codigos_de_distritos.csv', sep=';')

# %%
distrito['Nr Distrito'] = distrito['Nr Distrito'].astype(float)

# %%
distrito
# Out:
#     Nr Distrito       Nome Distrito
# 0           1.0           Agua Rasa
# 1           2.0   Alto de Pinheiros
# 2           3.0          Anhanguera
# 3           4.0          Aricanduva
# 4           5.0         Artur Alvim
# 5           6.0         Barra Funda
# 6           7.0          Bela Vista
# 7           8.0               Belem
# 8           9.0          Bom Retiro
# 9          10.0                Bras
# 10         11.0         Brasilandia
# 11         12.0             Butanta
# 12         13.0        Cachoeirinha
# 13         14.0             Cambuci
# 14         15.0          Campo Belo
# 15         16.0        Campo Grande
# 16         17.0         Campo Limpo
# 17         18.0            Cangaiba
# 18         19.0       Capao Redondo
# 19         20.0              Carrao
# 20         21.0          Casa Verde
# 21         22.0       Cidade Ademar
# 22         23.0        Cidade Dutra
# 23         24.0        Cidade Lider
# 24         25.0   Cidade Tiradentes
# 25         26.0          Consolacao
# 26         27.0             Cursino
# 27         28.0  Ermelino Matarazzo
# 28         29.0      Freguesia Do O
# 29         30.0              Grajau
# 30         31.0          Guaianases
# 31         32.0               Moema
# 32         33.0            Iguatemi
# 33         34.0            Ipiranga
# 34         35.0          Itaim Bibi
# 35         36.0      Itaim Paulista
# 36         37.0            Itaquera
# 37         38.0           Jabaquara
# 38         39.0              Jacana
# 39         40.0             Jaguara
# 40         41.0             Jaguare
# 41         42.0             Jaragua
# 42         43.0       Jardim Angela
# 43         44.0       Jardim Helena
# 44         45.0     Jardim Paulista
# 45         46.0     Jardim Sao Luis
# 46         47.0      Jose Bonifacio
# 47         48.0                Lapa
# 48         49.0           Liberdade
# 49         50.0               Limao
# 50         51.0            Mandaqui
# 51         52.0            Marsilac
# 52         53.0               Mooca
# 53         54.0             Morumbi
# 54         55.0         Parelheiros
# 55         56.0                Pari
# 56         57.0     Parque Do Carmo
# 57         58.0            Pedreira
# 58         59.0               Penha
# 59         60.0            Perdizes
# 60         61.0               Perus
# 61         62.0           Pinheiros
# 62         63.0            Pirituba
# 63         64.0          Ponte Rasa
# 64         65.0      Raposo Tavares
# 65         66.0           Republica
# 66         67.0         Rio Pequeno
# 67         68.0              Sacoma
# 68         69.0       Santa Cecilia
# 69         70.0             Santana
# 70         71.0         Santo Amaro
# 71         72.0           Sao Lucas
# 72         73.0          Sao Mateus
# 73         74.0          Sao Miguel
# 74         75.0          Sao Rafael
# 75         76.0           Sapopemba
# 76         77.0               Saude
# 77         78.0                  Se
# 78         79.0             Socorro
# 79         80.0             Tatuape
# 80         81.0            Tremembe
# 81         82.0            Tucuruvi
# 82         83.0        Vila Andrade
# 83         84.0         Vila Curuca
# 84         85.0        Vila Formosa
# 85         86.0      Vila Guilherme
# 86         87.0          Vila Jacui
# 87         88.0     Vila Leopoldina
# 88         89.0          Vila Maria
# 89         90.0        Vila Mariana
# 90         91.0        Vila Matilde
# 91         92.0       Vila Medeiros
# 92         93.0       Vila Prudente
# 93         94.0          Vila Sonia
# 94         95.0        Sao Domingos
# 95         96.0             Lajeado

# %%
df1['Distrito'] = df1['Distrito'].replace(distrito.set_index('Nr Distrito')['Nome Distrito'])

# %% [markdown]
# ### Preencher valores de 'Distrito' com o de 'Bairro'

# %%
df1.loc[df1['Distrito'].isnull() & df1['Bairro'].notnull(), 'Distrito'] = df1.loc[df1['Distrito'].isnull() & df1['Bairro'].notnull(), 'Bairro']

# %%
df1.sample(10)
# Out:
#                Data de abertura     Tema
# 571107               2014-03-21      NaN  \
# 27482       2022-11-07 23:38:43  Animais
# 658311  2012-10-26 23:20:14.147      NaN
# 165278      2021-07-21 10:37:21  Animais
# 344956  2019-08-27 14:37:19.067  Animais
# 318372      2020-09-30 15:53:28  Animais
# 504108  2015-01-15 12:07:50.497  Animais
# 220366      2021-06-17 13:11:53  Animais
# 324264      2020-02-03 09:35:33  Animais
# 373329  2019-04-15 05:56:51.836  Animais
#
#                                                 Assunto
# 571107           Animais / Abelhas, Vespas, Marimbondos  \
# 27482                       Exames, vacinas e castração
# 658311                                    Animais / Cão
# 165278                      Exames, vacinas e castração
# 344956  Animais que transmitem doenças ou risco à saúde
# 318372                      Exames, vacinas e castração
# 504108  Animais que transmitem doenças ou risco à saúde
# 220366                    Criação inadequada de animais
# 324264                     Animal agressor e/ou invasor
# 373329  Animais que transmitem doenças ou risco à saúde
#
#                                                   Serviço             Bairro
# 571107                         Colméia/Vespeiro instalado  JARDIM PAULISTANO  \
# 27482                  Castrar cães e gatos gratuitamente                NaN
# 658311                                       Cão Agressor           TUCURUVI
# 165278                 Castrar cães e gatos gratuitamente                NaN
# 344956      Ratos - Solicitar vistoria em local infestado                NaN
# 318372                 Castrar cães e gatos gratuitamente                NaN
# 504108    Abelhas e Vespas - Solicitar vistoria em ninhos                NaN
# 220366         Denunciar condições inadequadas de criação                NaN
# 324264      Avisar sobre animal agressor em vias públicas                NaN
# 373329  Pernilongo/Mosquito - Solicitar vistoria em lo...                NaN
#
#                  Distrito Status da solicitação          Data do parecer
# 571107  JARDIM PAULISTANO             REALIZADA  2014-07-21 00:00:00.000
# 27482                 NaN            FINALIZADA      2022-11-09 08:22:31
# 658311       Vila Andrade             REALIZADA  2013-03-22 09:55:10.440
# 165278                NaN            FINALIZADA      2021-07-22 13:42:15
# 344956      VILA MEDEIROS            FINALIZADA  2019-10-03 13:30:41.379
# 318372                NaN            FINALIZADA      2020-10-19 21:23:31
# 504108       CIDADE DUTRA            FINALIZADA  2015-01-23 02:00:00.000
# 220366          JABAQUARA            FINALIZADA      2021-06-23 14:28:11
# 324264             GRAJAU            FINALIZADA      2020-02-18 17:31:05
# 373329      CAPAO REDONDO            FINALIZADA  2019-04-18 20:40:02.131

# %%
df1 = df1.drop('Bairro', axis=1)

# %%
df1.sample(10)
# Out:
#                Data de abertura     Tema
# 525575  2015-05-27 13:34:53.110  Animais  \
# 120283      2022-03-06 12:50:01  Animais
# 565531               2014-02-21      NaN
# 265133      2020-12-11 20:46:46  Animais
# 335449      2020-06-09 15:13:59  Animais
# 307244      2020-08-30 21:09:33  Animais
# 681548  2012-02-26 22:55:37.200      NaN
# 645313  2012-07-30 12:27:57.220      NaN
# 219611      2021-06-15 19:22:05  Animais
# 653278  2012-09-23 11:31:34.460      NaN
#
#                                        Assunto
# 525575            Animal agressor e/ou invasor  \
# 120283                   Animal em via pública
# 565531  Animais / Abelhas, Vespas, Marimbondos
# 265133             Exames, vacinas e castração
# 335449             Exames, vacinas e castração
# 307244             Exames, vacinas e castração
# 681548                           Animais / Cão
# 645313                         Animais / Ratos
# 219611             Exames, vacinas e castração
# 653278                           Animais / Cão
#
#                                                  Serviço
# 525575     Avisar sobre animal agressor em vias públicas  \
# 120283  Solicitar remoção de animal morto em via pública
# 565531                        Colméia/Vespeiro instalado
# 265133                Castrar cães e gatos gratuitamente
# 335449                Castrar cães e gatos gratuitamente
# 307244                Castrar cães e gatos gratuitamente
# 681548                                      Cão Agressor
# 645313                               Reclamação de ratos
# 219611                Castrar cães e gatos gratuitamente
# 653278  Atropelado ou Acidentado vivo e sem proprietário
#
#                     Distrito Status da solicitação             Data do parecer
# 525575          VILA ANDRADE            FINALIZADA     2015-06-10 03:00:00.000
# 120283              MANDAQUI            FINALIZADO         2022-03-06 18:04:25
# 565531      JARDIM SAO PAULO             REALIZADA     2014-03-10 00:00:00.000
# 265133                   NaN            FINALIZADA         2020-12-14 13:03:36
# 335449                   NaN            FINALIZADA         2020-06-11 18:03:45
# 307244                   NaN            FINALIZADA         2020-10-14 14:12:24
# 681548                 Moema             CANCELADA     2012-04-24 00:00:00.000
# 645313              Pedreira             REALIZADA     2012-08-02 15:45:42.290
# 219611                   NaN            FINALIZADA         2021-06-21 10:27:41
# 653278  PARQUE INDEPENDENCIA             REALIZADA  2017-05-04 17:23:21.817000

# %%
df1['Distrito'].isnull().sum()
# Out:
# 232507

# %%
df1['Distrito'].notnull().sum()
# Out:
# 471853

# %% [markdown]
# ## Tratamento das descrições (Assunto, Serviço)

# %%
df2 = df1.rename({'Assunto': 'Tipo de Serviço'}, axis=1)

# %%
df2.sample()
# Out:
#            Data de abertura     Tema
# 328271  2020-03-04 18:58:44  Animais  \
#
#                                         Tipo de Serviço
# 328271  Animais que transmitem doenças ou risco à saúde  \
#
#                                                 Serviço   Distrito
# 328271  Abelhas e Vespas - Solicitar vistoria em ninhos  AGUA RASA  \
#
#        Status da solicitação      Data do parecer
# 328271            FINALIZADA  2020-04-09 16:44:58

# %%
df2['Tipo de Serviço'].drop_duplicates()
# Out:
# 0                                Registro de animais - RGA
# 1                              Exames, vacinas e castração
# 3                                        Adoção de animais
# 4                            Criação inadequada de animais
# 6                                       Animais silvestres
# 9                                    Animal em via pública
# 14         Animais que transmitem doenças ou risco à saúde
# 23                            Animal agressor e/ou invasor
# 66        Dengue/chikungunya/zika (mosquito aedes aegypti)
# 26265                                  Comércio de animais
# 128038                    Animais que podem causar doenças
# 361615                                      Animais/Aranha
# 386661                                  Animais/Carrapatos
# 392961                                      Animais/Pulgas
# 397007                                      Animais/barata
# 529214                                       Animais / Cão
# 529218                                      Animais / Gato
# 529219                                     Animais / Ratos
# 529220              Animais / Abelhas, Vespas, Marimbondos
# 529226                                             Animais
# 529229                                Animais / Pernilongo
# 529237                                  Animais / Morcegos
# 529244                     Animais / Escorpiões ou Aranhas
# 529253                                    Animais / Pombos
# 529263                                Animais / Carrapatos
# 529296              Animais / Ocorrencias com outros tipos
# 529414                                   Animais / Formiga
# 529472                                   Animais / Baratas
# 529482                                    Animais / Pulgas
# 529725                                    Animais / Moscas
# 529765                                    Animais / Cavalo
# 529767                                  Vistoria / Animais
# 540659                                Animais / Escorpiões
# 540820                                   Animais / Aranhas
# Name: Tipo de Serviço, dtype: object

# %%
df2[['Tipo de Serviço', 'Serviço']].drop_duplicates()
# Out:
#                                          Tipo de Serviço
# 0                              Registro de animais - RGA  \
# 1                            Exames, vacinas e castração
# 3                                      Adoção de animais
# 4                          Criação inadequada de animais
# 6                                     Animais silvestres
# 9                                  Animal em via pública
# 12                                 Animal em via pública
# 14       Animais que transmitem doenças ou risco à saúde
# 15       Animais que transmitem doenças ou risco à saúde
# 19       Animais que transmitem doenças ou risco à saúde
# 21       Animais que transmitem doenças ou risco à saúde
# 23                          Animal agressor e/ou invasor
# 25                          Animal agressor e/ou invasor
# 66      Dengue/chikungunya/zika (mosquito aedes aegypti)
# 69       Animais que transmitem doenças ou risco à saúde
# 71                             Registro de animais - RGA
# 109                                Animal em via pública
# 227      Animais que transmitem doenças ou risco à saúde
# 501                          Exames, vacinas e castração
# 1276                           Registro de animais - RGA
# 1460                                  Animais silvestres
# 26265                                Comércio de animais
# 34365                                Comércio de animais
# 40401                                 Animais silvestres
# 46546                                 Animais silvestres
# 67423                                Comércio de animais
# 88229                                Comércio de animais
# 128038                  Animais que podem causar doenças
# 128051                  Animais que podem causar doenças
# 128056                  Animais que podem causar doenças
# 128063                  Animais que podem causar doenças
# 128068                             Animal em via pública
# 128086                  Animais que podem causar doenças
# 128122                  Animais que podem causar doenças
# 147468                         Registro de animais - RGA
# 148018                       Exames, vacinas e castração
# 361615                                    Animais/Aranha
# 386661                                Animais/Carrapatos
# 392961                                    Animais/Pulgas
# 397007                                    Animais/barata
# 529214                                     Animais / Cão
# 529218                                    Animais / Gato
# 529219                                   Animais / Ratos
# 529220            Animais / Abelhas, Vespas, Marimbondos
# 529221                                     Animais / Cão
# 529224                                     Animais / Cão
# 529226                                           Animais
# 529229                              Animais / Pernilongo
# 529237                                Animais / Morcegos
# 529238                                    Animais / Gato
# 529240                                    Animais / Gato
# 529244                   Animais / Escorpiões ou Aranhas
# 529253                                  Animais / Pombos
# 529263                              Animais / Carrapatos
# 529269                                     Animais / Cão
# 529296            Animais / Ocorrencias com outros tipos
# 529397                                    Animais / Gato
# 529406                                    Animais / Gato
# 529414                                 Animais / Formiga
# 529472                                 Animais / Baratas
# 529482                                  Animais / Pulgas
# 529725                                  Animais / Moscas
# 529765                                  Animais / Cavalo
# 529767                                Vistoria / Animais
# 530004                                    Animais / Gato
# 530090                                  Animais / Cavalo
# 530119                                Vistoria / Animais
# 530506                                     Animais / Cão
# 534481                                Vistoria / Animais
# 536291                                Vistoria / Animais
# 540659                              Animais / Escorpiões
# 540820                                 Animais / Aranhas
# 585177                                Animais / Morcegos
# 681086                                     Animais / Cão
# 682824            Animais / Abelhas, Vespas, Marimbondos
#
#                                                   Serviço
# 0       Avisar  sobre animal encontrado com Registro G...
# 1                      Castrar cães e gatos gratuitamente
# 3                                     Adotar cães e gatos
# 4              Denunciar condições inadequadas de criação
# 6       Animais silvestres feridos ? Solicitar atendim...
# 9        Solicitar remoção de animal morto em via pública
# 12      Avaliação de animal em sofrimento sem propriet...
# 14      Pernilongo/Mosquito - Solicitar vistoria em lo...
# 15           Morcegos - Reclamar sobre local com morcegos
# 19          Ratos - Solicitar vistoria em local infestado
# 21        Abelhas e Vespas - Solicitar vistoria em ninhos
# 23          Avisar sobre animal agressor em vias públicas
# 25      Cães e gatos invasores de instituições pública...
# 66      Água limpa e parada ? Solicitar vistoria de lo...
# 69      Escorpião - Solicitar vistoria de local com es...
# 71      Registro Geral do Animal (RGA) - Solicitar ide...
# 109      Animal de grande porte solto - Solicitar remoção
# 227        Pombos - Solicitar vistoria em local infestado
# 501      Castrar cães e gatos de protetores independentes
# 1276     Registro Geral do Animal (RGA) - Atualizar dados
# 1460      Animais silvestres ? Agendar entrega voluntária
# 26265   Cadastro Municipal de Comércio de Animais (CMC...
# 34365   Cadastro Municipal de Comércio de Animais (CMC...
# 40401   Animais silvestres feridos – Solicitar atendim...
# 46546     Animais silvestres – Agendar entrega voluntária
# 67423   Cadastro Municipal de Comércio de Animais (CMC...
# 88229   Cadastro Municipal de Comércio de Animais (CMC...
# 128038  Pernilongo/Mosquito - Solicitar vistoria em lo...
# 128051      Ratos - Solicitar vistoria em local infestado
# 128056    Abelhas e Vespas - Solicitar vistoria em ninhos
# 128063       Morcegos - Reclamar sobre local com morcegos
# 128068             Remoção de animal morto em via pública
# 128086     Pombos - Solicitar vistoria em local infestado
# 128122  Escorpião - Solicitar vistoria de local com es...
# 147468  TESTE TESTE TESTE - Registro Geral do Animal (...
# 148018  TESTE TESTE TESTE - Castrar cães e gatos gratu...
# 361615                              Reclamação de Aranhas
# 386661                           Reclamação de carrapatos
# 392961                               Reclamação de pulgas
# 397007                              Reclamação de baratas
# 529214                 Condições de criação / maus tratos
# 529218                 Condições de criação / maus tratos
# 529219                                Reclamação de ratos
# 529220                         Colméia/Vespeiro instalado
# 529221   Atropelado ou Acidentado vivo e sem proprietário
# 529224                                       Cão Agressor
# 529226           Remoção de animal morto em vias publicas
# 529229                           Reclamação de Pernilongo
# 529237                            Ocorrências com morcego
# 529238                        Atropelado sem proprietário
# 529240                                   Invadiu o local
# 529244                Reclamação de Escorpiões ou Aranhas
# 529253                               Reclamação de Pombos
# 529263                           Reclamação de Carrapatos
# 529269                                    Invadiu o local
# 529296                 Ocorrências / Condições de criação
# 529397                                      Gato agressor
# 529406                        Acidentado sem proprietário
# 529414                             Reclamação de Formigas
# 529472                              Reclamação de Baratas
# 529482                               Reclamação de Pulgas
# 529725                               Reclamação de Moscas
# 529765                               Diversas ocorrências
# 529767                           Trânsito de boiadas a pé
# 530004                            Gato encontrado com RGA
# 530090                               Condições de criação
# 530119                                         Em parques
# 530506                             Cão encontrado com RGA
# 534481                  Falta de placa sobre animal feroz
# 536291                        Cães em vigilância bancária
# 540659                           Reclamação de Escorpiões
# 540820                              Reclamação de Aranhas
# 585177                             Ocorrências rotineiras
# 681086                               Solto em via pública
# 682824          Remoção de Abelhas, Vespas ou Marimbondos

# %% [markdown]
# ### Padronizar o Tipo de Serviço

# %%
df2.loc[df2['Tipo de Serviço'].str.contains('Animais[ |/]') & df2['Tipo de Serviço']
        .str.match('^(?!.*(Cão|Gato|Cavalo|silvestres|RGA|agressor|via))'), 'Tipo de Serviço'
       ] = 'Animais que transmitem doenças ou risco à saúde'

# %%
df2[['Tipo de Serviço', 'Serviço']].drop_duplicates()
# Out:
#                                          Tipo de Serviço
# 0                              Registro de animais - RGA  \
# 1                            Exames, vacinas e castração
# 3                                      Adoção de animais
# 4                          Criação inadequada de animais
# 6                                     Animais silvestres
# 9                                  Animal em via pública
# 12                                 Animal em via pública
# 14       Animais que transmitem doenças ou risco à saúde
# 15       Animais que transmitem doenças ou risco à saúde
# 19       Animais que transmitem doenças ou risco à saúde
# 21       Animais que transmitem doenças ou risco à saúde
# 23                          Animal agressor e/ou invasor
# 25                          Animal agressor e/ou invasor
# 66      Dengue/chikungunya/zika (mosquito aedes aegypti)
# 69       Animais que transmitem doenças ou risco à saúde
# 71                             Registro de animais - RGA
# 109                                Animal em via pública
# 227      Animais que transmitem doenças ou risco à saúde
# 501                          Exames, vacinas e castração
# 1276                           Registro de animais - RGA
# 1460                                  Animais silvestres
# 26265                                Comércio de animais
# 34365                                Comércio de animais
# 40401                                 Animais silvestres
# 46546                                 Animais silvestres
# 67423                                Comércio de animais
# 88229                                Comércio de animais
# 128068                             Animal em via pública
# 147468                         Registro de animais - RGA
# 148018                       Exames, vacinas e castração
# 361615   Animais que transmitem doenças ou risco à saúde
# 386661   Animais que transmitem doenças ou risco à saúde
# 392961   Animais que transmitem doenças ou risco à saúde
# 397007   Animais que transmitem doenças ou risco à saúde
# 529214                                     Animais / Cão
# 529218                                    Animais / Gato
# 529219   Animais que transmitem doenças ou risco à saúde
# 529220   Animais que transmitem doenças ou risco à saúde
# 529221                                     Animais / Cão
# 529224                                     Animais / Cão
# 529226                                           Animais
# 529229   Animais que transmitem doenças ou risco à saúde
# 529237   Animais que transmitem doenças ou risco à saúde
# 529238                                    Animais / Gato
# 529240                                    Animais / Gato
# 529244   Animais que transmitem doenças ou risco à saúde
# 529253   Animais que transmitem doenças ou risco à saúde
# 529263   Animais que transmitem doenças ou risco à saúde
# 529269                                     Animais / Cão
# 529296   Animais que transmitem doenças ou risco à saúde
# 529397                                    Animais / Gato
# 529406                                    Animais / Gato
# 529414   Animais que transmitem doenças ou risco à saúde
# 529472   Animais que transmitem doenças ou risco à saúde
# 529482   Animais que transmitem doenças ou risco à saúde
# 529725   Animais que transmitem doenças ou risco à saúde
# 529765                                  Animais / Cavalo
# 529767                                Vistoria / Animais
# 530004                                    Animais / Gato
# 530090                                  Animais / Cavalo
# 530119                                Vistoria / Animais
# 530506                                     Animais / Cão
# 534481                                Vistoria / Animais
# 536291                                Vistoria / Animais
# 540659   Animais que transmitem doenças ou risco à saúde
# 585177   Animais que transmitem doenças ou risco à saúde
# 681086                                     Animais / Cão
# 682824   Animais que transmitem doenças ou risco à saúde
#
#                                                   Serviço
# 0       Avisar  sobre animal encontrado com Registro G...
# 1                      Castrar cães e gatos gratuitamente
# 3                                     Adotar cães e gatos
# 4              Denunciar condições inadequadas de criação
# 6       Animais silvestres feridos ? Solicitar atendim...
# 9        Solicitar remoção de animal morto em via pública
# 12      Avaliação de animal em sofrimento sem propriet...
# 14      Pernilongo/Mosquito - Solicitar vistoria em lo...
# 15           Morcegos - Reclamar sobre local com morcegos
# 19          Ratos - Solicitar vistoria em local infestado
# 21        Abelhas e Vespas - Solicitar vistoria em ninhos
# 23          Avisar sobre animal agressor em vias públicas
# 25      Cães e gatos invasores de instituições pública...
# 66      Água limpa e parada ? Solicitar vistoria de lo...
# 69      Escorpião - Solicitar vistoria de local com es...
# 71      Registro Geral do Animal (RGA) - Solicitar ide...
# 109      Animal de grande porte solto - Solicitar remoção
# 227        Pombos - Solicitar vistoria em local infestado
# 501      Castrar cães e gatos de protetores independentes
# 1276     Registro Geral do Animal (RGA) - Atualizar dados
# 1460      Animais silvestres ? Agendar entrega voluntária
# 26265   Cadastro Municipal de Comércio de Animais (CMC...
# 34365   Cadastro Municipal de Comércio de Animais (CMC...
# 40401   Animais silvestres feridos – Solicitar atendim...
# 46546     Animais silvestres – Agendar entrega voluntária
# 67423   Cadastro Municipal de Comércio de Animais (CMC...
# 88229   Cadastro Municipal de Comércio de Animais (CMC...
# 128068             Remoção de animal morto em via pública
# 147468  TESTE TESTE TESTE - Registro Geral do Animal (...
# 148018  TESTE TESTE TESTE - Castrar cães e gatos gratu...
# 361615                              Reclamação de Aranhas
# 386661                           Reclamação de carrapatos
# 392961                               Reclamação de pulgas
# 397007                              Reclamação de baratas
# 529214                 Condições de criação / maus tratos
# 529218                 Condições de criação / maus tratos
# 529219                                Reclamação de ratos
# 529220                         Colméia/Vespeiro instalado
# 529221   Atropelado ou Acidentado vivo e sem proprietário
# 529224                                       Cão Agressor
# 529226           Remoção de animal morto em vias publicas
# 529229                           Reclamação de Pernilongo
# 529237                            Ocorrências com morcego
# 529238                        Atropelado sem proprietário
# 529240                                   Invadiu o local
# 529244                Reclamação de Escorpiões ou Aranhas
# 529253                               Reclamação de Pombos
# 529263                           Reclamação de Carrapatos
# 529269                                    Invadiu o local
# 529296                 Ocorrências / Condições de criação
# 529397                                      Gato agressor
# 529406                        Acidentado sem proprietário
# 529414                             Reclamação de Formigas
# 529472                              Reclamação de Baratas
# 529482                               Reclamação de Pulgas
# 529725                               Reclamação de Moscas
# 529765                               Diversas ocorrências
# 529767                           Trânsito de boiadas a pé
# 530004                            Gato encontrado com RGA
# 530090                               Condições de criação
# 530119                                         Em parques
# 530506                             Cão encontrado com RGA
# 534481                  Falta de placa sobre animal feroz
# 536291                        Cães em vigilância bancária
# 540659                           Reclamação de Escorpiões
# 585177                             Ocorrências rotineiras
# 681086                               Solto em via pública
# 682824          Remoção de Abelhas, Vespas ou Marimbondos

# %%
df2['Tipo de Serviço'] = df2['Tipo de Serviço'].str.replace('Animais / ', '')

# %%
df2['Tipo de Serviço'] = df2['Tipo de Serviço'].str.replace(' / Animais', '')

# %%
df2['Tipo de Serviço'] = df2['Tipo de Serviço'].str.replace('Dengue/chikungunya/zika (mosquito aedes aegypti)', 'Vistoria')

# %%
df2['Tipo de Serviço'].drop_duplicates()
# Out:
# 0                               Registro de animais - RGA
# 1                             Exames, vacinas e castração
# 3                                       Adoção de animais
# 4                           Criação inadequada de animais
# 6                                      Animais silvestres
# 9                                   Animal em via pública
# 14        Animais que transmitem doenças ou risco à saúde
# 23                           Animal agressor e/ou invasor
# 66                                               Vistoria
# 26265                                 Comércio de animais
# 529214                                                Cão
# 529218                                               Gato
# 529226                                            Animais
# 529765                                             Cavalo
# Name: Tipo de Serviço, dtype: object

# %% [markdown]
# ### Apagar os registros de teste

# %%
df2 = df2.drop(df2.loc[df1['Serviço'].str.contains('TESTE', regex=True)].index)

# %% [markdown]
# ### Padronizar o Serviço

# %% [markdown]
# #### Tratar o Tipo de Serviço 'Animais que transmitem doenças ou risco à saúde'

# %%
df2.loc[df2['Tipo de Serviço'] == 'Animais que transmitem doenças ou risco à saúde', 'Serviço'].drop_duplicates().sort_values()
# Out:
# 21          Abelhas e Vespas - Solicitar vistoria em ninhos
# 529220                           Colméia/Vespeiro instalado
# 69        Escorpião - Solicitar vistoria de local com es...
# 15             Morcegos - Reclamar sobre local com morcegos
# 529296                   Ocorrências / Condições de criação
# 529237                              Ocorrências com morcego
# 585177                               Ocorrências rotineiras
# 14        Pernilongo/Mosquito - Solicitar vistoria em lo...
# 227          Pombos - Solicitar vistoria em local infestado
# 19            Ratos - Solicitar vistoria em local infestado
# 361615                                Reclamação de Aranhas
# 529472                                Reclamação de Baratas
# 529263                             Reclamação de Carrapatos
# 540659                             Reclamação de Escorpiões
# 529244                  Reclamação de Escorpiões ou Aranhas
# 529414                               Reclamação de Formigas
# 529725                                 Reclamação de Moscas
# 529229                             Reclamação de Pernilongo
# 529253                                 Reclamação de Pombos
# 529482                                 Reclamação de Pulgas
# 397007                                Reclamação de baratas
# 386661                             Reclamação de carrapatos
# 392961                                 Reclamação de pulgas
# 529219                                  Reclamação de ratos
# 682824            Remoção de Abelhas, Vespas ou Marimbondos
# Name: Serviço, dtype: object

# %%
df3 = df2.copy()

# %% [markdown]
# #### Juntar Serviços iguais com nomes diferentes

# %%
df3.loc[(df3['Serviço'].str.contains('Pernilongo/Mosquito', regex=True)) | (df3['Serviço'] == 'Reclamação de Pernilongo'), 'Serviço'] = 'Reclamação de Pernilongos e Mosquitos'

# %%
df3.loc[(df3['Serviço'] == 'Abelhas e Vespas') | (df3['Serviço'] == 'Colméia/Vespeiro instalado'), 'Serviço'] = 'Remoção de Abelhas, Vespas ou Marimbondos'

# %%
df3.loc[df3['Serviço'].str.contains('Escorpião', regex=True), 'Serviço'] = 'Escorpiões'

# %%
df3.loc[df3['Serviço'] == 'Reclamação de Escorpião', 'Serviço'] = 'Reclamação de Escorpiões'

# %%
df3.loc[df3['Serviço'] == 'Ocorrências com morcego', 'Serviço'] = 'Reclamação de Morcegos'

# %% [markdown]
# #### Juntar diversos Serviços que estão duplicados, seguindo um padrão igual

# %%
df3.loc[df3['Tipo de Serviço'] == 'Animais que transmitem doenças ou risco à saúde', 'Serviço'] = df3.loc[df3[
    'Tipo de Serviço'] == 'Animais que transmitem doenças ou risco à saúde', 'Serviço'].str.replace(r' -.*', '', regex=True)

# %%
df3.loc[df3['Serviço'].str.split().str.len() == 1, 'Serviço'] = 'Reclamação de ' + df3['Serviço']

# %%
df3.loc[df3['Tipo de Serviço'] == 'Animais que transmitem doenças ou risco à saúde', 'Serviço'].drop_duplicates().sort_values()
# Out:
# 21                                 Abelhas e Vespas
# 529296           Ocorrências / Condições de criação
# 585177                       Ocorrências rotineiras
# 361615                        Reclamação de Aranhas
# 529472                        Reclamação de Baratas
# 529263                     Reclamação de Carrapatos
# 69                         Reclamação de Escorpiões
# 529244          Reclamação de Escorpiões ou Aranhas
# 529414                       Reclamação de Formigas
# 15                           Reclamação de Morcegos
# 529725                         Reclamação de Moscas
# 14            Reclamação de Pernilongos e Mosquitos
# 227                            Reclamação de Pombos
# 529482                         Reclamação de Pulgas
# 19                              Reclamação de Ratos
# 397007                        Reclamação de baratas
# 386661                     Reclamação de carrapatos
# 392961                         Reclamação de pulgas
# 529219                          Reclamação de ratos
# 529220    Remoção de Abelhas, Vespas ou Marimbondos
# Name: Serviço, dtype: object

# %% [markdown]
# #### Tratar os Tipos de Serviços que NÃO são 'Animais que transmitem doenças ou risco à saúde'

# %% [markdown]
# #### Retirar caracteres não úteis

# %%
df3['Serviço'] = df3['Serviço'].str.replace('?', '-')
df3['Serviço'] = df3['Serviço'].str.replace('–', '-')
df3['Serviço'] = df3['Serviço'].str.replace('Invadiu o local ', 'Invadiu o local')

# %%
pd.set_option('display.max_colwidth', None)
df3.loc[df3['Tipo de Serviço'] != 'Animais que transmitem doenças ou risco à saúde', 'Serviço'].drop_duplicates().sort_values()
# Out:
# 529406                                                          Acidentado sem proprietário
# 3                                                                       Adotar cães e gatos
# 1460                                        Animais silvestres - Agendar entrega voluntária
# 6                            Animais silvestres feridos - Solicitar atendimento veterinário
# 109                                        Animal de grande porte solto - Solicitar remoção
# 529221                                     Atropelado ou Acidentado vivo e sem proprietário
# 529238                                                          Atropelado sem proprietário
# 12        Avaliação de animal em sofrimento sem proprietário para eutanásia (morte sem dor)
# 0                        Avisar  sobre animal encontrado com Registro Geral do Animal (RGA)
# 23                                            Avisar sobre animal agressor em vias públicas
# 34365                  Cadastro Municipal de Comércio de Animais (CMCA) - Cancelar cadastro
# 26265                    Cadastro Municipal de Comércio de Animais (CMCA) - Fazer inscrição
# 501                                        Castrar cães e gatos de protetores independentes
# 1                                                        Castrar cães e gatos gratuitamente
# 530090                                                                 Condições de criação
# 529214                                                   Condições de criação / maus tratos
# 25                    Cães e gatos invasores de instituições públicas - Solicitar avaliação
# 536291                                                          Cães em vigilância bancária
# 529224                                                                         Cão Agressor
# 530506                                                               Cão encontrado com RGA
# 4                                                Denunciar condições inadequadas de criação
# 529765                                                                 Diversas ocorrências
# 530119                                                                           Em parques
# 534481                                                    Falta de placa sobre animal feroz
# 529397                                                                        Gato agressor
# 530004                                                              Gato encontrado com RGA
# 529240                                                                      Invadiu o local
# 1276                                       Registro Geral do Animal (RGA) - Atualizar dados
# 71                          Registro Geral do Animal (RGA) - Solicitar identidade do animal
# 128068                                               Remoção de animal morto em via pública
# 529226                                             Remoção de animal morto em vias publicas
# 9                                          Solicitar remoção de animal morto em via pública
# 681086                                                                 Solto em via pública
# 529767                                                             Trânsito de boiadas a pé
# 66                            Água limpa e parada - Solicitar vistoria de local com acúmulo
# Name: Serviço, dtype: object

# %% [markdown]
# #### Padronizar os 'Serviços' que contém 'Acidentado' ou 'Atropelado'

# %%
df3.loc[df3['Serviço'].str.contains('Atropelado') | df3['Serviço'].str.contains('Acidentado'), 'Serviço'
       ] = 'Atropelado ou Acidentado vivo e sem proprietário'

# %% [markdown]
# #### Padronizar 'Condições de criação' e 'Denunciar condições inadequadas de criação' com 'Condições de criação / maus tratos'

# %%
df3.loc[df3['Serviço'].str.match('.*ondições'), 'Serviço'
       ] = 'Condições de criação / maus tratos'

# %% [markdown]
# #### Padronizar os que tem 'Remoção de animal morto em via pública' (3)

# %%
df3.loc[df3['Serviço'].str.match('.*morto em via.*'), 'Serviço'
       ] = 'Remoção de animal morto em via pública'

# %% [markdown]
# #### Usar o 'Tipo de Serviço' para preencher 'Serviços' não tão bem descritos, como 'Solto em via pública'

# %%
condicoes = (df3['Serviço'] == 'Em parques') | (df3['Serviço'] == 'Invadiu o local') | (df3['Serviço'] == 'Solto em via pública')
df3.loc[condicoes, 'Serviço'] = df3.loc[condicoes, 'Tipo de Serviço'].str.cat(df3.loc[condicoes, 'Serviço'], sep=' ')

# %%
condicoes = (df3['Serviço'] == 'Diversas ocorrências') | (df3['Serviço'] == 'Ocorrências rotineiras')
df3.loc[condicoes, 'Serviço'] = df3.loc[condicoes, 'Tipo de Serviço'].str.cat(df3.loc[condicoes, 'Serviço'], sep=' - ')

# %%
pd.set_option('display.max_colwidth', None)
df3.loc[df3['Tipo de Serviço'] != 'Animais que transmitem doenças ou risco à saúde', 'Serviço'].drop_duplicates().sort_values()
# Out:
# 3                                                                       Adotar cães e gatos
# 1460                                        Animais silvestres - Agendar entrega voluntária
# 6                            Animais silvestres feridos - Solicitar atendimento veterinário
# 109                                        Animal de grande porte solto - Solicitar remoção
# 529221                                     Atropelado ou Acidentado vivo e sem proprietário
# 12        Avaliação de animal em sofrimento sem proprietário para eutanásia (morte sem dor)
# 0                        Avisar  sobre animal encontrado com Registro Geral do Animal (RGA)
# 23                                            Avisar sobre animal agressor em vias públicas
# 34365                  Cadastro Municipal de Comércio de Animais (CMCA) - Cancelar cadastro
# 26265                    Cadastro Municipal de Comércio de Animais (CMCA) - Fazer inscrição
# 501                                        Castrar cães e gatos de protetores independentes
# 1                                                        Castrar cães e gatos gratuitamente
# 529765                                                        Cavalo - Diversas ocorrências
# 4                                                        Condições de criação / maus tratos
# 25                    Cães e gatos invasores de instituições públicas - Solicitar avaliação
# 536291                                                          Cães em vigilância bancária
# 529224                                                                         Cão Agressor
# 529269                                                                  Cão Invadiu o local
# 681086                                                             Cão Solto em via pública
# 530506                                                               Cão encontrado com RGA
# 534481                                                    Falta de placa sobre animal feroz
# 529240                                                                 Gato Invadiu o local
# 529397                                                                        Gato agressor
# 530004                                                              Gato encontrado com RGA
# 1276                                       Registro Geral do Animal (RGA) - Atualizar dados
# 71                          Registro Geral do Animal (RGA) - Solicitar identidade do animal
# 9                                                    Remoção de animal morto em via pública
# 529767                                                             Trânsito de boiadas a pé
# 530119                                                                  Vistoria Em parques
# 66                            Água limpa e parada - Solicitar vistoria de local com acúmulo
# Name: Serviço, dtype: object

# %%
df3[['Tipo de Serviço', 'Serviço']].drop_duplicates().sort_values(by=['Tipo de Serviço', 'Serviço'])
# Out:
#                                         Tipo de Serviço
# 3                                     Adoção de animais  \
# 529226                                          Animais
# 21      Animais que transmitem doenças ou risco à saúde
# 585177  Animais que transmitem doenças ou risco à saúde
# 529296  Animais que transmitem doenças ou risco à saúde
# 361615  Animais que transmitem doenças ou risco à saúde
# 529472  Animais que transmitem doenças ou risco à saúde
# 529263  Animais que transmitem doenças ou risco à saúde
# 69      Animais que transmitem doenças ou risco à saúde
# 529244  Animais que transmitem doenças ou risco à saúde
# 529414  Animais que transmitem doenças ou risco à saúde
# 15      Animais que transmitem doenças ou risco à saúde
# 529725  Animais que transmitem doenças ou risco à saúde
# 14      Animais que transmitem doenças ou risco à saúde
# 227     Animais que transmitem doenças ou risco à saúde
# 529482  Animais que transmitem doenças ou risco à saúde
# 19      Animais que transmitem doenças ou risco à saúde
# 397007  Animais que transmitem doenças ou risco à saúde
# 386661  Animais que transmitem doenças ou risco à saúde
# 392961  Animais que transmitem doenças ou risco à saúde
# 529219  Animais que transmitem doenças ou risco à saúde
# 529220  Animais que transmitem doenças ou risco à saúde
# 1460                                 Animais silvestres
# 6                                    Animais silvestres
# 23                         Animal agressor e/ou invasor
# 25                         Animal agressor e/ou invasor
# 109                               Animal em via pública
# 12                                Animal em via pública
# 9                                 Animal em via pública
# 529765                                           Cavalo
# 530090                                           Cavalo
# 34365                               Comércio de animais
# 26265                               Comércio de animais
# 4                         Criação inadequada de animais
# 529221                                              Cão
# 529214                                              Cão
# 529224                                              Cão
# 529269                                              Cão
# 681086                                              Cão
# 530506                                              Cão
# 501                         Exames, vacinas e castração
# 1                           Exames, vacinas e castração
# 529238                                             Gato
# 529218                                             Gato
# 529240                                             Gato
# 529397                                             Gato
# 530004                                             Gato
# 0                             Registro de animais - RGA
# 1276                          Registro de animais - RGA
# 71                            Registro de animais - RGA
# 536291                                         Vistoria
# 534481                                         Vistoria
# 529767                                         Vistoria
# 530119                                         Vistoria
# 66                                             Vistoria
#
#                                                                                   Serviço
# 3                                                                     Adotar cães e gatos
# 529226                                             Remoção de animal morto em via pública
# 21                                                                       Abelhas e Vespas
# 585177           Animais que transmitem doenças ou risco à saúde - Ocorrências rotineiras
# 529296                                                 Condições de criação / maus tratos
# 361615                                                              Reclamação de Aranhas
# 529472                                                              Reclamação de Baratas
# 529263                                                           Reclamação de Carrapatos
# 69                                                               Reclamação de Escorpiões
# 529244                                                Reclamação de Escorpiões ou Aranhas
# 529414                                                             Reclamação de Formigas
# 15                                                                 Reclamação de Morcegos
# 529725                                                               Reclamação de Moscas
# 14                                                  Reclamação de Pernilongos e Mosquitos
# 227                                                                  Reclamação de Pombos
# 529482                                                               Reclamação de Pulgas
# 19                                                                    Reclamação de Ratos
# 397007                                                              Reclamação de baratas
# 386661                                                           Reclamação de carrapatos
# 392961                                                               Reclamação de pulgas
# 529219                                                                Reclamação de ratos
# 529220                                          Remoção de Abelhas, Vespas ou Marimbondos
# 1460                                      Animais silvestres - Agendar entrega voluntária
# 6                          Animais silvestres feridos - Solicitar atendimento veterinário
# 23                                          Avisar sobre animal agressor em vias públicas
# 25                  Cães e gatos invasores de instituições públicas - Solicitar avaliação
# 109                                      Animal de grande porte solto - Solicitar remoção
# 12      Avaliação de animal em sofrimento sem proprietário para eutanásia (morte sem dor)
# 9                                                  Remoção de animal morto em via pública
# 529765                                                      Cavalo - Diversas ocorrências
# 530090                                                 Condições de criação / maus tratos
# 34365                Cadastro Municipal de Comércio de Animais (CMCA) - Cancelar cadastro
# 26265                  Cadastro Municipal de Comércio de Animais (CMCA) - Fazer inscrição
# 4                                                      Condições de criação / maus tratos
# 529221                                   Atropelado ou Acidentado vivo e sem proprietário
# 529214                                                 Condições de criação / maus tratos
# 529224                                                                       Cão Agressor
# 529269                                                                Cão Invadiu o local
# 681086                                                           Cão Solto em via pública
# 530506                                                             Cão encontrado com RGA
# 501                                      Castrar cães e gatos de protetores independentes
# 1                                                      Castrar cães e gatos gratuitamente
# 529238                                   Atropelado ou Acidentado vivo e sem proprietário
# 529218                                                 Condições de criação / maus tratos
# 529240                                                               Gato Invadiu o local
# 529397                                                                      Gato agressor
# 530004                                                            Gato encontrado com RGA
# 0                      Avisar  sobre animal encontrado com Registro Geral do Animal (RGA)
# 1276                                     Registro Geral do Animal (RGA) - Atualizar dados
# 71                        Registro Geral do Animal (RGA) - Solicitar identidade do animal
# 536291                                                        Cães em vigilância bancária
# 534481                                                  Falta de placa sobre animal feroz
# 529767                                                           Trânsito de boiadas a pé
# 530119                                                                Vistoria Em parques
# 66                          Água limpa e parada - Solicitar vistoria de local com acúmulo

# %%
df3.sample(10)
# Out:
#                Data de abertura     Tema
# 351481  2019-10-24 17:35:57.216  Animais  \
# 325414      2020-02-11 16:10:48  Animais
# 650069  2012-09-03 19:29:42.857      NaN
# 347263  2019-09-18 22:58:51.861  Animais
# 301573      2020-08-09 03:34:10  Animais
# 403950  2018-02-01 21:43:30.243  Animais
# 566369               2014-02-26      NaN
# 626927               2013-03-26      NaN
# 486069  2015-09-21 13:14:24.273  Animais
# 312557      2020-09-15 17:23:56  Animais
#
#                                         Tipo de Serviço
# 351481  Animais que transmitem doenças ou risco à saúde  \
# 325414                    Criação inadequada de animais
# 650069  Animais que transmitem doenças ou risco à saúde
# 347263  Animais que transmitem doenças ou risco à saúde
# 301573                      Exames, vacinas e castração
# 403950                            Animal em via pública
# 566369  Animais que transmitem doenças ou risco à saúde
# 626927  Animais que transmitem doenças ou risco à saúde
# 486069  Animais que transmitem doenças ou risco à saúde
# 312557                      Exames, vacinas e castração
#
#                                                                                   Serviço
# 351481                                                                Reclamação de Ratos  \
# 325414                                                 Condições de criação / maus tratos
# 650069                                                                Reclamação de ratos
# 347263                                                                   Abelhas e Vespas
# 301573                                                 Castrar cães e gatos gratuitamente
# 403950  Avaliação de animal em sofrimento sem proprietário para eutanásia (morte sem dor)
# 566369                                          Remoção de Abelhas, Vespas ou Marimbondos
# 626927                                          Remoção de Abelhas, Vespas ou Marimbondos
# 486069                                                                   Abelhas e Vespas
# 312557                                                 Castrar cães e gatos gratuitamente
#
#                  Distrito Status da solicitação          Data do parecer
# 351481        RIO PEQUENO            FINALIZADA  2019-10-30 18:58:45.845
# 325414           PIRITUBA            FINALIZADA      2020-07-17 19:01:19
# 650069      Cidade Ademar             REALIZADA  2012-09-24 00:00:00.000
# 347263           TREMEMBE            FINALIZADA  2019-09-20 17:33:39.802
# 301573                NaN            INDEFERIDO      2020-08-23 16:41:41
# 403950        SANTO AMARO            FINALIZADA  2018-02-02 01:19:30.572
# 566369  JARDIM ARICANDUVA            INDEFERIDA  2015-04-06 03:00:00.000
# 626927     VILA PALMEIRAS             REALIZADA  2013-03-28 00:00:00.000
# 486069          PINHEIROS            FINALIZADA  2015-09-24 03:00:00.000
# 312557                NaN            FINALIZADA      2020-11-16 18:55:28

# %% [markdown]
# ### Realizar um capitalize em cada "Serviço" caso gouver necessidade

# %%
def capitalize(servico):
    # Descobrir o sinal que a frase usa
    sinal = re.findall(r" - | / ", servico)
    
    if sinal:
        # Dividindo a frase em duas partes: antes e depois do traço ou da barra
        partes = re.split(sinal[0], servico)
        
        # Realizando o capitalize na primeira parte (antes do traço)
        parte1 = partes[0].capitalize()

        # Realizando o capitalize na segunda parte (depois do traço)
        parte2 = partes[1].capitalize()
        
        return "".join([parte1, sinal[0], parte2])
    else:
        return servico.capitalize()

# %%
df3['Serviço'] = df3['Serviço'].apply(lambda x: capitalize(x) if not re.search(r'RGA|CMCA', x) else x)

# %%
df3[['Tipo de Serviço', 'Serviço']].drop_duplicates().sort_values(by=['Tipo de Serviço', 'Serviço'])
# Out:
#                                         Tipo de Serviço
# 3                                     Adoção de animais  \
# 529226                                          Animais
# 21      Animais que transmitem doenças ou risco à saúde
# 585177  Animais que transmitem doenças ou risco à saúde
# 529296  Animais que transmitem doenças ou risco à saúde
# 361615  Animais que transmitem doenças ou risco à saúde
# 397007  Animais que transmitem doenças ou risco à saúde
# 386661  Animais que transmitem doenças ou risco à saúde
# 69      Animais que transmitem doenças ou risco à saúde
# 529244  Animais que transmitem doenças ou risco à saúde
# 529414  Animais que transmitem doenças ou risco à saúde
# 15      Animais que transmitem doenças ou risco à saúde
# 529725  Animais que transmitem doenças ou risco à saúde
# 14      Animais que transmitem doenças ou risco à saúde
# 227     Animais que transmitem doenças ou risco à saúde
# 392961  Animais que transmitem doenças ou risco à saúde
# 19      Animais que transmitem doenças ou risco à saúde
# 529220  Animais que transmitem doenças ou risco à saúde
# 1460                                 Animais silvestres
# 6                                    Animais silvestres
# 23                         Animal agressor e/ou invasor
# 25                         Animal agressor e/ou invasor
# 109                               Animal em via pública
# 12                                Animal em via pública
# 9                                 Animal em via pública
# 529765                                           Cavalo
# 530090                                           Cavalo
# 34365                               Comércio de animais
# 26265                               Comércio de animais
# 4                         Criação inadequada de animais
# 529221                                              Cão
# 529214                                              Cão
# 529224                                              Cão
# 530506                                              Cão
# 529269                                              Cão
# 681086                                              Cão
# 501                         Exames, vacinas e castração
# 1                           Exames, vacinas e castração
# 529238                                             Gato
# 529218                                             Gato
# 529397                                             Gato
# 530004                                             Gato
# 529240                                             Gato
# 0                             Registro de animais - RGA
# 1276                          Registro de animais - RGA
# 71                            Registro de animais - RGA
# 536291                                         Vistoria
# 534481                                         Vistoria
# 529767                                         Vistoria
# 530119                                         Vistoria
# 66                                             Vistoria
#
#                                                                                   Serviço
# 3                                                                     Adotar cães e gatos
# 529226                                             Remoção de animal morto em via pública
# 21                                                                       Abelhas e vespas
# 585177           Animais que transmitem doenças ou risco à saúde - Ocorrências rotineiras
# 529296                                                 Condições de criação / Maus tratos
# 361615                                                              Reclamação de aranhas
# 397007                                                              Reclamação de baratas
# 386661                                                           Reclamação de carrapatos
# 69                                                               Reclamação de escorpiões
# 529244                                                Reclamação de escorpiões ou aranhas
# 529414                                                             Reclamação de formigas
# 15                                                                 Reclamação de morcegos
# 529725                                                               Reclamação de moscas
# 14                                                  Reclamação de pernilongos e mosquitos
# 227                                                                  Reclamação de pombos
# 392961                                                               Reclamação de pulgas
# 19                                                                    Reclamação de ratos
# 529220                                          Remoção de abelhas, vespas ou marimbondos
# 1460                                      Animais silvestres - Agendar entrega voluntária
# 6                          Animais silvestres feridos - Solicitar atendimento veterinário
# 23                                          Avisar sobre animal agressor em vias públicas
# 25                  Cães e gatos invasores de instituições públicas - Solicitar avaliação
# 109                                      Animal de grande porte solto - Solicitar remoção
# 12      Avaliação de animal em sofrimento sem proprietário para eutanásia (morte sem dor)
# 9                                                  Remoção de animal morto em via pública
# 529765                                                      Cavalo - Diversas ocorrências
# 530090                                                 Condições de criação / Maus tratos
# 34365                Cadastro Municipal de Comércio de Animais (CMCA) - Cancelar cadastro
# 26265                  Cadastro Municipal de Comércio de Animais (CMCA) - Fazer inscrição
# 4                                                      Condições de criação / Maus tratos
# 529221                                   Atropelado ou acidentado vivo e sem proprietário
# 529214                                                 Condições de criação / Maus tratos
# 529224                                                                       Cão agressor
# 530506                                                             Cão encontrado com RGA
# 529269                                                                Cão invadiu o local
# 681086                                                           Cão solto em via pública
# 501                                      Castrar cães e gatos de protetores independentes
# 1                                                      Castrar cães e gatos gratuitamente
# 529238                                   Atropelado ou acidentado vivo e sem proprietário
# 529218                                                 Condições de criação / Maus tratos
# 529397                                                                      Gato agressor
# 530004                                                            Gato encontrado com RGA
# 529240                                                               Gato invadiu o local
# 0                      Avisar  sobre animal encontrado com Registro Geral do Animal (RGA)
# 1276                                     Registro Geral do Animal (RGA) - Atualizar dados
# 71                        Registro Geral do Animal (RGA) - Solicitar identidade do animal
# 536291                                                        Cães em vigilância bancária
# 534481                                                  Falta de placa sobre animal feroz
# 529767                                                           Trânsito de boiadas a pé
# 530119                                                                Vistoria em parques
# 66                          Água limpa e parada - Solicitar vistoria de local com acúmulo

# %% [markdown]
# ### Transformar todas as datas e horas para apenas data

# %%
df4 = df3.copy()

# %% [markdown]
# #### 'Data de abertura'

# %%
df4['Data de abertura'] = df4['Data de abertura'].str.slice(0,10)

# %%
df4['Data de abertura'] = pd.to_datetime(df4['Data de abertura']).dt.date

# %%
df4['Data de abertura'].sample(10)
# Out:
# 178409    2021-08-26
# 8383      2023-01-26
# 295055    2020-07-17
# 519102    2015-04-08
# 117180    2022-02-23
# 202445    2021-05-04
# 376020    2019-05-05
# 530342    2014-07-14
# 306047    2020-08-25
# 601790    2013-11-12
# Name: Data de abertura, dtype: object

# %%
df4.loc[df4['Data do parecer'].notnull(), 'Data do parecer'] = df4.loc[
    df4['Data do parecer'].notnull(), 'Data do parecer'].str.slice(0,10)

# %%
df4['Data do parecer'].sample(10)
# Out:
# 192701    2021-04-19
# 148297    2021-12-23
# 525157    2015-05-29
# 347833    2019-10-02
# 521778    2015-07-24
# 625455    2013-06-18
# 387484    2018-09-12
# 425031    2017-10-25
# 482120    2015-09-14
# 107039    2022-02-14
# Name: Data do parecer, dtype: object

# %%
df4.sample(10)
# Out:
#        Data de abertura     Tema
# 554686       2014-01-03      NaN  \
# 310316       2020-09-10  Animais
# 433630       2017-12-18  Animais
# 345473       2019-09-02  Animais
# 372165       2019-04-03  Animais
# 433283       2017-12-15  Animais
# 130561       2021-10-09  Animais
# 461042       2016-02-16  Animais
# 7781         2023-01-24  Animais
# 474953       2016-06-02  Animais
#
#                                         Tipo de Serviço
# 554686  Animais que transmitem doenças ou risco à saúde  \
# 310316                      Exames, vacinas e castração
# 433630  Animais que transmitem doenças ou risco à saúde
# 345473                     Animal agressor e/ou invasor
# 372165  Animais que transmitem doenças ou risco à saúde
# 433283  Animais que transmitem doenças ou risco à saúde
# 130561                      Exames, vacinas e castração
# 461042  Animais que transmitem doenças ou risco à saúde
# 7781                              Animal em via pública
# 474953                    Criação inadequada de animais
#
#                                                                       Serviço
# 554686                                  Reclamação de pernilongos e mosquitos  \
# 310316                                     Castrar cães e gatos gratuitamente
# 433630                                                       Abelhas e vespas
# 345473  Cães e gatos invasores de instituições públicas - Solicitar avaliação
# 372165                                               Reclamação de escorpiões
# 433283                                                       Abelhas e vespas
# 130561                                     Castrar cães e gatos gratuitamente
# 461042                                                    Reclamação de ratos
# 7781                         Animal de grande porte solto - Solicitar remoção
# 474953                                     Condições de criação / Maus tratos
#
#                    Distrito Status da solicitação Data do parecer
# 554686  VILA SANTO HENRIQUE             REALIZADA      2014-01-14
# 310316                  NaN            FINALIZADA      2020-10-26
# 433630                PERUS            FINALIZADA      2017-12-29
# 345473              JAGUARA            FINALIZADA      2019-09-02
# 372165         CACHOEIRINHA            FINALIZADA      2019-04-15
# 433283        CIDADE ADEMAR            FINALIZADA      2018-02-27
# 130561                  NaN            INDEFERIDO      2021-10-23
# 461042                  NaN            FINALIZADA      2016-06-13
# 7781        JARDIM SAO LUIS            FINALIZADA      2023-01-24
# 474953                  NaN            INDEFERIDO      2016-06-06

# %%
df4.isnull().any()
# Out:
# Data de abertura         False
# Tema                      True
# Tipo de Serviço          False
# Serviço                  False
# Distrito                  True
# Status da solicitação    False
# Data do parecer           True
# dtype: bool

# %% [markdown]
# ## Gerar o arquivo com os dados necessários

# %%
df4.to_parquet('sp156_all_time.gzip',
              compression='gzip',
              index=False)
