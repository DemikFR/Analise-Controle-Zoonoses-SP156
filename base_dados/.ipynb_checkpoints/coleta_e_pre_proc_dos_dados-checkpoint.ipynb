# %% [markdown]
# # Agregando Datasets do SP196 em um Arquivo Consolidado

# %% [markdown]
# ## Aviso: Comentários resumidos neste código; consulte a  [Documentação](https://github.com/DemikFR/Analise-Controle-Zoonoses-SP156/blob/main/README.md) para obter uma compreensão mais detalhada das razões por trás de cada trecho de código.

# %% [markdown]
# ## Gerar o dataframe com os dados da Prefeitura

# %%
import requests
import re
from bs4 import BeautifulSoup as bs
import pandas as pd
from io import StringIO
import chardet

# %% [markdown]
# ### Criar o dataframe que conterá os dados necessários para a análise

# %%
df = pd.DataFrame()
dfs = []

# %% [markdown]
# ## Função para buscar os caminhos para o download de cada dataset

# %%
def get_soup(url, search):
    response = requests.get(url)
    
    # Verificar se a conexão foi bem sucedida
    if response.status_code == 200:
        soup = bs(response.content, 'html.parser')

        # Retornar as páginas onde terão as de download
        return soup.find_all('a', href=True, attrs={'title': re.compile(search)}) 
    else:
        return f'Página{link["title"]} está inacessível. Código: {response.status_code}'

# %% [markdown]
# ## Código para inserir os dados em uma lista

# %%
# URL base do site da Prefeitura
url_base = 'http://dados.prefeitura.sp.gov.br'

# URL inicial onde estarão os links para os datasets
url_inicial = 'http://dados.prefeitura.sp.gov.br/dataset/dados-do-sp156'

# extensão do dataset para filtrar
file_type = '.csv'

for link in get_soup(url_inicial, r'^Dados do SP156.*'):
    
    # Pegar o link de download
    for page in get_soup(url_base+link['href'], r'^http://dados.prefeitura.sp.gov.br/dataset/.*'):
        link_download = page['href']
        
        # Verificar se é o arquivo a ser baixado é Excel
        if file_type in link_download:
            
            # Pegar o conteúdo do CSV
            response_csv = requests.get(link_download)
            
            # Cada datset tem um encoding diferente, por isso foi necessário usar a biblioteca chardet para identificar 
            # automaticamente qual é.
            encoding = chardet.detect(response_csv.content)['encoding']
            
            # Colocar os dados na tabela auxiliar
            if int(link["title"][-4:]) >= 2020:
                df3 = pd.read_csv(StringIO(response_csv.content.decode(encoding)), sep=';', encoding=encoding, low_memory=False)
            else:
                df3 = pd.read_csv(StringIO(response_csv.content.decode(encoding)), sep=',', encoding=encoding, low_memory=False)
                
            dfs.append(df3)  # Adicionar o DataFrame intermediário à lista
            
            # Inserir os dados na planilha original
            print(f'Os dados do {link["title"]} foram inseridos com sucesso.')
# Out:
# Os dados do Dados do SP156 - 1º TRI 2023 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 4º TRI 2022 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 3º TRI 2022 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º TRI 2022 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º TRI 2022 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 4º TRI 2021 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 3º TRI 2021 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º TRI 2021 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º TRI 2021 foram inseridos com sucesso.
# Os dados do Dados do SP156 - Dezembro - 2020 foram inseridos com sucesso.
# Os dados do Dados do SP156 - Outubro e Novembro - 2020 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 3º TRI 2020 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2020 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º SEM 2019 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2019 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º SEM 2018 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2018 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2° SEM 2017 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1° SEM 2017 foram inseridos com sucesso.
# Os dados do Dados do SP156  - 2° SEM 2016 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1° SEM 2016 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º SEM 2015 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2015 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2° SEM 2014 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2014 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º SEM 2013 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2013 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 2º SEM 2012 foram inseridos com sucesso.
# Os dados do Dados do SP156 - 1º SEM 2012 foram inseridos com sucesso.

# %% [markdown]
# ## Criar o dataframe com todos os datasets coletados

# %%
df = pd.concat(dfs, ignore_index=True)

# %%
df.shape
# Out:
# (14183650, 33)

# %% [markdown]
# ## Verificar todas as colunas disponibilizadas

# %%
df.any()
# Out:
# Data de abertura                                                          True
# Canal                                                                     True
# Tema                                                                      True
# Assunto                                                                   True
# Serviço                                                                   True
# Logradouro                                                                True
# Número                                                                    True
# CEP                                                                       True
# Subprefeitura                                                             True
# Distrito                                                                  True
# Setor                                                                     True
# Quadra                                                                    True
# Latitude                                                                  True
# Longitude                                                                 True
# Data do parecer                                                           True
# Status da solicitação                                                     True
# Órgão                                                                     True
# Data Avaliação Pesquisa Satisfação                                        True
# Nível Satisfação                                                          True
# Prazo de Atendimento                                                      True
# Qualidade do Serviço                                                      True
# Atendeu a Solicitação                                                     True
# Compreensão da Resposta                                                   True
# De modo geral, qual o seu nível de satisfação com o serviço prestado?     True
# Prazo de atendimento                                                      True
# Qualidade do serviço                                                      True
# A Prefeitura atendeu a sua solicitação?                                   True
# Compreensão da resposta recebida                                          True
# Cep                                                                       True
# Unnamed: 23                                                              False
# Canal de atendimento                                                      True
# Especificação do assunto                                                  True
# Bairro                                                                    True
# dtype: bool

# %% [markdown]
# ## Manter apenas os campos necessários

# %%
df = df[['Data de abertura', 'Tema', 'Assunto', 'Especificação do assunto', 'Serviço', 'Bairro', 'Distrito'
         , 'Status da solicitação', 'Data do parecer']]

# %% [markdown]
# ## Apagar registros que por terem muitos valores nulo, não servirão para a análise

# %%
df = df.dropna(thresh=4)

# %%
df[df['Data de abertura'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Data de abertura, Tema, Assunto, Especificação do assunto, Serviço, Bairro, Distrito, Status da solicitação, Data do parecer]
# Index: []

# %%
df.sample(10)
# Out:
#                  Data de abertura                            Tema
# 11570275  2015-02-11 11:53:46.000                    Rua e bairro  \
# 1244212       2022-08-13 02:03:00  Cidadania e assistência social
# 1886790       2022-06-20 11:43:31                         Animais
# 12548010               2014-05-16                             NaN
# 7186144       2020-01-31 11:37:05                    Rua e bairro
# 1033483       2022-12-30 21:49:04  Cidadania e assistência social
# 1708221       2022-05-13 12:19:48                           Saúde
# 4236471       2021-06-15 01:16:21  Cidadania e assistência social
# 8183865   2019-11-29 13:40:06.644           Trânsito e Transporte
# 6021181       2020-12-16 14:48:44  Cidadania e assistência social
#
#                                                    Assunto
# 11570275                          Calçadas, guias e postes  \
# 1244212             População ou pessoa em situação de rua
# 1886790                          Registro de animais - RGA
# 12548010                   Dengue (Mosquito Aedes aegypti)
# 7186144              Reparos em asfalto, pontes e viadutos
# 1033483             População ou pessoa em situação de rua
# 1708221                   Medicamento de controle especial
# 4236471                           Renda Básica Emergencial
# 8183865   Sinalização e Circulação de Veículos e Pedestres
# 6021181                           Renda Básica Emergencial
#
#                                    Especificação do assunto
# 11570275                                                NaN  \
# 1244212                                                 NaN
# 1886790                                                 NaN
# 12548010  Reclamação de presença de mosquito incomodando...
# 7186144                                                 NaN
# 1033483                                                 NaN
# 1708221                                                 NaN
# 4236471                                                 NaN
# 8183865                                                 NaN
# 6021181                                                 NaN
#
#                                                     Serviço          Bairro
# 11570275  Calçada particular - denunciar calçada danific...             NaN  \
# 1244212   Acolhimento para pessoas em situação de rua - ...             NaN
# 1886790   Registro Geral do Animal (RGA) - Solicitar ide...             NaN
# 12548010                                                NaN  VILA CARMOSINA
# 7186144                                         Tapa-buraco             NaN
# 1033483   Pessoa em situação de rua ? Solicitar atendime...             NaN
# 1708221   Farmácias de manipulação e drogarias - Entrega...             NaN
# 4236471   Renda Básica Emergencial - Consultar Situação ...             NaN
# 8183865   Rodízio de veículos - Isenção para pessoa com ...             NaN
# 6021181   Renda Básica Emergencial - Consultar benefício...             NaN
#
#                 Distrito Status da solicitação          Data do parecer
# 11570275  RAPOSO TAVARES            FINALIZADA  2018-08-29 19:14:09.000
# 1244212            BELEM            FINALIZADA      2022-08-13 05:45:52
# 1886790              NaN            FINALIZADA      2022-06-29 18:39:03
# 12548010             NaN             REALIZADA  2014-08-29 00:00:00.000
# 7186144      BRASILANDIA            INDEFERIDO      2020-04-15 17:53:53
# 1033483               SE            FINALIZADA      2022-12-31 00:15:35
# 1708221              NaN            FINALIZADA      2022-05-17 14:45:07
# 4236471              NaN             CANCELADA      2021-06-24 18:07:25
# 8183865              NaN            INDEFERIDO  2019-12-02 19:28:48.263
# 6021181              NaN            FINALIZADA      2020-12-16 14:48:50

# %% [markdown]
# ## Filtrar apenas os dados necessários para a análise

# %%
df['Tema'].drop_duplicates()
# Out:
# 0           Cidadania e assistência social
# 5                                  Animais
# 7               Obras, imóveis e habitação
# 10                            Rua e bairro
# 34                           Meio Ambiente
# 37                          Lixo e limpeza
# 41                                Urgência
# 54                                   Saúde
# 67                     Comércio e serviços
# 95                   Trânsito e Transporte
# 151                           Causa animal
# 188           Ouvidoria Geral do Município
# 227                         Pragas urbanas
# 431                               Finanças
# 439                         Acessibilidade
# 918                          Bilhete Único
# 1272                      Segurança urbana
# 2334                 Documentos e licenças
# 2885              Cultura, esporte e lazer
# 4389                              Educação
# 8048                              Trabalho
# 334059              Descomplica São Miguel
# 596920               Canais de Atendimento
# 597569                 Prefeitura Regional
# 1044114                               4093
# 1389675                               4126
# 1548739                Baixas Temperaturas
# 1550759                               4050
# 1997106                  Serviço funerário
# 2605867                               3917
# 2605909                               4020
# 2770878                            SAC/GRC
# 4821770                               3929
# 11883410                               NaN
# Name: Tema, dtype: object

# %% [markdown]
# ### Entender o motivo de existirem nulos no 'Tema'

# %%
pd.set_option('display.max_rows', None)
df[df.Tema.isnull()]['Assunto'].drop_duplicates()
# Out:
# 11883410                             Construcao de passarelas
# 11883411                                               Buraco
# 11883412                                      Poluição Sonora
# 11883414    Placas de Nomes de Ruas, Praças e demais Logra...
# 11883416                         Iluminacao - Lampada apagada
# 11883417             Transporte publico / Conduta de Trabalho
# 11883418                              Remoção veículo/carcaça
# 11883420                                               Elogio
# 11883424                            Vistoria / Infraestrutura
# 11883427                                                Obras
# 11883428                                           Edificacao
# 11883429                                        Animais / Cão
# 11883434                                         Pavimentacao
# 11883439                      Árvore(Calçada/Passeio Público)
# 11883442                          Transporte publico / Outros
# 11883444                                       Guias/sarjetas
# 11883446        Transporte publico / Manutenção e Conservação
# 11883453                                              Calçada
# 11883469              Transporte publico / Linha e Itinerário
# 11883473                        Bueiros/galerias agua pluvial
# 11883477                   CET / Veículo com placa abandonado
# 11883480                   Transporte publico / Bilhete Unico
# 11883483    CET / Insatisfação com circulação de veículos(...
# 11883489                     Lixo / Limpeza - Coleta Seletiva
# 11883494                                              Entulho
# 11883503                                   Comercio irregular
# 11883509                                     Varrição/Limpeza
# 11883511                 Praças/Áreas Verdes/Canteiro Central
# 11883513                                        Praça Pública
# 11883516                 Ecoponto (Entulho e Grandes Objetos)
# 11883520         Processo Encerrado/Solicitacao Vistas/Cópias
# 11883523                        Denúncia sobre Poluição do Ar
# 11883525                  Capinação/Roçada de áreas vegetadas
# 11883526                              Bagulho/Grandes Objetos
# 11883528                                           Papeleiras
# 11883530                                          Feira Livre
# 11883539                                       Lixo / Limpeza
# 11883548                                     Areas municipais
# 11883550           CET / Manutenção da Sinalização Semafórica
# 11883552                                Árvore(Praça Pública)
# 11883553    Transporte publico / Terminal, Corredor e Esta...
# 11883559                              Vigilância de Alimentos
# 11883565                               Boca de Lobo - Bueiros
# 11883566                  Transporte publico / Táxi e Escolar
# 11883567                                       Animais / Gato
# 11883568                                      Animais / Ratos
# 11883573               Animais / Abelhas, Vespas, Marimbondos
# 11883580                      Dengue (Mosquito Aedes aegypti)
# 11883585                               Programa Bolsa Família
# 11883629                                             Terrenos
# 11883641            Transporte Publico / Bilhete Único Mensal
# 11883646                                              Animais
# 11883672                Transporte publico / Pontos de Parada
# 11883677                                         CET / Escola
# 11883685                                 CET / Mão de direção
# 11883688                     Lixo/Limpeza - Queixas/Denuncias
# 11883699                                 CET / Estacionamento
# 11883712    NF Paulistana (Comunicação de não conversão – ...
# 11883713                                   Saude / Informacao
# 11883747                                   CET / Fiscalização
# 11883753                                    Remoções diversas
# 11883765                                      CET / Zona Azul
# 11883766                                 Animais / Pernilongo
# 11883770                            Saude - Queixa / Denuncia
# 11883783          CET / Manutenção de sinalização de trânsito
# 11883805     Esgoto a céu aberto/imóvel particular/residência
# 11883848                                   Animais / Morcegos
# 11883873                         CET / Circulação de Pedestre
# 11883877                        CET / Conflito entre veículos
# 11883908                                                Saude
# 11883910                      Animais / Escorpiões ou Aranhas
# 11883911               Guias/rebaixamento para acessibilidade
# 11883977                                             Corregos
# 11883985                                   Vistoria / Limpeza
# 11884005                                    Vistoria / Árvore
# 11884024                                  Denúncia sobre Solo
# 11884042                                     Animais / Pombos
# 11884101             Iluminacao - Lampada acesa durante o dia
# 11884135                      Denúncia sobre Poluição da Água
# 11884139                               Obras em Vias Públicas
# 11884157                                 Animais / Carrapatos
# 11884164                                     CET / Velocidade
# 11884257                  Hidrante de Incêndio em Edificações
# 11884287                                           Leve Leite
# 11884303                                    Logradouro/imovel
# 11884364          Iluminacao - Barulho no Transformador/Chave
# 11884472                                               Árvore
# 11884505                                           Reclamação
# 11884507               Animais / Ocorrencias com outros tipos
# 11884531                             Denúncia sobre Vegetação
# 11884589                                             Vistoria
# 11884645                                  Programa Ação Jovem
# 11884654                           CET / Manutenção de placas
# 11884690                                 Vistoria / Ambiental
# 11884788                      Escadas e Rampas em Edificações
# 11885046                                    Bancos / Denúncia
# 11885052                    PEV - Ponto de Entrega Voluntária
# 11885114                                Postos de Combustível
# 11885288                          Vistoria / Mesas e Cadeiras
# 11885298                             Bolsa Família - Denúncia
# 11885361        CET / Desvio/Interdição temporária de tráfego
# 11885378           CET / Sinalização de orientação de destino
# 11885389             Iluminacao - Luminaria pendente ou caída
# 11885407                               Iluminacao - Fio caído
# 11885525                            Vistoria / Acessibilidade
# 11885534                            Roçada de Áreas vegetadas
# 11885549                     CET / Interferências no trânsito
# 11885649                        Parques Municipais / Denúncia
# 11885662                               CET / Faixa reversível
# 11885786                                Programa Renda Cidadã
# 11885828                                             Poluição
# 11885924                           Guarda Civil Metropolitana
# 11886028                                        Jogos de Azar
# 11886122                                    Animais / Formiga
# 11886154                                       CET / Semáforo
# 11886256           Lixo Limpeza Saúde - Atraso / Implantação
# 11886309                        Acesso p/ Deficientes Fisicos
# 11886544                         CET / Conduta de Funcionário
# 11886866    Água Infiltrada Afetando a Segurança da Edific...
# 11886904                                    Animais / Baratas
# 11887060                                     Animais / Pulgas
# 11887087                                            Desportos
# 11887160                                                 IPTU
# 11887179              CET / Sinalização Horizontal e Vertical
# 11887269                                      Faixas/Cartazes
# 11887366                  Ecoponto(Entulho e Grandes Objetos)
# 11887381    Locais de Reunião - Lotação Superior a 500 Pes...
# 11887846                                             Transito
# 11888531          Produtos Químicos Perigosos nas Edificações
# 11888737                        Centro de Controle de Doenças
# 11888750                           Iluminacao - Fio faiscando
# 11888823                  Saídas de Emergência em Edificações
# 11888996                                 Vistoria / Tabagismo
# 11889332                              Renda Mínima - Denúncia
# 11889344                                               Idosos
# 11889523                                             Sugestão
# 11889662                           Vistoria / Estacionamentos
# 11890095        Brigada de Combate a Incêndios em Edificações
# 11890557                                Programa Renda Mínima
# 11890583    Transporte publico / Terminal, Corredor e Estação
# 11890729                                     Pintura de guias
# 11890739                                     Animais / Moscas
# 11890785                                    Pintura de Postes
# 11890893                  Extintor de Incêndio em Edificações
# 11891221                                       Vistoria / Gás
# 11891242     Comercialização Irregular de Fogos de Artifícios
# 11891299      Elevador de Passageiro/Carga,Escada Rolante Etc
# 11891312                                     Animais / Cavalo
# 11891334                                   Vistoria / Animais
# 11891574                Iluminacao - Poste metalico abalroado
# 11892052    Instalações Elétricas Precárias - Nas Edificações
# 11892521                           Programa Social - Denuncia
# 11893247                              Agente Jovem - Denúncia
# 11894361    Transporte publico / Portador  Mobilidade Redu...
# 11894791             Iluminação de Emergência nas Edificações
# 11895493                    Alarme de Incêndio em edificações
# 11897156                                          Funcionario
# 11897184                    Portas Corta-Fogo nas Edificações
# 11898241    PROGRAMA NOTA FISCAL PAULISTANA - N.F. DE SERV...
# 11898501                                       BPC - Denúncia
# 11898629                                   Lixo-Limpeza Saúde
# 11899275                        Alistamento e Serviço Militar
# 11899279    Instalações de Gás (GLP ou NATURAL) na Edificação
# 11899320                                   Lixo Limpeza Ruído
# 11899347                                    Servico funerario
# 11899608    Dific. de  estacionamento - pessoas c/deficiencia
# 11901655                      CET / Fiscalização (Emergência)
# 11901848     Sinalização de Emergência/Incêndio em Edificação
# 11902459               População ou Pessoa em Situação de Rua
# 11903206                              Renda Cidadã - Denúncia
# 11908962                     CET / Emergências de Alagamentos
# 11910276    Comercialização irregular de substâncias inala...
# 11914155                                              Merenda
# 11915136    Vigilância Sanitária de Produtos de Interesse ...
# 11919547                                                Praça
# 11922991                                 Pintura de Floreiras
# 11929568    Chuveiro Automático de Combate ao Fogo (Sprink...
# 11944572                            Pára-Raios em Edificações
# 11956788                                     Atendimento - SF
# 11977589                                                  PPI
# 11985962                                                  CCM
# 11989818                                Ação Jovem - Denúncia
# 12049318                                 Animais / Escorpiões
# 12051206                                    Animais / Aranhas
# 12170752                                                  ISS
# 12208912     Dengue/Chikungunya/Zika (Mosquito Aedes aegypti)
# 12227765                            Guarda-Volumes nos bancos
# 12370449                                     PETI - Denúncias
# 12621132     Lixeira em Prédio Residencial e Outros Edifícios
# 12621369      Recente Ocorrência de Desabamento em Edificação
# 12621616                                Feira livre / Sacolao
# 12623375            Problemas com as Estruturas da Edificação
# 12664602         Recente Ocorrência de Incêndio em Edificação
# 12696961         Recente Ocorrência de Explosão em Edificação
# 12995552                        Jardinagem (poda, corte mato)
# 12997692    Mananciais-Oper.Defesa Águas/Áreas Verdes-Denú...
# 13430205                                      Permissionárias
# 13766897        Iluminacao - Novo ponto de Iluminacao Publica
# 13798504                                        Meio Ambiente
# 13801574                    CET / Cancelamento de Ocorrências
# 14033944                Central de Atendimento Telefonico 156
# Name: Assunto, dtype: object

# %% [markdown]
# ### O campo 'Tema' só é usado em datasets mais recentes, por isso deve-se utilizar o campo 'Assunto' para filtrar

# %%
df1 = df[df['Assunto'].str.contains('Animais', regex=False) | df['Tema'].str.contains(r'^Anim.*|^Pragas.*', regex=True)].reset_index(drop=True)

# %%
df1.shape
# Out:
# (722401, 9)

# %%
df1.sample(20)
# Out:
#                Data de abertura     Tema
# 70128       2022-04-09 15:43:03  Animais  \
# 325156      2020-02-08 14:55:13  Animais
# 191142      2021-04-05 12:48:14  Animais
# 467540  2016-11-23 12:48:56.200  Animais
# 431840  2017-12-04 15:01:23.320  Animais
# 558112               2014-10-03      NaN
# 19785       2022-10-08 16:07:23  Animais
# 130543      2021-10-09 20:39:36  Animais
# 153311      2021-12-12 01:59:35  Animais
# 122854      2022-03-15 09:05:01  Animais
# 622990               2013-12-05      NaN
# 707845  2012-04-03 11:58:25.000      NaN
# 671155  2012-09-21 12:42:47.047      NaN
# 345624  2019-09-03 21:40:36.225  Animais
# 311694      2020-09-14 13:19:30  Animais
# 587881               2014-03-17      NaN
# 702464  2012-03-07 16:29:45.610      NaN
# 660616  2012-07-07 12:37:30.517      NaN
# 676825  2012-10-29 20:28:34.347      NaN
# 174888      2021-08-17 15:23:52  Animais
#
#                                                 Assunto
# 70128                       Exames, vacinas e castração  \
# 325156                    Criação inadequada de animais
# 191142  Animais que transmitem doenças ou risco à saúde
# 467540  Animais que transmitem doenças ou risco à saúde
# 431840  Animais que transmitem doenças ou risco à saúde
# 558112                             Animais / Pernilongo
# 19785                     Criação inadequada de animais
# 130543                            Animal em via pública
# 153311                 Animais que podem causar doenças
# 122854  Animais que transmitem doenças ou risco à saúde
# 622990                                 Animais / Pombos
# 707845                                    Animais / Cão
# 671155                                    Animais / Cão
# 345624  Animais que transmitem doenças ou risco à saúde
# 311694  Animais que transmitem doenças ou risco à saúde
# 587881           Animais / Ocorrencias com outros tipos
# 702464                             Animais / Pernilongo
# 660616                                    Animais / Cão
# 676825                                  Animais / Ratos
# 174888                      Exames, vacinas e castração
#
#                   Especificação do assunto
# 70128                                  NaN  \
# 325156                                 NaN
# 191142                                 NaN
# 467540                                 NaN
# 431840                                 NaN
# 558112            Reclamação de Pernilongo
# 19785                                  NaN
# 130543                                 NaN
# 153311                                 NaN
# 122854                                 NaN
# 622990                Reclamação de Pombos
# 707845  Condições de criação / maus tratos
# 671155  Condições de criação / maus tratos
# 345624                                 NaN
# 311694                                 NaN
# 587881  Ocorrências / Condições de criação
# 702464            Reclamação de Pernilongo
# 660616                     Invadiu o local
# 676825                 Reclamação de ratos
# 174888                                 NaN
#
#                                                   Serviço             Bairro
# 70128                  Castrar cães e gatos gratuitamente                NaN  \
# 325156         Denunciar condições inadequadas de criação                NaN
# 191142    Abelhas e Vespas - Solicitar vistoria em ninhos                NaN
# 467540    Abelhas e Vespas - Solicitar vistoria em ninhos                NaN
# 431840      Ratos - Solicitar vistoria em local infestado                NaN
# 558112                                                NaN           VELEIROS
# 19785          Denunciar condições inadequadas de criação                NaN
# 130543             Remoção de animal morto em via pública                NaN
# 153311  Pernilongo/Mosquito - Solicitar vistoria em lo...                NaN
# 122854      Ratos - Solicitar vistoria em local infestado                NaN
# 622990                                                NaN      LAPA DE BAIXO
# 707845                                                NaN          VILA RICA
# 671155                                                NaN  JARDIM DE LORENZO
# 345624    Abelhas e Vespas - Solicitar vistoria em ninhos                NaN
# 311694    Abelhas e Vespas - Solicitar vistoria em ninhos                NaN
# 587881                                                NaN    JARDIM SAO LUIS
# 702464                                                NaN        SANTO AMARO
# 660616                                                NaN    VILA CONSTANCIA
# 676825                                                NaN          VILA NILO
# 174888                 Castrar cães e gatos gratuitamente                NaN
#
#               Distrito Status da solicitação          Data do parecer
# 70128              NaN            FINALIZADA      2022-04-30 15:17:43
# 325156        TUCURUVI            FINALIZADA      2020-03-25 13:03:21
# 191142    CIDADE DUTRA            FINALIZADA      2021-04-09 14:36:24
# 467540       SAPOPEMBA            FINALIZADA  2016-12-27 17:17:36.531
# 431840       AGUA RASA            FINALIZADA  2018-03-29 14:14:38.682
# 558112             NaN             REALIZADA  2014-10-07 00:00:00.000
# 19785              NaN            FINALIZADA      2022-12-14 16:12:20
# 130543         JARAGUA            FINALIZADA      2021-10-13 11:50:14
# 153311        PIRITUBA            FINALIZADA      2022-01-07 16:48:47
# 122854  VILA GUILHERME            FINALIZADO      2022-06-07 15:19:49
# 622990             NaN             REALIZADA  2013-12-10 00:00:00.000
# 707845            11.0             REALIZADA  2012-04-24 00:00:00.000
# 671155            18.0             CANCELADA  2014-03-25 10:33:40.687
# 345624  FREGUESIA DO O            FINALIZADA  2020-01-02 14:41:43.264
# 311694     RIO PEQUENO            FINALIZADA      2020-09-17 17:47:11
# 587881             NaN             REALIZADA  2014-04-17 00:00:00.000
# 702464            72.0             REALIZADA  2012-03-19 00:00:00.000
# 660616             NaN             CANCELADA  2014-02-27 00:00:00.000
# 676825            38.0             REALIZADA  2013-05-15 13:16:03.033
# 174888             NaN            INDEFERIDO      2021-08-27 17:20:19

# %% [markdown]
# ## Padronizar o campo 'Serviço' com o 'Especificação do assunto'

# %% [markdown]
# #### Os dois campos possuem o mesmo objetivo

# %%
df1.loc[df1['Serviço'].isnull(), 'Serviço'] = df1.loc[df1['Serviço'].isnull(), 'Especificação do assunto']

# %%
df1.sample(10)
# Out:
#                Data de abertura     Tema
# 161916      2021-07-12 17:46:59  Animais  \
# 175462      2021-08-18 21:41:30  Animais
# 164465      2021-07-19 14:43:39  Animais
# 100156      2022-01-11 10:48:39  Animais
# 307368      2020-08-31 14:29:53  Animais
# 639594               2013-02-27      NaN
# 271226      2020-10-05 10:56:11  Animais
# 263476      2020-12-07 11:47:38  Animais
# 421461  2017-08-24 17:23:05.260  Animais
# 623773               2013-12-10      NaN
#
#                                                 Assunto
# 161916                      Exames, vacinas e castração  \
# 175462                      Exames, vacinas e castração
# 164465                      Exames, vacinas e castração
# 100156  Animais que transmitem doenças ou risco à saúde
# 307368                      Exames, vacinas e castração
# 639594           Animais / Abelhas, Vespas, Marimbondos
# 271226  Animais que transmitem doenças ou risco à saúde
# 263476                    Criação inadequada de animais
# 421461  Animais que transmitem doenças ou risco à saúde
# 623773                                    Animais / Cão
#
#                   Especificação do assunto
# 161916                                 NaN  \
# 175462                                 NaN
# 164465                                 NaN
# 100156                                 NaN
# 307368                                 NaN
# 639594          Colméia/Vespeiro instalado
# 271226                                 NaN
# 263476                                 NaN
# 421461                                 NaN
# 623773  Condições de criação / maus tratos
#
#                                                 Serviço
# 161916               Castrar cães e gatos gratuitamente  \
# 175462               Castrar cães e gatos gratuitamente
# 164465               Castrar cães e gatos gratuitamente
# 100156    Ratos - Solicitar vistoria em local infestado
# 307368               Castrar cães e gatos gratuitamente
# 639594                       Colméia/Vespeiro instalado
# 271226  Abelhas e Vespas - Solicitar vistoria em ninhos
# 263476       Denunciar condições inadequadas de criação
# 421461    Ratos - Solicitar vistoria em local infestado
# 623773               Condições de criação / maus tratos
#
#                        Bairro     Distrito Status da solicitação
# 161916                    NaN          NaN            FINALIZADA  \
# 175462                    NaN          NaN            FINALIZADA
# 164465                    NaN          NaN            FINALIZADA
# 100156                    NaN          NaN            FINALIZADO
# 307368                    NaN          NaN            FINALIZADA
# 639594         JARDIM NORONHA          NaN             REALIZADA
# 271226                    NaN        MOEMA            FINALIZADA
# 263476                    NaN      SANTANA            FINALIZADA
# 421461                    NaN  CAMPO LIMPO            FINALIZADA
# 623773  JARDIM SAO BENTO NOVO          NaN             REALIZADA
#
#                 Data do parecer
# 161916      2021-07-19 13:50:04
# 175462      2021-08-26 13:00:31
# 164465      2021-07-27 18:05:34
# 100156      2022-01-19 15:38:48
# 307368      2020-10-14 19:30:50
# 639594  2014-01-20 00:00:00.000
# 271226      2020-10-21 14:23:39
# 263476      2021-01-08 14:41:08
# 421461  2017-09-29 13:44:02.797
# 623773  2013-12-27 00:00:00.000

# %%
df1[df1['Serviço'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Data de abertura, Tema, Assunto, Especificação do assunto, Serviço, Bairro, Distrito, Status da solicitação, Data do parecer]
# Index: []

# %% [markdown]
# #### Deletar o campo que não terá mais utilidade

# %%
df1 = df1.drop('Especificação do assunto', axis=1)

# %% [markdown]
# ## Tratamento dos campos de localização

# %% [markdown]
# #### Os campos 'Bairro' e 'Distrito' são ambíguos, por isso que os valores que estão nulos em 'Distrito' receberão o valor de 'Bairro', caso exista. Além disso, o campo 'Distrito' existe alguns que são número, indicando um distrito que está na metadado disponibilizado neste repositório.

# %% [markdown]
# ### Converter os valores que estão em código para o seu nome original

# %%
distrito = pd.read_csv('codigos_de_distritos.csv', sep=';')

# %%
distrito['Nr Distrito'] = distrito['Nr Distrito'].astype(float)

# %%
distrito
# Out:
#     Nr Distrito       Nome Distrito
# 0           1.0           Agua Rasa
# 1           2.0   Alto de Pinheiros
# 2           3.0          Anhanguera
# 3           4.0          Aricanduva
# 4           5.0         Artur Alvim
# 5           6.0         Barra Funda
# 6           7.0          Bela Vista
# 7           8.0               Belem
# 8           9.0          Bom Retiro
# 9          10.0                Bras
# 10         11.0         Brasilandia
# 11         12.0             Butanta
# 12         13.0        Cachoeirinha
# 13         14.0             Cambuci
# 14         15.0          Campo Belo
# 15         16.0        Campo Grande
# 16         17.0         Campo Limpo
# 17         18.0            Cangaiba
# 18         19.0       Capao Redondo
# 19         20.0              Carrao
# 20         21.0          Casa Verde
# 21         22.0       Cidade Ademar
# 22         23.0        Cidade Dutra
# 23         24.0        Cidade Lider
# 24         25.0   Cidade Tiradentes
# 25         26.0          Consolacao
# 26         27.0             Cursino
# 27         28.0  Ermelino Matarazzo
# 28         29.0      Freguesia Do O
# 29         30.0              Grajau
# 30         31.0          Guaianases
# 31         32.0               Moema
# 32         33.0            Iguatemi
# 33         34.0            Ipiranga
# 34         35.0          Itaim Bibi
# 35         36.0      Itaim Paulista
# 36         37.0            Itaquera
# 37         38.0           Jabaquara
# 38         39.0              Jacana
# 39         40.0             Jaguara
# 40         41.0             Jaguare
# 41         42.0             Jaragua
# 42         43.0       Jardim Angela
# 43         44.0       Jardim Helena
# 44         45.0     Jardim Paulista
# 45         46.0     Jardim Sao Luis
# 46         47.0      Jose Bonifacio
# 47         48.0                Lapa
# 48         49.0           Liberdade
# 49         50.0               Limao
# 50         51.0            Mandaqui
# 51         52.0            Marsilac
# 52         53.0               Mooca
# 53         54.0             Morumbi
# 54         55.0         Parelheiros
# 55         56.0                Pari
# 56         57.0     Parque Do Carmo
# 57         58.0            Pedreira
# 58         59.0               Penha
# 59         60.0            Perdizes
# 60         61.0               Perus
# 61         62.0           Pinheiros
# 62         63.0            Pirituba
# 63         64.0          Ponte Rasa
# 64         65.0      Raposo Tavares
# 65         66.0           Republica
# 66         67.0         Rio Pequeno
# 67         68.0              Sacoma
# 68         69.0       Santa Cecilia
# 69         70.0             Santana
# 70         71.0         Santo Amaro
# 71         72.0           Sao Lucas
# 72         73.0          Sao Mateus
# 73         74.0          Sao Miguel
# 74         75.0          Sao Rafael
# 75         76.0           Sapopemba
# 76         77.0               Saude
# 77         78.0                  Se
# 78         79.0             Socorro
# 79         80.0             Tatuape
# 80         81.0            Tremembe
# 81         82.0            Tucuruvi
# 82         83.0        Vila Andrade
# 83         84.0         Vila Curuca
# 84         85.0        Vila Formosa
# 85         86.0      Vila Guilherme
# 86         87.0          Vila Jacui
# 87         88.0     Vila Leopoldina
# 88         89.0          Vila Maria
# 89         90.0        Vila Mariana
# 90         91.0        Vila Matilde
# 91         92.0       Vila Medeiros
# 92         93.0       Vila Prudente
# 93         94.0          Vila Sonia
# 94         95.0        Sao Domingos
# 95         96.0             Lajeado

# %%
df1['Distrito'] = df1['Distrito'].replace(distrito.set_index('Nr Distrito')['Nome Distrito'])

# %% [markdown]
# ### Preencher valores de 'Distrito' com o de 'Bairro'

# %%
df1.loc[df1['Distrito'].isnull() & df1['Bairro'].notnull(), 'Distrito'] = df1.loc[df1['Distrito'].isnull() & df1['Bairro'].notnull(), 'Bairro']

# %%
df1.sample(10)
# Out:
#                Data de abertura     Tema
# 112011      2022-02-08 20:24:09  Animais  \
# 121399      2022-03-09 18:26:35  Animais
# 552831               2014-08-25      NaN
# 686849  2012-12-28 10:14:16.990      NaN
# 70723       2022-04-12 04:28:59  Animais
# 352379  2019-10-30 20:36:38.545  Animais
# 263794      2020-12-07 19:56:45  Animais
# 913         2023-01-03 15:09:09  Animais
# 619230               2013-11-08      NaN
# 645874               2013-04-01      NaN
#
#                                                 Assunto
# 112011                      Exames, vacinas e castração  \
# 121399                      Exames, vacinas e castração
# 552831                                  Animais / Ratos
# 686849                                    Animais / Cão
# 70723   Animais que transmitem doenças ou risco à saúde
# 352379  Animais que transmitem doenças ou risco à saúde
# 263794                    Criação inadequada de animais
# 913                           Registro de animais - RGA
# 619230                                    Animais / Cão
# 645874                                    Animais / Cão
#
#                                                   Serviço              Bairro
# 112011                 Castrar cães e gatos gratuitamente                 NaN  \
# 121399                 Castrar cães e gatos gratuitamente                 NaN
# 552831                                Reclamação de ratos      JARDIM POPULAR
# 686849                                       Cão Agressor     JARDIM SAO JOAO
# 70723   Escorpião - Solicitar vistoria de local com es...                 NaN
# 352379  Pernilongo/Mosquito - Solicitar vistoria em lo...                 NaN
# 263794         Denunciar condições inadequadas de criação                 NaN
# 913     Registro Geral do Animal (RGA) - Solicitar ide...                 NaN
# 619230                 Condições de criação / maus tratos  JARDIM DOS MANACAS
# 645874                 Condições de criação / maus tratos   JARDIM CASABLANCA
#
#                   Distrito Status da solicitação          Data do parecer
# 112011                 NaN            FINALIZADO      2022-02-15 12:59:11
# 121399                 NaN            INDEFERIDO      2022-03-10 10:22:30
# 552831      JARDIM POPULAR             REALIZADA  2014-09-01 00:00:00.000
# 686849          Guaianases             CANCELADA  2012-12-28 00:00:00.000
# 70723                  NaN            FINALIZADA      2022-05-04 12:57:12
# 352379             SOCORRO            FINALIZADA  2019-11-01 17:14:56.643
# 263794            TUCURUVI            FINALIZADA      2021-01-04 15:14:12
# 913                    NaN            INDEFERIDO      2023-01-04 04:38:30
# 619230  JARDIM DOS MANACAS             REALIZADA  2014-08-18 00:00:00.000
# 645874   JARDIM CASABLANCA             REALIZADA  2013-09-10 00:00:00.000

# %%
df1 = df1.drop('Bairro', axis=1)

# %%
df1.sample(10)
# Out:
#                Data de abertura     Tema
# 59459       2022-09-03 10:35:17  Animais  \
# 690640  2012-01-16 12:33:51.757      NaN
# 647276               2013-04-08      NaN
# 154166      2021-12-14 20:23:17  Animais
# 226048      2021-01-03 02:44:28  Animais
# 656066               2013-05-31      NaN
# 414633  2018-05-14 13:37:52.893  Animais
# 601378               2014-06-11      NaN
# 549666               2014-07-25      NaN
# 51662       2022-08-06 16:24:43  Animais
#
#                                                 Assunto
# 59459   Animais que transmitem doenças ou risco à saúde  \
# 690640           Animais / Abelhas, Vespas, Marimbondos
# 647276                             Animais / Pernilongo
# 154166                 Animais que podem causar doenças
# 226048                      Exames, vacinas e castração
# 656066                                    Animais / Cão
# 414633  Animais que transmitem doenças ou risco à saúde
# 601378           Animais / Abelhas, Vespas, Marimbondos
# 549666                  Animais / Escorpiões ou Aranhas
# 51662                       Exames, vacinas e castração
#
#                                                  Serviço          Distrito
# 59459    Abelhas e Vespas - Solicitar vistoria em ninhos        ANHANGUERA  \
# 690640                        Colméia/Vespeiro instalado        Sao Rafael
# 647276                          Reclamação de Pernilongo     PARQUE GRAJAU
# 154166     Ratos - Solicitar vistoria em local infestado        ARICANDUVA
# 226048                Castrar cães e gatos gratuitamente               NaN
# 656066  Atropelado ou Acidentado vivo e sem proprietário    PARQUE DO LAGO
# 414633     Ratos - Solicitar vistoria em local infestado         AGUA RASA
# 601378                        Colméia/Vespeiro instalado   JARDIM DA SAUDE
# 549666               Reclamação de Escorpiões ou Aranhas  PARQUE ITABERABA
# 51662                 Castrar cães e gatos gratuitamente               NaN
#
#        Status da solicitação          Data do parecer
# 59459             FINALIZADA      2022-09-23 13:14:23
# 690640             REALIZADA  2012-01-19 00:00:00.000
# 647276             REALIZADA  2013-08-27 00:00:00.000
# 154166            FINALIZADA      2021-12-21 11:29:13
# 226048            FINALIZADA      2021-01-04 16:34:39
# 656066             REALIZADA  2017-05-17 12:35:23.890
# 414633            FINALIZADA  2018-07-11 13:12:45.083
# 601378             REALIZADA  2015-06-02 00:00:00.000
# 549666             REALIZADA  2014-08-01 00:00:00.000
# 51662             INDEFERIDO      2022-08-16 18:10:16

# %%
df1['Distrito'].isnull().sum()
# Out:
# 233978

# %%
df1['Distrito'].notnull().sum()
# Out:
# 488423

# %% [markdown]
# ## Tratamento das descrições (Assunto, Serviço)

# %%
df2 = df1.rename({'Assunto': 'Tipo de Serviço'}, axis=1)

# %%
df2.sample()
# Out:
#                Data de abertura     Tema        Tipo de Serviço
# 356122  2019-11-30 10:49:48.765  Animais  Animal em via pública  \
#
#                                                   Serviço      Distrito
# 356122  Avaliação de animal em sofrimento sem propriet...  VILA FORMOSA  \
#
#        Status da solicitação          Data do parecer
# 356122            FINALIZADA  2020-04-13 19:57:45.119

# %%
df2['Tipo de Serviço'].drop_duplicates()
# Out:
# 0                                Registro de animais - RGA
# 1                              Exames, vacinas e castração
# 3                                        Adoção de animais
# 4                            Criação inadequada de animais
# 6                                       Animais silvestres
# 9                                    Animal em via pública
# 14         Animais que transmitem doenças ou risco à saúde
# 23                            Animal agressor e/ou invasor
# 66        Dengue/chikungunya/zika (mosquito aedes aegypti)
# 26265                                  Comércio de animais
# 128038                    Animais que podem causar doenças
# 361615                                      Animais/Aranha
# 386661                                  Animais/Carrapatos
# 392961                                      Animais/Pulgas
# 397007                                      Animais/barata
# 547255                                       Animais / Cão
# 547259                                      Animais / Gato
# 547260                                     Animais / Ratos
# 547261              Animais / Abelhas, Vespas, Marimbondos
# 547267                                             Animais
# 547270                                Animais / Pernilongo
# 547278                                  Animais / Morcegos
# 547285                     Animais / Escorpiões ou Aranhas
# 547294                                    Animais / Pombos
# 547304                                Animais / Carrapatos
# 547337              Animais / Ocorrencias com outros tipos
# 547455                                   Animais / Formiga
# 547513                                   Animais / Baratas
# 547523                                    Animais / Pulgas
# 547766                                    Animais / Moscas
# 547806                                    Animais / Cavalo
# 547808                                  Vistoria / Animais
# 558700                                Animais / Escorpiões
# 558861                                   Animais / Aranhas
# Name: Tipo de Serviço, dtype: object

# %%
df2[['Tipo de Serviço', 'Serviço']].drop_duplicates()
# Out:
#                                          Tipo de Serviço
# 0                              Registro de animais - RGA  \
# 1                            Exames, vacinas e castração
# 3                                      Adoção de animais
# 4                          Criação inadequada de animais
# 6                                     Animais silvestres
# 9                                  Animal em via pública
# 12                                 Animal em via pública
# 14       Animais que transmitem doenças ou risco à saúde
# 15       Animais que transmitem doenças ou risco à saúde
# 19       Animais que transmitem doenças ou risco à saúde
# 21       Animais que transmitem doenças ou risco à saúde
# 23                          Animal agressor e/ou invasor
# 25                          Animal agressor e/ou invasor
# 66      Dengue/chikungunya/zika (mosquito aedes aegypti)
# 69       Animais que transmitem doenças ou risco à saúde
# 71                             Registro de animais - RGA
# 109                                Animal em via pública
# 227      Animais que transmitem doenças ou risco à saúde
# 501                          Exames, vacinas e castração
# 1276                           Registro de animais - RGA
# 1460                                  Animais silvestres
# 26265                                Comércio de animais
# 34365                                Comércio de animais
# 40401                                 Animais silvestres
# 46546                                 Animais silvestres
# 67423                                Comércio de animais
# 88229                                Comércio de animais
# 128038                  Animais que podem causar doenças
# 128051                  Animais que podem causar doenças
# 128056                  Animais que podem causar doenças
# 128063                  Animais que podem causar doenças
# 128068                             Animal em via pública
# 128086                  Animais que podem causar doenças
# 128122                  Animais que podem causar doenças
# 147468                         Registro de animais - RGA
# 148018                       Exames, vacinas e castração
# 361615                                    Animais/Aranha
# 386661                                Animais/Carrapatos
# 392961                                    Animais/Pulgas
# 397007                                    Animais/barata
# 547255                                     Animais / Cão
# 547259                                    Animais / Gato
# 547260                                   Animais / Ratos
# 547261            Animais / Abelhas, Vespas, Marimbondos
# 547262                                     Animais / Cão
# 547265                                     Animais / Cão
# 547267                                           Animais
# 547270                              Animais / Pernilongo
# 547278                                Animais / Morcegos
# 547279                                    Animais / Gato
# 547281                                    Animais / Gato
# 547285                   Animais / Escorpiões ou Aranhas
# 547294                                  Animais / Pombos
# 547304                              Animais / Carrapatos
# 547310                                     Animais / Cão
# 547337            Animais / Ocorrencias com outros tipos
# 547438                                    Animais / Gato
# 547447                                    Animais / Gato
# 547455                                 Animais / Formiga
# 547513                                 Animais / Baratas
# 547523                                  Animais / Pulgas
# 547766                                  Animais / Moscas
# 547806                                  Animais / Cavalo
# 547808                                Vistoria / Animais
# 548045                                    Animais / Gato
# 548131                                  Animais / Cavalo
# 548160                                Vistoria / Animais
# 548547                                     Animais / Cão
# 552522                                Vistoria / Animais
# 554332                                Vistoria / Animais
# 558700                              Animais / Escorpiões
# 558861                                 Animais / Aranhas
# 603218                                Animais / Morcegos
# 699127                                     Animais / Cão
# 700865            Animais / Abelhas, Vespas, Marimbondos
#
#                                                   Serviço
# 0       Avisar  sobre animal encontrado com Registro G...
# 1                      Castrar cães e gatos gratuitamente
# 3                                     Adotar cães e gatos
# 4              Denunciar condições inadequadas de criação
# 6       Animais silvestres feridos ? Solicitar atendim...
# 9        Solicitar remoção de animal morto em via pública
# 12      Avaliação de animal em sofrimento sem propriet...
# 14      Pernilongo/Mosquito - Solicitar vistoria em lo...
# 15           Morcegos - Reclamar sobre local com morcegos
# 19          Ratos - Solicitar vistoria em local infestado
# 21        Abelhas e Vespas - Solicitar vistoria em ninhos
# 23          Avisar sobre animal agressor em vias públicas
# 25      Cães e gatos invasores de instituições pública...
# 66      Água limpa e parada ? Solicitar vistoria de lo...
# 69      Escorpião - Solicitar vistoria de local com es...
# 71      Registro Geral do Animal (RGA) - Solicitar ide...
# 109      Animal de grande porte solto - Solicitar remoção
# 227        Pombos - Solicitar vistoria em local infestado
# 501      Castrar cães e gatos de protetores independentes
# 1276     Registro Geral do Animal (RGA) - Atualizar dados
# 1460      Animais silvestres ? Agendar entrega voluntária
# 26265   Cadastro Municipal de Comércio de Animais (CMC...
# 34365   Cadastro Municipal de Comércio de Animais (CMC...
# 40401   Animais silvestres feridos – Solicitar atendim...
# 46546     Animais silvestres – Agendar entrega voluntária
# 67423   Cadastro Municipal de Comércio de Animais (CMC...
# 88229   Cadastro Municipal de Comércio de Animais (CMC...
# 128038  Pernilongo/Mosquito - Solicitar vistoria em lo...
# 128051      Ratos - Solicitar vistoria em local infestado
# 128056    Abelhas e Vespas - Solicitar vistoria em ninhos
# 128063       Morcegos - Reclamar sobre local com morcegos
# 128068             Remoção de animal morto em via pública
# 128086     Pombos - Solicitar vistoria em local infestado
# 128122  Escorpião - Solicitar vistoria de local com es...
# 147468  TESTE TESTE TESTE - Registro Geral do Animal (...
# 148018  TESTE TESTE TESTE - Castrar cães e gatos gratu...
# 361615                              Reclamação de Aranhas
# 386661                           Reclamação de carrapatos
# 392961                               Reclamação de pulgas
# 397007                              Reclamação de baratas
# 547255                 Condições de criação / maus tratos
# 547259                 Condições de criação / maus tratos
# 547260                                Reclamação de ratos
# 547261                         Colméia/Vespeiro instalado
# 547262   Atropelado ou Acidentado vivo e sem proprietário
# 547265                                       Cão Agressor
# 547267           Remoção de animal morto em vias publicas
# 547270                           Reclamação de Pernilongo
# 547278                            Ocorrências com morcego
# 547279                        Atropelado sem proprietário
# 547281                                   Invadiu o local
# 547285                Reclamação de Escorpiões ou Aranhas
# 547294                               Reclamação de Pombos
# 547304                           Reclamação de Carrapatos
# 547310                                    Invadiu o local
# 547337                 Ocorrências / Condições de criação
# 547438                                      Gato agressor
# 547447                        Acidentado sem proprietário
# 547455                             Reclamação de Formigas
# 547513                              Reclamação de Baratas
# 547523                               Reclamação de Pulgas
# 547766                               Reclamação de Moscas
# 547806                               Diversas ocorrências
# 547808                           Trânsito de boiadas a pé
# 548045                            Gato encontrado com RGA
# 548131                               Condições de criação
# 548160                                         Em parques
# 548547                             Cão encontrado com RGA
# 552522                  Falta de placa sobre animal feroz
# 554332                        Cães em vigilância bancária
# 558700                           Reclamação de Escorpiões
# 558861                              Reclamação de Aranhas
# 603218                             Ocorrências rotineiras
# 699127                               Solto em via pública
# 700865          Remoção de Abelhas, Vespas ou Marimbondos

# %% [markdown]
# ### Padronizar o Tipo de Serviço

# %%
df2.loc[df2['Tipo de Serviço'].str.contains('Animais[ |/]') & df2['Tipo de Serviço']
        .str.match('^(?!.*(Cão|Gato|Cavalo|silvestres|RGA|agressor|via))'), 'Tipo de Serviço'
       ] = 'Animais que transmitem doenças ou risco à saúde'

# %%
df2[['Tipo de Serviço', 'Serviço']].drop_duplicates()
# Out:
#                                          Tipo de Serviço
# 0                              Registro de animais - RGA  \
# 1                            Exames, vacinas e castração
# 3                                      Adoção de animais
# 4                          Criação inadequada de animais
# 6                                     Animais silvestres
# 9                                  Animal em via pública
# 12                                 Animal em via pública
# 14       Animais que transmitem doenças ou risco à saúde
# 15       Animais que transmitem doenças ou risco à saúde
# 19       Animais que transmitem doenças ou risco à saúde
# 21       Animais que transmitem doenças ou risco à saúde
# 23                          Animal agressor e/ou invasor
# 25                          Animal agressor e/ou invasor
# 66      Dengue/chikungunya/zika (mosquito aedes aegypti)
# 69       Animais que transmitem doenças ou risco à saúde
# 71                             Registro de animais - RGA
# 109                                Animal em via pública
# 227      Animais que transmitem doenças ou risco à saúde
# 501                          Exames, vacinas e castração
# 1276                           Registro de animais - RGA
# 1460                                  Animais silvestres
# 26265                                Comércio de animais
# 34365                                Comércio de animais
# 40401                                 Animais silvestres
# 46546                                 Animais silvestres
# 67423                                Comércio de animais
# 88229                                Comércio de animais
# 128068                             Animal em via pública
# 147468                         Registro de animais - RGA
# 148018                       Exames, vacinas e castração
# 361615   Animais que transmitem doenças ou risco à saúde
# 386661   Animais que transmitem doenças ou risco à saúde
# 392961   Animais que transmitem doenças ou risco à saúde
# 397007   Animais que transmitem doenças ou risco à saúde
# 547255                                     Animais / Cão
# 547259                                    Animais / Gato
# 547260   Animais que transmitem doenças ou risco à saúde
# 547261   Animais que transmitem doenças ou risco à saúde
# 547262                                     Animais / Cão
# 547265                                     Animais / Cão
# 547267                                           Animais
# 547270   Animais que transmitem doenças ou risco à saúde
# 547278   Animais que transmitem doenças ou risco à saúde
# 547279                                    Animais / Gato
# 547281                                    Animais / Gato
# 547285   Animais que transmitem doenças ou risco à saúde
# 547294   Animais que transmitem doenças ou risco à saúde
# 547304   Animais que transmitem doenças ou risco à saúde
# 547310                                     Animais / Cão
# 547337   Animais que transmitem doenças ou risco à saúde
# 547438                                    Animais / Gato
# 547447                                    Animais / Gato
# 547455   Animais que transmitem doenças ou risco à saúde
# 547513   Animais que transmitem doenças ou risco à saúde
# 547523   Animais que transmitem doenças ou risco à saúde
# 547766   Animais que transmitem doenças ou risco à saúde
# 547806                                  Animais / Cavalo
# 547808                                Vistoria / Animais
# 548045                                    Animais / Gato
# 548131                                  Animais / Cavalo
# 548160                                Vistoria / Animais
# 548547                                     Animais / Cão
# 552522                                Vistoria / Animais
# 554332                                Vistoria / Animais
# 558700   Animais que transmitem doenças ou risco à saúde
# 603218   Animais que transmitem doenças ou risco à saúde
# 699127                                     Animais / Cão
# 700865   Animais que transmitem doenças ou risco à saúde
#
#                                                   Serviço
# 0       Avisar  sobre animal encontrado com Registro G...
# 1                      Castrar cães e gatos gratuitamente
# 3                                     Adotar cães e gatos
# 4              Denunciar condições inadequadas de criação
# 6       Animais silvestres feridos ? Solicitar atendim...
# 9        Solicitar remoção de animal morto em via pública
# 12      Avaliação de animal em sofrimento sem propriet...
# 14      Pernilongo/Mosquito - Solicitar vistoria em lo...
# 15           Morcegos - Reclamar sobre local com morcegos
# 19          Ratos - Solicitar vistoria em local infestado
# 21        Abelhas e Vespas - Solicitar vistoria em ninhos
# 23          Avisar sobre animal agressor em vias públicas
# 25      Cães e gatos invasores de instituições pública...
# 66      Água limpa e parada ? Solicitar vistoria de lo...
# 69      Escorpião - Solicitar vistoria de local com es...
# 71      Registro Geral do Animal (RGA) - Solicitar ide...
# 109      Animal de grande porte solto - Solicitar remoção
# 227        Pombos - Solicitar vistoria em local infestado
# 501      Castrar cães e gatos de protetores independentes
# 1276     Registro Geral do Animal (RGA) - Atualizar dados
# 1460      Animais silvestres ? Agendar entrega voluntária
# 26265   Cadastro Municipal de Comércio de Animais (CMC...
# 34365   Cadastro Municipal de Comércio de Animais (CMC...
# 40401   Animais silvestres feridos – Solicitar atendim...
# 46546     Animais silvestres – Agendar entrega voluntária
# 67423   Cadastro Municipal de Comércio de Animais (CMC...
# 88229   Cadastro Municipal de Comércio de Animais (CMC...
# 128068             Remoção de animal morto em via pública
# 147468  TESTE TESTE TESTE - Registro Geral do Animal (...
# 148018  TESTE TESTE TESTE - Castrar cães e gatos gratu...
# 361615                              Reclamação de Aranhas
# 386661                           Reclamação de carrapatos
# 392961                               Reclamação de pulgas
# 397007                              Reclamação de baratas
# 547255                 Condições de criação / maus tratos
# 547259                 Condições de criação / maus tratos
# 547260                                Reclamação de ratos
# 547261                         Colméia/Vespeiro instalado
# 547262   Atropelado ou Acidentado vivo e sem proprietário
# 547265                                       Cão Agressor
# 547267           Remoção de animal morto em vias publicas
# 547270                           Reclamação de Pernilongo
# 547278                            Ocorrências com morcego
# 547279                        Atropelado sem proprietário
# 547281                                   Invadiu o local
# 547285                Reclamação de Escorpiões ou Aranhas
# 547294                               Reclamação de Pombos
# 547304                           Reclamação de Carrapatos
# 547310                                    Invadiu o local
# 547337                 Ocorrências / Condições de criação
# 547438                                      Gato agressor
# 547447                        Acidentado sem proprietário
# 547455                             Reclamação de Formigas
# 547513                              Reclamação de Baratas
# 547523                               Reclamação de Pulgas
# 547766                               Reclamação de Moscas
# 547806                               Diversas ocorrências
# 547808                           Trânsito de boiadas a pé
# 548045                            Gato encontrado com RGA
# 548131                               Condições de criação
# 548160                                         Em parques
# 548547                             Cão encontrado com RGA
# 552522                  Falta de placa sobre animal feroz
# 554332                        Cães em vigilância bancária
# 558700                           Reclamação de Escorpiões
# 603218                             Ocorrências rotineiras
# 699127                               Solto em via pública
# 700865          Remoção de Abelhas, Vespas ou Marimbondos

# %%
df2['Tipo de Serviço'] = df2['Tipo de Serviço'].str.replace('Animais / ', '')

# %%
df2['Tipo de Serviço'] = df2['Tipo de Serviço'].str.replace(' / Animais', '')

# %%
df2['Tipo de Serviço'] = df2['Tipo de Serviço'].str.replace('Dengue/chikungunya/zika (mosquito aedes aegypti)', 'Vistoria')

# %%
df2['Tipo de Serviço'].drop_duplicates()
# Out:
# 0                               Registro de animais - RGA
# 1                             Exames, vacinas e castração
# 3                                       Adoção de animais
# 4                           Criação inadequada de animais
# 6                                      Animais silvestres
# 9                                   Animal em via pública
# 14        Animais que transmitem doenças ou risco à saúde
# 23                           Animal agressor e/ou invasor
# 66                                               Vistoria
# 26265                                 Comércio de animais
# 547255                                                Cão
# 547259                                               Gato
# 547267                                            Animais
# 547806                                             Cavalo
# Name: Tipo de Serviço, dtype: object

# %% [markdown]
# ### Apagar os registros de teste

# %%
df2 = df2.drop(df2.loc[df1['Serviço'].str.contains('TESTE', regex=True)].index)

# %% [markdown]
# ### Padronizar o Serviço

# %% [markdown]
# #### Tratar o Tipo de Serviço 'Animais que transmitem doenças ou risco à saúde'

# %%
df2.loc[df2['Tipo de Serviço'] == 'Animais que transmitem doenças ou risco à saúde', 'Serviço'].drop_duplicates().sort_values()
# Out:
# 21          Abelhas e Vespas - Solicitar vistoria em ninhos
# 547261                           Colméia/Vespeiro instalado
# 69        Escorpião - Solicitar vistoria de local com es...
# 15             Morcegos - Reclamar sobre local com morcegos
# 547337                   Ocorrências / Condições de criação
# 547278                              Ocorrências com morcego
# 603218                               Ocorrências rotineiras
# 14        Pernilongo/Mosquito - Solicitar vistoria em lo...
# 227          Pombos - Solicitar vistoria em local infestado
# 19            Ratos - Solicitar vistoria em local infestado
# 361615                                Reclamação de Aranhas
# 547513                                Reclamação de Baratas
# 547304                             Reclamação de Carrapatos
# 558700                             Reclamação de Escorpiões
# 547285                  Reclamação de Escorpiões ou Aranhas
# 547455                               Reclamação de Formigas
# 547766                                 Reclamação de Moscas
# 547270                             Reclamação de Pernilongo
# 547294                                 Reclamação de Pombos
# 547523                                 Reclamação de Pulgas
# 397007                                Reclamação de baratas
# 386661                             Reclamação de carrapatos
# 392961                                 Reclamação de pulgas
# 547260                                  Reclamação de ratos
# 700865            Remoção de Abelhas, Vespas ou Marimbondos
# Name: Serviço, dtype: object

# %%
df3 = df2.copy()

# %% [markdown]
# #### Juntar Serviços iguais com nomes diferentes

# %%
df3.loc[(df3['Serviço'].str.contains('Pernilongo/Mosquito', regex=True)) | (df3['Serviço'] == 'Reclamação de Pernilongo'), 'Serviço'] = 'Reclamação de Pernilongos e Mosquitos'

# %%
df3.loc[(df3['Serviço'].str.contains('Abelha')) | (df3['Serviço'] == 'Colméia/Vespeiro instalado'), 'Serviço'] = 'Abelhas, Vespas ou Marimbondos'

# %%
df3.loc[df3['Serviço'].str.contains('Escorpião', regex=True), 'Serviço'] = 'Escorpiões'

# %%
df3.loc[df3['Serviço'] == 'Reclamação de Escorpião', 'Serviço'] = 'Reclamação de Escorpiões'

# %%
df3.loc[df3['Serviço'] == 'Ocorrências com morcego', 'Serviço'] = 'Reclamação de Morcegos'

# %% [markdown]
# #### Juntar diversos Serviços que estão duplicados, seguindo um padrão igual

# %%
df3.loc[df3['Tipo de Serviço'] == 'Animais que transmitem doenças ou risco à saúde', 'Serviço'] = df3.loc[df3[
    'Tipo de Serviço'] == 'Animais que transmitem doenças ou risco à saúde', 'Serviço'].str.replace(r' -.*', '', regex=True)

# %%
df3.loc[df3['Serviço'].str.split().str.len() == 1, 'Serviço'] = 'Reclamação de ' + df3['Serviço']

# %%
df3.loc[df3['Tipo de Serviço'] == 'Animais que transmitem doenças ou risco à saúde', 'Serviço'].drop_duplicates().sort_values()
# Out:
# 21                                 Abelhas e Vespas
# 547337           Ocorrências / Condições de criação
# 603218                       Ocorrências rotineiras
# 361615                        Reclamação de Aranhas
# 547513                        Reclamação de Baratas
# 547304                     Reclamação de Carrapatos
# 69                         Reclamação de Escorpiões
# 547285          Reclamação de Escorpiões ou Aranhas
# 547455                       Reclamação de Formigas
# 15                           Reclamação de Morcegos
# 547766                         Reclamação de Moscas
# 14            Reclamação de Pernilongos e Mosquitos
# 227                            Reclamação de Pombos
# 547523                         Reclamação de Pulgas
# 19                              Reclamação de Ratos
# 397007                        Reclamação de baratas
# 386661                     Reclamação de carrapatos
# 392961                         Reclamação de pulgas
# 547260                          Reclamação de ratos
# 547261    Remoção de Abelhas, Vespas ou Marimbondos
# Name: Serviço, dtype: object

# %% [markdown]
# #### Tratar os Tipos de Serviços que NÃO são 'Animais que transmitem doenças ou risco à saúde'

# %% [markdown]
# #### Retirar caracteres não úteis

# %%
df3['Serviço'] = df3['Serviço'].str.replace('?', '-')
df3['Serviço'] = df3['Serviço'].str.replace('–', '-')
df3['Serviço'] = df3['Serviço'].str.replace('Invadiu o local ', 'Invadiu o local')

# %%
pd.set_option('display.max_colwidth', None)
df3.loc[df3['Tipo de Serviço'] != 'Animais que transmitem doenças ou risco à saúde', 'Serviço'].drop_duplicates().sort_values()
# Out:
# 547447                                                          Acidentado sem proprietário
# 3                                                                       Adotar cães e gatos
# 1460                                        Animais silvestres - Agendar entrega voluntária
# 6                            Animais silvestres feridos - Solicitar atendimento veterinário
# 109                                        Animal de grande porte solto - Solicitar remoção
# 547262                                     Atropelado ou Acidentado vivo e sem proprietário
# 547279                                                          Atropelado sem proprietário
# 12        Avaliação de animal em sofrimento sem proprietário para eutanásia (morte sem dor)
# 0                        Avisar  sobre animal encontrado com Registro Geral do Animal (RGA)
# 23                                            Avisar sobre animal agressor em vias públicas
# 34365                  Cadastro Municipal de Comércio de Animais (CMCA) - Cancelar cadastro
# 26265                    Cadastro Municipal de Comércio de Animais (CMCA) - Fazer inscrição
# 501                                        Castrar cães e gatos de protetores independentes
# 1                                                        Castrar cães e gatos gratuitamente
# 548131                                                                 Condições de criação
# 547255                                                   Condições de criação / maus tratos
# 25                    Cães e gatos invasores de instituições públicas - Solicitar avaliação
# 554332                                                          Cães em vigilância bancária
# 547265                                                                         Cão Agressor
# 548547                                                               Cão encontrado com RGA
# 4                                                Denunciar condições inadequadas de criação
# 547806                                                                 Diversas ocorrências
# 548160                                                                           Em parques
# 552522                                                    Falta de placa sobre animal feroz
# 547438                                                                        Gato agressor
# 548045                                                              Gato encontrado com RGA
# 547281                                                                      Invadiu o local
# 1276                                       Registro Geral do Animal (RGA) - Atualizar dados
# 71                          Registro Geral do Animal (RGA) - Solicitar identidade do animal
# 128068                                               Remoção de animal morto em via pública
# 547267                                             Remoção de animal morto em vias publicas
# 9                                          Solicitar remoção de animal morto em via pública
# 699127                                                                 Solto em via pública
# 547808                                                             Trânsito de boiadas a pé
# 66                            Água limpa e parada - Solicitar vistoria de local com acúmulo
# Name: Serviço, dtype: object

# %% [markdown]
# #### Padronizar os 'Serviços' que contém 'Acidentado' ou 'Atropelado'

# %%
df3.loc[df3['Serviço'].str.contains('Atropelado') | df3['Serviço'].str.contains('Acidentado'), 'Serviço'
       ] = 'Atropelado ou Acidentado vivo e sem proprietário'

# %% [markdown]
# #### Padronizar 'Condições de criação' e 'Denunciar condições inadequadas de criação' com 'Condições de criação / maus tratos'

# %%
df3.loc[df3['Serviço'].str.match('.*ondições'), 'Serviço'
       ] = 'Condições de criação / maus tratos'

# %% [markdown]
# #### Padronizar os que tem 'Remoção de animal morto em via pública' (3)

# %%
df3.loc[df3['Serviço'].str.match('.*morto em via.*'), 'Serviço'
       ] = 'Remoção de animal morto em via pública'

# %% [markdown]
# #### Padronizar "Castrar Cães e Gatos"

# %%
df3.loc[df3['Serviço'] == 'Castrar cães e gatos de protetores independentes', 'Serviço'] = 'Castrar cães e gatos gratuitamente'

# %% [markdown]
# #### Usar o 'Tipo de Serviço' para preencher 'Serviços' não tão bem descritos, como 'Solto em via pública'

# %%
condicoes = (df3['Serviço'] == 'Em parques') | (df3['Serviço'] == 'Invadiu o local') | (df3['Serviço'] == 'Solto em via pública')
df3.loc[condicoes, 'Serviço'] = df3.loc[condicoes, 'Tipo de Serviço'].str.cat(df3.loc[condicoes, 'Serviço'], sep=' ')

# %%
condicoes = (df3['Serviço'] == 'Diversas ocorrências') | (df3['Serviço'] == 'Ocorrências rotineiras')
df3.loc[condicoes, 'Serviço'] = df3.loc[condicoes, 'Tipo de Serviço'].str.cat(df3.loc[condicoes, 'Serviço'], sep=' - ')

# %%
pd.set_option('display.max_colwidth', None)
df3.loc[df3['Tipo de Serviço'] != 'Animais que transmitem doenças ou risco à saúde', 'Serviço'].drop_duplicates().sort_values()
# Out:
# 3                                                                       Adotar cães e gatos
# 1460                                        Animais silvestres - Agendar entrega voluntária
# 6                            Animais silvestres feridos - Solicitar atendimento veterinário
# 109                                        Animal de grande porte solto - Solicitar remoção
# 547262                                     Atropelado ou acidentado vivo e sem proprietário
# 12        Avaliação de animal em sofrimento sem proprietário para eutanásia (morte sem dor)
# 0                        Avisar  sobre animal encontrado com Registro Geral do Animal (RGA)
# 23                                            Avisar sobre animal agressor em vias públicas
# 34365                  Cadastro Municipal de Comércio de Animais (CMCA) - Cancelar cadastro
# 26265                    Cadastro Municipal de Comércio de Animais (CMCA) - Fazer inscrição
# 1                                                        Castrar cães e gatos gratuitamente
# 547806                                                        Cavalo - Diversas ocorrências
# 4                                                        Condições de criação / Maus tratos
# 25                    Cães e gatos invasores de instituições públicas - Solicitar avaliação
# 554332                                                          Cães em vigilância bancária
# 547265                                                                         Cão agressor
# 548547                                                               Cão encontrado com RGA
# 547310                                                                  Cão invadiu o local
# 699127                                                             Cão solto em via pública
# 552522                                                    Falta de placa sobre animal feroz
# 547438                                                                        Gato agressor
# 548045                                                              Gato encontrado com RGA
# 547281                                                                 Gato invadiu o local
# 1276                                       Registro Geral do Animal (RGA) - Atualizar dados
# 71                          Registro Geral do Animal (RGA) - Solicitar identidade do animal
# 9                                                    Remoção de animal morto em via pública
# 547808                                                             Trânsito de boiadas a pé
# 548160                                                                  Vistoria em parques
# 66                            Água limpa e parada - Solicitar vistoria de local com acúmulo
# Name: Serviço, dtype: object

# %%
df3[['Tipo de Serviço', 'Serviço']].drop_duplicates().sort_values(by=['Tipo de Serviço', 'Serviço'])
# Out:
#                                         Tipo de Serviço
# 3                                     Adoção de animais  \
# 547267                                          Animais
# 21      Animais que transmitem doenças ou risco à saúde
# 547261  Animais que transmitem doenças ou risco à saúde
# 603218  Animais que transmitem doenças ou risco à saúde
# 547337  Animais que transmitem doenças ou risco à saúde
# 361615  Animais que transmitem doenças ou risco à saúde
# 397007  Animais que transmitem doenças ou risco à saúde
# 386661  Animais que transmitem doenças ou risco à saúde
# 69      Animais que transmitem doenças ou risco à saúde
# 547285  Animais que transmitem doenças ou risco à saúde
# 547455  Animais que transmitem doenças ou risco à saúde
# 15      Animais que transmitem doenças ou risco à saúde
# 547766  Animais que transmitem doenças ou risco à saúde
# 14      Animais que transmitem doenças ou risco à saúde
# 227     Animais que transmitem doenças ou risco à saúde
# 392961  Animais que transmitem doenças ou risco à saúde
# 19      Animais que transmitem doenças ou risco à saúde
# 1460                                 Animais silvestres
# 6                                    Animais silvestres
# 23                         Animal agressor e/ou invasor
# 25                         Animal agressor e/ou invasor
# 109                               Animal em via pública
# 12                                Animal em via pública
# 9                                 Animal em via pública
# 547806                                           Cavalo
# 548131                                           Cavalo
# 34365                               Comércio de animais
# 26265                               Comércio de animais
# 4                         Criação inadequada de animais
# 547262                                              Cão
# 547255                                              Cão
# 547265                                              Cão
# 548547                                              Cão
# 547310                                              Cão
# 699127                                              Cão
# 1                           Exames, vacinas e castração
# 547279                                             Gato
# 547259                                             Gato
# 547438                                             Gato
# 548045                                             Gato
# 547281                                             Gato
# 0                             Registro de animais - RGA
# 1276                          Registro de animais - RGA
# 71                            Registro de animais - RGA
# 554332                                         Vistoria
# 552522                                         Vistoria
# 547808                                         Vistoria
# 548160                                         Vistoria
# 66                                             Vistoria
#
#                                                                                   Serviço
# 3                                                                     Adotar cães e gatos
# 547267                                             Remoção de animal morto em via pública
# 21                                                                       Abelhas e vespas
# 547261                                                     Abelhas, Vespas ou Marimbondos
# 603218           Animais que transmitem doenças ou risco à saúde - Ocorrências rotineiras
# 547337                                                 Condições de criação / Maus tratos
# 361615                                                              Reclamação de aranhas
# 397007                                                              Reclamação de baratas
# 386661                                                           Reclamação de carrapatos
# 69                                                               Reclamação de escorpiões
# 547285                                                Reclamação de escorpiões ou aranhas
# 547455                                                             Reclamação de formigas
# 15                                                                 Reclamação de morcegos
# 547766                                                               Reclamação de moscas
# 14                                                  Reclamação de pernilongos e mosquitos
# 227                                                                  Reclamação de pombos
# 392961                                                               Reclamação de pulgas
# 19                                                                    Reclamação de ratos
# 1460                                      Animais silvestres - Agendar entrega voluntária
# 6                          Animais silvestres feridos - Solicitar atendimento veterinário
# 23                                          Avisar sobre animal agressor em vias públicas
# 25                  Cães e gatos invasores de instituições públicas - Solicitar avaliação
# 109                                      Animal de grande porte solto - Solicitar remoção
# 12      Avaliação de animal em sofrimento sem proprietário para eutanásia (morte sem dor)
# 9                                                  Remoção de animal morto em via pública
# 547806                                                      Cavalo - Diversas ocorrências
# 548131                                                 Condições de criação / Maus tratos
# 34365                Cadastro Municipal de Comércio de Animais (CMCA) - Cancelar cadastro
# 26265                  Cadastro Municipal de Comércio de Animais (CMCA) - Fazer inscrição
# 4                                                      Condições de criação / Maus tratos
# 547262                                   Atropelado ou acidentado vivo e sem proprietário
# 547255                                                 Condições de criação / Maus tratos
# 547265                                                                       Cão agressor
# 548547                                                             Cão encontrado com RGA
# 547310                                                                Cão invadiu o local
# 699127                                                           Cão solto em via pública
# 1                                                      Castrar cães e gatos gratuitamente
# 547279                                   Atropelado ou acidentado vivo e sem proprietário
# 547259                                                 Condições de criação / Maus tratos
# 547438                                                                      Gato agressor
# 548045                                                            Gato encontrado com RGA
# 547281                                                               Gato invadiu o local
# 0                      Avisar  sobre animal encontrado com Registro Geral do Animal (RGA)
# 1276                                     Registro Geral do Animal (RGA) - Atualizar dados
# 71                        Registro Geral do Animal (RGA) - Solicitar identidade do animal
# 554332                                                        Cães em vigilância bancária
# 552522                                                  Falta de placa sobre animal feroz
# 547808                                                           Trânsito de boiadas a pé
# 548160                                                                Vistoria em parques
# 66                          Água limpa e parada - Solicitar vistoria de local com acúmulo

# %%
df3.sample(10)
# Out:
#                Data de abertura     Tema
# 171721      2021-08-09 13:06:27  Animais  \
# 691883  2012-01-21 05:24:00.993      NaN
# 566383               2014-11-24      NaN
# 158576      2021-07-02 13:45:08  Animais
# 456351  2016-08-04 16:10:20.683  Animais
# 513981  2015-11-29 22:32:40.447  Animais
# 255625      2021-03-16 15:17:58  Animais
# 696839  2012-02-13 09:04:17.953      NaN
# 42434       2022-07-08 13:20:35  Animais
# 129115      2021-10-05 15:50:08  Animais
#
#                                         Tipo de Serviço
# 171721                      Exames, vacinas e castração  \
# 691883  Animais que transmitem doenças ou risco à saúde
# 566383  Animais que transmitem doenças ou risco à saúde
# 158576                     Animal agressor e/ou invasor
# 456351                            Animal em via pública
# 513981                            Animal em via pública
# 255625                      Exames, vacinas e castração
# 696839                                          Animais
# 42434                       Exames, vacinas e castração
# 129115  Animais que transmitem doenças ou risco à saúde
#
#                                                                                   Serviço
# 171721                                                 Castrar cães e gatos gratuitamente  \
# 691883                                                                Reclamação de ratos
# 566383                                                     Abelhas, Vespas ou Marimbondos
# 158576                                      Avisar sobre animal agressor em vias públicas
# 456351  Avaliação de animal em sofrimento sem proprietário para eutanásia (morte sem dor)
# 513981                                             Remoção de animal morto em via pública
# 255625                                                 Castrar cães e gatos gratuitamente
# 696839                                             Remoção de animal morto em via pública
# 42434                                                  Castrar cães e gatos gratuitamente
# 129115                                                                   Abelhas e vespas
#
#                 Distrito Status da solicitação          Data do parecer
# 171721               NaN            INDEFERIDO      2021-08-11 14:34:45
# 691883          Cangaiba            FINALIZADA  2013-02-04 00:00:00.000
# 566383  VILA NOVA SAVOIA            FINALIZADA  2014-12-02 00:00:00.000
# 158576          PEDREIRA            FINALIZADA      2021-07-02 15:09:25
# 456351       VILA CURUCA            FINALIZADA  2018-04-12 11:52:22.461
# 513981        SAO RAFAEL            FINALIZADA  2018-04-12 11:59:53.855
# 255625               NaN            INDEFERIDO      2021-03-27 18:06:05
# 696839    Vila Guilherme            FINALIZADA  2012-02-23 12:57:31.673
# 42434                NaN            FINALIZADA      2022-07-08 17:19:04
# 129115           BUTANTA            FINALIZADA      2021-10-08 17:52:27

# %% [markdown]
# ### Realizar um capitalize em cada "Serviço" caso gouver necessidade

# %%
def capitalize(servico):
    # Descobrir o sinal que a frase usa
    sinal = re.findall(r" - | / ", servico)
    
    if sinal:
        # Dividindo a frase em duas partes: antes e depois do traço ou da barra
        partes = re.split(sinal[0], servico)
        
        # Realizando o capitalize na primeira parte (antes do traço)
        parte1 = partes[0].capitalize()

        # Realizando o capitalize na segunda parte (depois do traço)
        parte2 = partes[1].capitalize()
        
        return "".join([parte1, sinal[0], parte2])
    else:
        return servico.capitalize()

# %%
df3['Serviço'] = df3['Serviço'].apply(lambda x: capitalize(x) if not re.search(r'RGA|CMCA', x) else x)

# %%
df3[['Tipo de Serviço', 'Serviço']].drop_duplicates().sort_values(by=['Tipo de Serviço', 'Serviço'])
# Out:
#                                         Tipo de Serviço
# 3                                     Adoção de animais  \
# 547267                                          Animais
# 21      Animais que transmitem doenças ou risco à saúde
# 547261  Animais que transmitem doenças ou risco à saúde
# 603218  Animais que transmitem doenças ou risco à saúde
# 547337  Animais que transmitem doenças ou risco à saúde
# 361615  Animais que transmitem doenças ou risco à saúde
# 397007  Animais que transmitem doenças ou risco à saúde
# 386661  Animais que transmitem doenças ou risco à saúde
# 69      Animais que transmitem doenças ou risco à saúde
# 547285  Animais que transmitem doenças ou risco à saúde
# 547455  Animais que transmitem doenças ou risco à saúde
# 15      Animais que transmitem doenças ou risco à saúde
# 547766  Animais que transmitem doenças ou risco à saúde
# 14      Animais que transmitem doenças ou risco à saúde
# 227     Animais que transmitem doenças ou risco à saúde
# 392961  Animais que transmitem doenças ou risco à saúde
# 19      Animais que transmitem doenças ou risco à saúde
# 1460                                 Animais silvestres
# 6                                    Animais silvestres
# 23                         Animal agressor e/ou invasor
# 25                         Animal agressor e/ou invasor
# 109                               Animal em via pública
# 12                                Animal em via pública
# 9                                 Animal em via pública
# 547806                                           Cavalo
# 548131                                           Cavalo
# 34365                               Comércio de animais
# 26265                               Comércio de animais
# 4                         Criação inadequada de animais
# 547262                                              Cão
# 547255                                              Cão
# 547265                                              Cão
# 548547                                              Cão
# 547310                                              Cão
# 699127                                              Cão
# 1                           Exames, vacinas e castração
# 547279                                             Gato
# 547259                                             Gato
# 547438                                             Gato
# 548045                                             Gato
# 547281                                             Gato
# 0                             Registro de animais - RGA
# 1276                          Registro de animais - RGA
# 71                            Registro de animais - RGA
# 554332                                         Vistoria
# 552522                                         Vistoria
# 547808                                         Vistoria
# 548160                                         Vistoria
# 66                                             Vistoria
#
#                                                                                   Serviço
# 3                                                                     Adotar cães e gatos
# 547267                                             Remoção de animal morto em via pública
# 21                                                                       Abelhas e vespas
# 547261                                                     Abelhas, vespas ou marimbondos
# 603218           Animais que transmitem doenças ou risco à saúde - Ocorrências rotineiras
# 547337                                                 Condições de criação / Maus tratos
# 361615                                                              Reclamação de aranhas
# 397007                                                              Reclamação de baratas
# 386661                                                           Reclamação de carrapatos
# 69                                                               Reclamação de escorpiões
# 547285                                                Reclamação de escorpiões ou aranhas
# 547455                                                             Reclamação de formigas
# 15                                                                 Reclamação de morcegos
# 547766                                                               Reclamação de moscas
# 14                                                  Reclamação de pernilongos e mosquitos
# 227                                                                  Reclamação de pombos
# 392961                                                               Reclamação de pulgas
# 19                                                                    Reclamação de ratos
# 1460                                      Animais silvestres - Agendar entrega voluntária
# 6                          Animais silvestres feridos - Solicitar atendimento veterinário
# 23                                          Avisar sobre animal agressor em vias públicas
# 25                  Cães e gatos invasores de instituições públicas - Solicitar avaliação
# 109                                      Animal de grande porte solto - Solicitar remoção
# 12      Avaliação de animal em sofrimento sem proprietário para eutanásia (morte sem dor)
# 9                                                  Remoção de animal morto em via pública
# 547806                                                      Cavalo - Diversas ocorrências
# 548131                                                 Condições de criação / Maus tratos
# 34365                Cadastro Municipal de Comércio de Animais (CMCA) - Cancelar cadastro
# 26265                  Cadastro Municipal de Comércio de Animais (CMCA) - Fazer inscrição
# 4                                                      Condições de criação / Maus tratos
# 547262                                   Atropelado ou acidentado vivo e sem proprietário
# 547255                                                 Condições de criação / Maus tratos
# 547265                                                                       Cão agressor
# 548547                                                             Cão encontrado com RGA
# 547310                                                                Cão invadiu o local
# 699127                                                           Cão solto em via pública
# 1                                                      Castrar cães e gatos gratuitamente
# 547279                                   Atropelado ou acidentado vivo e sem proprietário
# 547259                                                 Condições de criação / Maus tratos
# 547438                                                                      Gato agressor
# 548045                                                            Gato encontrado com RGA
# 547281                                                               Gato invadiu o local
# 0                      Avisar  sobre animal encontrado com Registro Geral do Animal (RGA)
# 1276                                     Registro Geral do Animal (RGA) - Atualizar dados
# 71                        Registro Geral do Animal (RGA) - Solicitar identidade do animal
# 554332                                                        Cães em vigilância bancária
# 552522                                                  Falta de placa sobre animal feroz
# 547808                                                           Trânsito de boiadas a pé
# 548160                                                                Vistoria em parques
# 66                          Água limpa e parada - Solicitar vistoria de local com acúmulo

# %% [markdown]
# ### Tratar o "Status da solicitação"

# %%
df4 = df3.copy()

# %%
df4['Status da solicitação'].drop_duplicates().sort_values()
# Out:
# 0         AGUARDANDO ATENDIMENTO
# 403                    CANCELADA
# 1                     FINALIZADA
# 547398                INDEFERIDA
# 4                     INDEFERIDO
# Name: Status da solicitação, dtype: object

# %%
df4['Status da solicitação'] = df4['Status da solicitação'].str.replace('CANCELADO', 'CANCELADA')
df4['Status da solicitação'] = df4['Status da solicitação'].str.replace('FINALIZADO', 'FINALIZADA')
df4['Status da solicitação'] = df4['Status da solicitação'].str.replace('REALIZADA', 'FINALIZADA')
df4['Status da solicitação'] = df4['Status da solicitação'].str.replace('INDEFERIDO', 'INDEFERIDA')
df4['Status da solicitação'] = df4['Status da solicitação'].str.replace('ABERTA', 'AGUARDANDO ATENDIMENTO')
df4['Status da solicitação'] = df4['Status da solicitação'].str.replace('EM ANDAMENTO', 'AGUARDANDO ATENDIMENTO')

# %%
df4['Status da solicitação'].drop_duplicates().sort_values()
# Out:
# 0      AGUARDANDO ATENDIMENTO
# 403                 CANCELADA
# 1                  FINALIZADA
# 4                  INDEFERIDA
# Name: Status da solicitação, dtype: object

# %% [markdown]
# ### Transformar todas as datas e horas para apenas data

# %% [markdown]
# #### 'Data de abertura'

# %%
df4['Data de abertura'] = df4['Data de abertura'].str.slice(0,10)

# %%
df4['Data de abertura'] = pd.to_datetime(df4['Data de abertura']).dt.date

# %%
df4['Data de abertura'].sample(10)
# Out:
# 221461    2021-06-20
# 93959     2022-06-27
# 419995    2017-08-01
# 136692    2021-10-30
# 199389    2021-04-26
# 57631     2022-08-28
# 479527    2016-02-18
# 143737    2021-11-19
# 677472    2012-11-01
# 642866    2013-03-13
# Name: Data de abertura, dtype: object

# %%
df4.loc[df4['Data do parecer'].notnull(), 'Data do parecer'] = df4.loc[
    df4['Data do parecer'].notnull(), 'Data do parecer'].str.slice(0,10)

# %%
df4['Data do parecer'].sample(10)
# Out:
# 582631    2014-04-23
# 537365    2015-07-02
# 489       2023-01-13
# 398613    2018-12-23
# 96696     2022-01-18
# 587526    2014-07-30
# 279252    2020-10-29
# 366430    2019-03-27
# 382670    2018-08-21
# 578332    2014-02-06
# Name: Data do parecer, dtype: object

# %%
df4.sample(10)
# Out:
#        Data de abertura     Tema
# 270565       2020-10-02  Animais  \
# 222911       2021-06-23  Animais
# 529203       2015-02-24  Animais
# 659687       2013-06-29      NaN
# 215859       2021-06-06  Animais
# 199572       2021-04-26  Animais
# 280593       2020-11-02  Animais
# 8734         2023-01-27  Animais
# 79083        2022-05-09  Animais
# 430726       2017-11-23  Animais
#
#                                         Tipo de Serviço
# 270565                            Animal em via pública  \
# 222911                      Exames, vacinas e castração
# 529203  Animais que transmitem doenças ou risco à saúde
# 659687                                              Cão
# 215859                      Exames, vacinas e castração
# 199572                      Exames, vacinas e castração
# 280593                     Animal agressor e/ou invasor
# 8734                        Exames, vacinas e castração
# 79083                     Criação inadequada de animais
# 430726  Animais que transmitem doenças ou risco à saúde
#
#                                               Serviço       Distrito
# 270565         Remoção de animal morto em via pública       PIRITUBA  \
# 222911             Castrar cães e gatos gratuitamente            NaN
# 529203                 Abelhas, Vespas ou Marimbondos            NaN
# 659687                                   Cão agressor  JARDIM HELENA
# 215859             Castrar cães e gatos gratuitamente            NaN
# 199572             Castrar cães e gatos gratuitamente            NaN
# 280593  Avisar sobre animal agressor em vias públicas        LAJEADO
# 8734               Castrar cães e gatos gratuitamente            NaN
# 79083              Condições de criação / Maus tratos     SAO MATEUS
# 430726                            Reclamação de ratos       MANDAQUI
#
#        Status da solicitação Data do parecer
# 270565             CANCELADA      2020-10-02
# 222911            FINALIZADA      2021-06-29
# 529203            FINALIZADA      2015-05-13
# 659687             CANCELADA      2013-07-02
# 215859            FINALIZADA      2021-06-11
# 199572            FINALIZADA      2021-05-08
# 280593            FINALIZADA      2020-12-19
# 8734              INDEFERIDA      2023-01-27
# 79083             FINALIZADA      2022-07-26
# 430726            FINALIZADA      2019-02-26

# %%
df4.isnull().any()
# Out:
# Data de abertura         False
# Tema                      True
# Tipo de Serviço          False
# Serviço                  False
# Distrito                  True
# Status da solicitação    False
# Data do parecer           True
# dtype: bool

# %% [markdown]
# ## Gerar o arquivo com os dados necessários

# %%
df4.to_parquet('sp156_all_time.gzip',
              compression='gzip',
              index=False)
